# %%
import logging

from collections import defaultdict
from itertools import combinations

from gensim import corpora
from gensim.corpora import Dictionary
from nltk.corpus import wordnet as wn

# %%
dictionary = corpora.Dictionary.load('../data/spa.dict')
corpus = corpora.MmCorpus('../data/spa.mm')

syn_dict = Dictionary()

# %%
syn_map = defaultdict(set)

word_count = 0
for term in dictionary.values():
    word_count += 1

    syns = wn.synsets(term)
    
    for syn_obj in syns:
        syn = syn_obj.name().split('.')[0]
        
        if syn in syn_dict.token2id:
            syn_map[syn_dict.token2id[syn]].add(term)
            
        else:
            syn_dict.add_documents([[syn]])
            syn_map[syn_dict.token2id[syn]].add(term)

# %% [markdown]
# ## Triangles
# For every syn, there is a term in the SPA associated with it, sometimes multiple, creating a triangle effect.
# Here is a POC for this.
#
# From this, you can create new synonym nodes on the pre-existing graph.

# %%
for syn_id, terms in syn_map.items():
    if len(terms) > 1:
        print('\n')
        print(f"SYN --> {syn_dict[syn_id]}")
        print(f"SPA --> {terms}")
# Out:
# SYN --> buy
# SPA --> {'buying', 'bought'}
#
#
# SYN --> bribe
# SPA --> {'corrupt', 'corrupted', 'bribe', 'bought', 'bribes', 'buying'}
#
#
# SYN --> breast
# SPA --> {'chest', 'bosoms', 'breast', 'bosom', 'chests', 'breasts'}
#
#
# SYN --> summit
# SPA --> {'breast', 'breasts'}
#
#
# SYN --> front
# SPA --> {'looked', 'faced', 'breast', 'looking', 'front', 'breasts', 'facing', 'face', 'looks', 'look', 'fronts', 'faces'}
#
#
# SYN --> brow
# SPA --> {'brows', 'brow'}
#
#
# SYN --> eyebrow
# SPA --> {'brows', 'brow'}
#
#
# SYN --> hilltop
# SPA --> {'brows', 'brow'}
#
#
# SYN --> care
# SPA --> {'cares', 'care', 'attention', 'caring', 'cared', 'charge'}
#
#
# SYN --> caution
# SPA --> {'cares', 'care'}
#
#
# SYN --> concern
# SPA --> {'fears', 'interest', 'cares', 'worried', 'fear', 'care', 'concerned'}
#
#
# SYN --> wish
# SPA --> {'wants', 'bade', 'cares', 'wished', 'want', 'care', 'wishing', 'caring', 'like', 'cared', 'wish', 'bidding'}
#
#
# SYN --> manage
# SPA --> {'deal', 'managed', 'cares', 'care', 'handling', 'caring', 'cared'}
#
#
# SYN --> worry
# SPA --> {'cares', 'worried', 'trouble', 'care', 'caring', 'cared', 'vexed'}
#
#
# SYN --> clasp
# SPA --> {'grip', 'hold', 'holds', 'clasped', 'clasp', 'grasp'}
#
#
# SYN --> brooch
# SPA --> {'clasped', 'clasp'}
#
#
# SYN --> buckle
# SPA --> {'buckles', 'clasped', 'clasp'}
#
#
# SYN --> dark
# SPA --> {'dark', 'darkness'}
#
#
# SYN --> iniquity
# SPA --> {'dark', 'darkness'}
#
#
# SYN --> darkness
# SPA --> {'dark', 'shadow', 'shadows', 'darkness'}
#
#
# SYN --> night
# SPA --> {'dark', 'nights', 'night'}
#
#
# SYN --> black
# SPA --> {'black', 'blackness', 'blackened', 'dark', 'shameful', 'grim'}
#
#
# SYN --> blue
# SPA --> {'dingy', 'drab', 'blue', 'blueness', 'dark', 'grim'}
#
#
# SYN --> colored
# SPA --> {'dark', 'colored'}
#
#
# SYN --> beloved
# SPA --> {'loves', 'dearest', 'honey', 'love', 'beloved', 'dear'}
#
#
# SYN --> lamb
# SPA --> {'lambs', 'dear'}
#
#
# SYN --> dear
# SPA --> {'better', 'dearest', 'earnest', 'dear', 'best', 'good', 'near'}
#
#
# SYN --> costly
# SPA --> {'dear', 'dearest'}
#
#
# SYN --> die
# SPA --> {'croaks', 'pass', 'died', 'dying', 'gone', 'dies', 'choked', 'passed', 'perished', 'going', 'deceased', 'passes', 'perish', 'went', 'passing', 'pall', 'goes'}
#
#
# SYN --> fail
# SPA --> {'neglect', 'break', 'died', 'dying', 'fails', 'dies', 'gone', 'failing', 'broke', 'going', 'bombs', 'neglected', 'betrayed', 'breaks', 'fail', 'failed', 'went', 'broken', 'goes'}
#
#
# SYN --> phonograph_record
# SPA --> {'disk', 'record', 'platter'}
#
#
# SYN --> eye
# SPA --> {'eyes', 'eyeballs'}
#
#
# SYN --> center
# SPA --> {'middle', 'hearts', 'eyes', 'center', 'halfway', 'heart', 'centre'}
#
#
# SYN --> fast
# SPA --> {'fastest', 'tight', 'fast'}
#
#
# SYN --> debauched
# SPA --> {'fastest', 'degenerate', 'fast', 'riotous'}
#
#
# SYN --> flying
# SPA --> {'quick', 'fastest', 'flying', 'fast'}
#
#
# SYN --> firm
# SPA --> {'strongest', 'fastest', 'house', 'fast', 'loyal', 'houses', 'stiff', 'steadfast', 'stronger', 'strong'}
#
#
# SYN --> father
# SPA --> {'father', 'fathers'}
#
#
# SYN --> forefather
# SPA --> {'father', 'fathers'}
#
#
# SYN --> church_father
# SPA --> {'father', 'fathers'}
#
#
# SYN --> founder
# SPA --> {'father', 'fathers'}
#
#
# SYN --> don
# SPA --> {'father', 'fathers'}
#
#
# SYN --> beget
# SPA --> {'engendered', 'mother', 'getting', 'father', 'mothers', 'fathers'}
#
#
# SYN --> fire
# SPA --> {'firing', 'fires', 'fired', 'fire', 'blast', 'discharge', 'flaming', 'attacks', 'flames', 'flame'}
#
#
# SYN --> flare
# SPA --> {'flamed', 'flash', 'flashes', 'flaming', 'flames', 'flame'}
#
#
# SYN --> flame
# SPA --> {'flaming', 'flamed', 'flames', 'flame'}
#
#
# SYN --> flower
# SPA --> {'bloom', 'prime', 'flowers', 'blossoms', 'blossom', 'peaks', 'peak', 'flower'}
#
#
# SYN --> bloom
# SPA --> {'bloom', 'flowers', 'blossoms', 'blossoming', 'blossom', 'bloomed', 'flowering', 'flower'}
#
#
# SYN --> luck
# SPA --> {'hazards', 'chance', 'fortune', 'fortunes', 'chances'}
#
#
# SYN --> fortune
# SPA --> {'destiny', 'destinies', 'fates', 'fortune', 'fortunes', 'fate'}
#
#
# SYN --> hand
# SPA --> {'deal', 'hands', 'handed', 'hand'}
#
#
# SYN --> hired_hand
# SPA --> {'hands', 'hand'}
#
#
# SYN --> handwriting
# SPA --> {'hands', 'hand'}
#
#
# SYN --> bridge_player
# SPA --> {'hands', 'hand'}
#
#
# SYN --> pass
# SPA --> {'reached', 'pass', 'reaching', 'head', 'handed', 'passing', 'clear', 'gave', 'hands', 'give', 'passed', 'given', 'gives', 'heads', 'giving', 'hand', 'reach', 'cleared', 'passport', 'passes', 'notches', 'reaches'}
#
#
# SYN --> have
# SPA --> {'made', 'having', 'getting', 'holding', 'have', 'makes', 'making', 'features', 'holds', 'held', 'make', 'hold'}
#
#
# SYN --> experience
# SPA --> {'seen', 'received', 'getting', 'having', 'receive', 'have', 'seeing', 'sees'}
#
#
# SYN --> own
# SPA --> {'owned', 'have', 'possess', 'having'}
#
#
# SYN --> get
# SPA --> {'catching', 'catches', 'received', 'letting', 'lets', 'having', 'receive', 'getting', 'captured', 'catch', 'have', 'acquired', 'caught', 'capture'}
#
#
# SYN --> consume
# SPA --> {'eating', 'exhausted', 'takes', 'exhaust', 'taking', 'wasted', 'wastes', 'eaten', 'took', 'having', 'taken', 'have', 'take', 'waste', 'wasting'}
#
#
# SYN --> hold
# SPA --> {'carrying', 'made', 'bear', 'contained', 'have', 'makes', 'carried', 'gave', 'give', 'given', 'thrown', 'keep', 'gives', 'giving', 'borne', 'born', 'keeps', 'supporting', 'carry', 'having', 'bearing', 'holds', 'bore', 'hold', 'supported', 'containing', 'holding', 'throw', 'threw', 'held', 'support', 'make', 'making'}
#
#
# SYN --> induce
# SPA --> {'hastened', 'rushing', 'made', 'causes', 'rushed', 'cause', 'having', 'getting', 'hastens', 'have', 'makes', 'make', 'making'}
#
#
# SYN --> accept
# SPA --> {'swallowed', 'takes', 'taking', 'having', 'took', 'taken', 'admit', 'have', 'take', 'swallows', 'swallow'}
#
#
# SYN --> receive
# SPA --> {'received', 'finding', 'having', 'receive', 'find', 'getting', 'have', 'found', 'obtained'}
#
#
# SYN --> suffer
# SPA --> {'loses', 'enduring', 'suffer', 'lost', 'lose', 'losing', 'meet', 'suffering', 'having', 'getting', 'meetings', 'have', 'suffers'}
#
#
# SYN --> give_birth
# SPA --> {'born', 'delivers', 'having', 'bear', 'bearing', 'have', 'borne', 'birth', 'bore'}
#
#
# SYN --> take
# SPA --> {'takes', 'made', 'taking', 'reading', 'having', 'took', 'taken', 'have', 'take', 'makes', 'submit', 'read', 'make', 'making'}
#
#
# SYN --> head
# SPA --> {'headed', 'leads', 'lead', 'head', 'chief', 'heads', 'leading'}
#
#
# SYN --> mind
# SPA --> {'idea', 'mind', 'head', 'minds', 'brain', 'ideas', 'heads', 'brains'}
#
#
# SYN --> fountainhead
# SPA --> {'head', 'heads'}
#
#
# SYN --> capitulum
# SPA --> {'head', 'heads'}
#
#
# SYN --> principal
# SPA --> {'head', 'heads'}
#
#
# SYN --> promontory
# SPA --> {'head', 'heads'}
#
#
# SYN --> forefront
# SPA --> {'head', 'heads'}
#
#
# SYN --> headway
# SPA --> {'head', 'heads'}
#
#
# SYN --> point
# SPA --> {'point', 'heads', 'head', 'pointed', 'tips', 'points', 'peaks', 'pointing', 'peak'}
#
#
# SYN --> question
# SPA --> {'head', 'question', 'heads'}
#
#
# SYN --> heading
# SPA --> {'head', 'heads'}
#
#
# SYN --> read/write_head
# SPA --> {'head', 'heads'}
#
#
# SYN --> drumhead
# SPA --> {'head', 'heads'}
#
#
# SYN --> oral_sex
# SPA --> {'head', 'heads'}
#
#
# SYN --> lead
# SPA --> {'takes', 'taking', 'topped', 'headed', 'leads', 'lead', 'tracks', 'taken', 'took', 'head', 'track', 'direct', 'conduct', 'take', 'heads', 'conducted', 'leading'}
#
#
# SYN --> steer
# SPA --> {'headed', 'point', 'heads', 'direct', 'head', 'pointed', 'points', 'pointing', 'steer'}
#
#
# SYN --> heart
# SPA --> {'bosoms', 'nerves', 'hearts', 'bosom', 'spirit', 'spirits', 'heart'}
#
#
# SYN --> kernel
# SPA --> {'meats', 'hearts', 'substance', 'center', 'core', 'heart', 'centre', 'substances', 'essence', 'kernel', 'meat'}
#
#
# SYN --> affection
# SPA --> {'heart', 'hearts'}
#
#
# SYN --> appreciation
# SPA --> {'grasp', 'holds', 'hold'}
#
#
# SYN --> delay
# SPA --> {'delayed', 'wait', 'holds', 'hold'}
#
#
# SYN --> detention
# SPA --> {'holds', 'hold'}
#
#
# SYN --> handle
# SPA --> {'grip', 'holds', 'handling', 'palms', 'hold'}
#
#
# SYN --> cargo_area
# SPA --> {'holds', 'hold'}
#
#
# SYN --> keep
# SPA --> {'held', 'keeps', 'keep', 'preserve', 'kept', 'holding', 'holds', 'keeping', 'hold'}
#
#
# SYN --> deem
# SPA --> {'holding', 'held', 'holds', 'hold'}
#
#
# SYN --> harbor
# SPA --> {'nursed', 'harbor', 'shields', 'holding', 'nurses', 'holds', 'entertained', 'held', 'hold'}
#
#
# SYN --> restrain
# SPA --> {'held', 'keeps', 'keep', 'kept', 'holding', 'holds', 'keeping', 'hold'}
#
#
# SYN --> retain
# SPA --> {'held', 'keeps', 'keep', 'kept', 'holding', 'holds', 'keeping', 'hold'}
#
#
# SYN --> bear
# SPA --> {'born', 'hold', 'bear', 'bearing', 'holding', 'holds', 'borne', 'held', 'bore'}
#
#
# SYN --> accommodate
# SPA --> {'admit', 'holding', 'holds', 'held', 'hold'}
#
#
# SYN --> prevail
# SPA --> {'enduring', 'runs', 'holding', 'running', 'obtained', 'triumph', 'holds', 'held', 'hold'}
#
#
# SYN --> contain
# SPA --> {'takes', 'taking', 'containing', 'taken', 'took', 'holding', 'contained', 'take', 'holds', 'held', 'hold'}
#
#
# SYN --> reserve
# SPA --> {'book', 'books', 'holding', 'holds', 'held', 'reserved', 'hold'}
#
#
# SYN --> defend
# SPA --> {'supported', 'supporting', 'guarded', 'guarding', 'guard', 'defended', 'holding', 'representing', 'holds', 'defend', 'held', 'support', 'hold'}
#
#
# SYN --> oblige
# SPA --> {'holding', 'holds', 'bound', 'held', 'hold'}
#
#
# SYN --> defy
# SPA --> {'refused', 'refusing', 'holding', 'holds', 'withstood', 'held', 'hold'}
#
#
# SYN --> apply
# SPA --> {'holding', 'held', 'holds', 'hold'}
#
#
# SYN --> control
# SPA --> {'checked', 'containing', 'check', 'curb', 'holding', 'contained', 'holds', 'control', 'held', 'hold'}
#
#
# SYN --> halt
# SPA --> {'halted', 'arrested', 'holding', 'arrest', 'holds', 'halt', 'held', 'hold'}
#
#
# SYN --> carry
# SPA --> {'carrying', 'takes', 'taking', 'swayed', 'runs', 'express', 'carry', 'taken', 'took', 'holding', 'running', 'take', 'holds', 'carried', 'extends', 'held', 'hold'}
#
#
# SYN --> declare
# SPA --> {'holding', 'held', 'holds', 'hold'}
#
#
# SYN --> agree
# SPA --> {'concord', 'holding', 'holds', 'held', 'agreed', 'hold'}
#
#
# SYN --> hope
# SPA --> {'desiring', 'trusted', 'desire', 'hopes', 'desired', 'hoping', 'hope', 'hoped'}
#
#
# SYN --> hop
# SPA --> {'skipped', 'skipping', 'hoped', 'hopes', 'hoping'}
#
#
# SYN --> put
# SPA --> {'laid', 'setting', 'places', 'placed', 'lays', 'place', 'puts'}
#
#
# SYN --> lay
# SPA --> {'laid', 'repose', 'lays'}
#
#
# SYN --> life
# SPA --> {'living', 'lives', 'lifes', 'life', 'lifetime'}
#
#
# SYN --> animation
# SPA --> {'lifes', 'life', 'living', 'lives'}
#
#
# SYN --> liveliness
# SPA --> {'spirit', 'lives', 'spirits', 'lifes', 'life'}
#
#
# SYN --> biography
# SPA --> {'lifes', 'life', 'lives'}
#
#
# SYN --> life_sentence
# SPA --> {'lifes', 'life', 'lives'}
#
#
# SYN --> like
# SPA --> {'like', 'same'}
#
#
# SYN --> alike
# SPA --> {'alike', 'like'}
#
#
# SYN --> fluent
# SPA --> {'liquid', 'smooth'}
#
#
# SYN --> fluid
# SPA --> {'fluids', 'liquid'}
#
#
# SYN --> little
# SPA --> {'small', 'smaller', 'slight', 'slightest', 'little'}
#
#
# SYN --> small
# SPA --> {'little', 'small', 'smaller'}
#
#
# SYN --> fiddling
# SPA --> {'trivial', 'little'}
#
#
# SYN --> short
# SPA --> {'little', 'short'}
#
#
# SYN --> hanker
# SPA --> {'long', 'longing', 'longed', 'longs'}
#
#
# SYN --> love
# SPA --> {'loves', 'enjoy', 'loved', 'love', 'passion', 'passions', 'enjoying', 'loving'}
#
#
# SYN --> sexual_love
# SPA --> {'loves', 'love'}
#
#
# SYN --> sleep_together
# SPA --> {'loves', 'loved', 'beds', 'love', 'knew', 'knowing', 'knows', 'known', 'know', 'loving'}
#
#
# SYN --> nox
# SPA --> {'nights', 'night'}
#
#
# SYN --> nurse
# SPA --> {'nurses', 'nursed'}
#
#
# SYN --> breastfeed
# SPA --> {'nurses', 'suck', 'nursed', 'sucked'}
#
#
# SYN --> pay
# SPA --> {'paying', 'paid'}
#
#
# SYN --> give
# SPA --> {'spring', 'springs', 'paid', 'threw', 'give', 'yielded', 'presented', 'given', 'gifted', 'thrown', 'gives', 'yield', 'committing', 'throw', 'gifts', 'gift', 'paying', 'giving', 'gave', 'devoted'}
#
#
# SYN --> pay_up
# SPA --> {'paying', 'paid'}
#
#
# SYN --> yield
# SPA --> {'softened', 'borne', 'paid', 'born', 'give', 'yielded', 'fruits', 'given', 'yield', 'fruit', 'gives', 'bear', 'bearing', 'paying', 'giving', 'gave', 'bore'}
#
#
# SYN --> gainful
# SPA --> {'paying', 'paid'}
#
#
# SYN --> pillow
# SPA --> {'rested', 'pillow', 'resting', 'rest', 'pillows', 'rests'}
#
#
# SYN --> supply
# SPA --> {'provided', 'provide'}
#
#
# SYN --> provide
# SPA --> {'provided', 'plied', 'provide'}
#
#
# SYN --> put_up
# SPA --> {'provided', 'contributing', 'offer', 'provide', 'offered'}
#
#
# SYN --> leave
# SPA --> {'leaves', 'leads', 'provided', 'departed', 'departing', 'lead', 'left', 'leaving', 'result', 'provide', 'leave', 'leading'}
#
#
# SYN --> room
# SPA --> {'ways', 'rooms', 'room'}
#
#
# SYN --> board
# SPA --> {'table', 'boarded', 'boards', 'rooms', 'room', 'board'}
#
#
# SYN --> state
# SPA --> {'said', 'saying', 'land', 'country', 'countries', 'states', 'nation', 'tell', 'telling', 'nations', 'lands', 'says', 'told', 'state'}
#
#
# SYN --> allege
# SPA --> {'said', 'says', 'saying'}
#
#
# SYN --> suppose
# SPA --> {'said', 'suppose', 'says', 'saying'}
#
#
# SYN --> read
# SPA --> {'said', 'show', 'record', 'shown', 'reading', 'says', 'read', 'showing', 'showed', 'saying'}
#
#
# SYN --> order
# SPA --> {'said', 'tell', 'orders', 'telling', 'says', 'ordered', 'told', 'order', 'saying'}
#
#
# SYN --> pronounce
# SPA --> {'said', 'saying', 'judging', 'says', 'judged', 'judge', 'judges'}
#
#
# SYN --> say
# SPA --> {'said', 'says', 'saying'}
#
#
# SYN --> sink
# SPA --> {'dropping', 'pass', 'dropped', 'sink', 'passed', 'sank', 'sunk', 'settle', 'passes', 'sinks', 'sinking', 'passing', 'drop'}
#
#
# SYN --> dip
# SPA --> {'sink', 'sank', 'sunk', 'duck', 'sinks', 'sinking'}
#
#
# SYN --> slump
# SPA --> {'slouch', 'sink', 'sank', 'sunk', 'slack', 'sinks', 'sinking', 'slacks'}
#
#
# SYN --> bury
# SPA --> {'buried', 'sink', 'sank', 'burying', 'sunk', 'sinks', 'sinking'}
#
#
# SYN --> faux_pas
# SPA --> {'slips', 'slip'}
#
#
# SYN --> slip
# SPA --> {'sneaked', 'slipping', 'slips', 'slipped', 'sneak', 'sneaking', 'trip', 'slip'}
#
#
# SYN --> cutting
# SPA --> {'keen', 'keener', 'slips', 'slip', 'piercing'}
#
#
# SYN --> mooring
# SPA --> {'slips', 'slip'}
#
#
# SYN --> slickness
# SPA --> {'slips', 'slip'}
#
#
# SYN --> strip
# SPA --> {'stripping', 'strips', 'slips', 'stripped', 'slip', 'strip'}
#
#
# SYN --> chemise
# SPA --> {'slips', 'shift', 'slip'}
#
#
# SYN --> case
# SPA --> {'slips', 'example', 'slip', 'cases', 'case'}
#
#
# SYN --> skid
# SPA --> {'slew', 'slipping', 'slips', 'slipped', 'slip'}
#
#
# SYN --> steal
# SPA --> {'slipping', 'slips', 'slipped', 'stealing', 'stole', 'slip', 'steals', 'steal'}
#
#
# SYN --> err
# SPA --> {'slipping', 'slips', 'slipped', 'mistook', 'slip'}
#
#
# SYN --> dislocate
# SPA --> {'slips', 'slip', 'slipped', 'slipping'}
#
#
# SYN --> smile
# SPA --> {'smiled', 'smile', 'smiles', 'grin', 'smiling'}
#
#
# SYN --> soul
# SPA --> {'souls', 'soul'}
#
#
# SYN --> person
# SPA --> {'souls', 'soul', 'mortal', 'persons', 'person', 'someone'}
#
#
# SYN --> idea
# SPA --> {'thoughts', 'thought', 'idea', 'ideas'}
#
#
# SYN --> thinking
# SPA --> {'thoughts', 'thought', 'thinking'}
#
#
# SYN --> thought
# SPA --> {'thoughts', 'thought'}
#
#
# SYN --> opinion
# SPA --> {'judgments', 'judgment', 'thought', 'thoughts', 'view'}
#
#
# SYN --> think
# SPA --> {'reckoned', 'imagine', 'believing', 'thinking', 'thinks', 'believe', 'thought', 'think', 'believed', 'considered', 'suppose'}
#
#
# SYN --> remember
# SPA --> {'retrieve', 'thinking', 'thinks', 'remembered', 'thought', 'think', 'remembers', 'remember'}
#
#
# SYN --> intend
# SPA --> {'thinking', 'thinks', 'meant', 'thought', 'destined', 'mean', 'meaning', 'think', 'means'}
#
#
# SYN --> till
# SPA --> {'till', 'tilled'}
#
#
# SYN --> public_treasury
# SPA --> {'troughs', 'till', 'trough'}
#
#
# SYN --> assume
# SPA --> {'seized', 'takes', 'taking', 'seizing', 'taken', 'adopt', 'took', 'strike', 'striking', 'take', 'acquired', 'struck', 'seize'}
#
#
# SYN --> bring
# SPA --> {'played', 'take', 'wrought', 'working', 'works', 'work', 'landed', 'worked', 'getting', 'took', 'taken', 'play', 'bring', 'brought', 'landing', 'takes', 'land', 'taking', 'playing', 'brings', 'bringing', 'lands'}
#
#
# SYN --> choose
# SPA --> {'takes', 'taking', 'choose', 'chosen', 'selected', 'taken', 'took', 'take', 'chose'}
#
#
# SYN --> fill
# SPA --> {'takes', 'taking', 'fill', 'taken', 'took', 'take', 'filled', 'fills'}
#
#
# SYN --> consider
# SPA --> {'deal', 'takes', 'taking', 'deliberate', 'debate', 'weighed', 'counts', 'took', 'taken', 'take', 'counting', 'considered', 'count'}
#
#
# SYN --> necessitate
# SPA --> {'takes', 'taking', 'needs', 'needed', 'needing', 'asking', 'taken', 'took', 'asked', 'take', 'need'}
#
#
# SYN --> film
# SPA --> {'takes', 'taking', 'celluloid', 'taken', 'took', 'take', 'shoots', 'shot'}
#
#
# SYN --> remove
# SPA --> {'takes', 'withdrawing', 'taking', 'removed', 'withdraws', 'taken', 'took', 'remove', 'take', 'withdrew'}
#
#
# SYN --> learn
# SPA --> {'study', 'learning', 'learned', 'take', 'studying', 'seeing', 'reading', 'taken', 'took', 'heard', 'acquired', 'sees', 'learn', 'hear', 'takes', 'taking', 'seen', 'hearing', 'studied', 'read', 'discovered'}
#
#
# SYN --> claim
# SPA --> {'takes', 'claimed', 'taking', 'title', 'taken', 'took', 'take', 'claims', 'claim'}
#
#
# SYN --> aim
# SPA --> {'takes', 'taking', 'aimed', 'direct', 'taken', 'took', 'trains', 'take', 'train', 'purpose'}
#
#
# SYN --> lease
# SPA --> {'takes', 'rented', 'taking', 'hired', 'letting', 'rents', 'lets', 'taken', 'took', 'take', 'chartered', 'engaged'}
#
#
# SYN --> subscribe
# SPA --> {'takes', 'taking', 'supported', 'supporting', 'taken', 'took', 'take', 'support'}
#
#
# SYN --> drive
# SPA --> {'driven', 'takes', 'drove', 'ride', 'taking', 'aimed', 'getting', 'took', 'taken', 'thrust', 'riding', 'take', 'drive', 'driving', 'rides'}
#
#
# SYN --> contract
# SPA --> {'takes', 'taking', 'getting', 'took', 'taken', 'take'}
#
#
# SYN --> heat
# SPA --> {'warmth', 'passion', 'heat', 'passions'}
#
#
# SYN --> well
# SPA --> {'better', 'well', 'swells', 'best', 'good'}
#
#
# SYN --> good
# SPA --> {'better', 'well', 'right', 'just', 'sound', 'goods', 'upright', 'best', 'good'}
#
#
# SYN --> travel
# SPA --> {'gone', 'traveling', 'going', 'traveled', 'trip', 'move', 'moved', 'went', 'moving', 'goes'}
#
#
# SYN --> go
# SPA --> {'turns', 'turn', 'gone', 'leads', 'departed', 'departing', 'going', 'lead', 'move', 'moved', 'went', 'goes', 'moving', 'leading'}
#
#
# SYN --> become
# SPA --> {'turns', 'turning', 'turn', 'gone', 'suits', 'going', 'getting', 'turned', 'became', 'become', 'becoming', 'becomes', 'went', 'goes'}
#
#
# SYN --> run
# SPA --> {'bleeding', 'feeds', 'pass', 'going', 'flowing', 'flows', 'passing', 'goes', 'passed', 'running', 'feed', 'went', 'course', 'runs', 'lead', 'bled', 'coursing', 'extends', 'gone', 'leads', 'passes', 'ladder', 'leading'}
#
#
# SYN --> proceed
# SPA --> {'went', 'going', 'gone', 'goes'}
#
#
# SYN --> sound
# SPA --> {'gone', 'going', 'sound', 'sounds', 'went', 'sounded', 'goes'}
#
#
# SYN --> function
# SPA --> {'gone', 'runs', 'going', 'worked', 'parts', 'office', 'working', 'running', 'wrought', 'part', 'went', 'uses', 'goes', 'works', 'work', 'purpose'}
#
#
# SYN --> run_low
# SPA --> {'went', 'going', 'gone', 'goes'}
#
#
# SYN --> move
# SPA --> {'gone', 'runs', 'going', 'running', 'move', 'moved', 'went', 'moving', 'goes'}
#
#
# SYN --> survive
# SPA --> {'enduring', 'live', 'gone', 'living', 'going', 'survives', 'lives', 'last', 'went', 'lived', 'lasting', 'goes'}
#
#
# SYN --> belong
# SPA --> {'gone', 'going', 'went', 'belonged', 'goes'}
#
#
# SYN --> start
# SPA --> {'popping', 'started', 'gone', 'start', 'scratch', 'going', 'went', 'scratches', 'goes'}
#
#
# SYN --> blend
# SPA --> {'gone', 'blending', 'mixing', 'going', 'fused', 'intermixed', 'mixes', 'mixed', 'went', 'goes'}
#
#
# SYN --> fit
# SPA --> {'gone', 'going', 'fitting', 'went', 'scene', 'goes'}
#
#
# SYN --> rifle
# SPA --> {'went', 'going', 'gone', 'goes'}
#
#
# SYN --> plump
# SPA --> {'went', 'going', 'gone', 'goes'}
#
#
# SYN --> hale
# SPA --> {'whole', 'hale'}
#
#
# SYN --> solid
# SPA --> {'strongest', 'whole', 'solids', 'stronger', 'strong'}
#
#
# SYN --> wholly
# SPA --> {'wholly', 'whole', 'completely'}
#
#
# SYN --> back
# SPA --> {'back', 'rear', 'supported', 'supporting', 'backward', 'support'}
#
#
# SYN --> rear
# SPA --> {'nurturing', 'back', 'rear', 'reared', 'erected', 'raising', 'raised', 'rearing', 'parents'}
#
#
# SYN --> binding
# SPA --> {'cover', 'back'}
#
#
# SYN --> second
# SPA --> {'back', 'second'}
#
#
# SYN --> bet_on
# SPA --> {'back', 'game', 'staked', 'stake'}
#
#
# SYN --> delivery
# SPA --> {'livery', 'bringing'}
#
#
# SYN --> institute
# SPA --> {'brought', 'bring', 'brings', 'bringing'}
#
#
# SYN --> lend
# SPA --> {'brings', 'bringing', 'loans', 'contributing', 'bring', 'brought'}
#
#
# SYN --> fetch
# SPA --> {'brought', 'bring', 'brings', 'bringing'}
#
#
# SYN --> earth
# SPA --> {'worlds', 'earth', 'world', 'globes', 'globe', 'ground', 'earths'}
#
#
# SYN --> land
# SPA --> {'land', 'earth', 'landed', 'shore', 'lands', 'ground', 'soil', 'earths', 'landing'}
#
#
# SYN --> worldly_concern
# SPA --> {'world', 'earths', 'worlds', 'earth'}
#
#
# SYN --> ground
# SPA --> {'ground', 'earths', 'earth'}
#
#
# SYN --> ageless
# SPA --> {'eternal', 'unending', 'unceasing'}
#
#
# SYN --> endless
# SPA --> {'eternal', 'endless'}
#
#
# SYN --> find
# SPA --> {'felt', 'chanced', 'happens', 'happen', 'feel', 'finding', 'happened', 'chance', 'find', 'feelings', 'found', 'bump', 'feeling', 'chances'}
#
#
# SYN --> detect
# SPA --> {'finding', 'find', 'found', 'observe', 'discovered', 'observed'}
#
#
# SYN --> determine
# SPA --> {'checked', 'watched', 'setting', 'finding', 'find', 'learning', 'learned', 'seeing', 'mold', 'found', 'watching', 'check', 'influence', 'shapes', 'molded', 'sees', 'learn', 'influenced', 'watches', 'seen', 'shape', 'influences', 'watch'}
#
#
# SYN --> witness
# SPA --> {'seen', 'finding', 'find', 'found', 'seeing', 'witness', 'sees'}
#
#
# SYN --> line_up
# SPA --> {'finding', 'found', 'find'}
#
#
# SYN --> discover
# SPA --> {'discovered', 'finding', 'found', 'find'}
#
#
# SYN --> rule
# SPA --> {'ruled', 'finding', 'find', 'found', 'decreed', 'rule', 'rules'}
#
#
# SYN --> recover
# SPA --> {'retrieve', 'finding', 'find', 'recoup', 'found'}
#
#
# SYN --> find_oneself
# SPA --> {'finding', 'found', 'find'}
#
#
# SYN --> friend
# SPA --> {'friends', 'friend'}
#
#
# SYN --> ally
# SPA --> {'friends', 'friend'}
#
#
# SYN --> acquaintance
# SPA --> {'friends', 'friend'}
#
#
# SYN --> supporter
# SPA --> {'friends', 'champion', 'friend'}
#
#
# SYN --> therefore
# SPA --> {'thus', 'thence', 'therefore', 'hence'}
#
#
# SYN --> home
# SPA --> {'places', 'home', 'interior', 'place'}
#
#
# SYN --> dwelling
# SPA --> {'home', 'habitations'}
#
#
# SYN --> home_plate
# SPA --> {'plate', 'home'}
#
#
# SYN --> base
# SPA --> {'stands', 'home', 'stand', 'pedestal', 'base', 'humble', 'mean'}
#
#
# SYN --> family
# SPA --> {'fellowship', 'home', 'house', 'familys', 'household', 'houses', 'family'}
#
#
# SYN --> space
# SPA --> {'places', 'infinite', 'place', 'space'}
#
#
# SYN --> countless
# SPA --> {'infinite', 'unnumbered', 'countless'}
#
#
# SYN --> stopping_point
# SPA --> {'last', 'close', 'finish', 'closes'}
#
#
# SYN --> last
# SPA --> {'enduring', 'utmost', 'last', 'lasting', 'finally', 'lowest'}
#
#
# SYN --> death
# SPA --> {'last', 'deaths', 'dying', 'death'}
#
#
# SYN --> end
# SPA --> {'ended', 'ceasing', 'death', 'stop', 'deaths', 'finished', 'remnant', 'last', 'ends', 'finish', 'ending', 'destruction', 'stopping', 'cease', 'stopped', 'stops'}
#
#
# SYN --> concluding
# SPA --> {'last', 'final'}
#
#
# SYN --> final
# SPA --> {'last', 'final'}
#
#
# SYN --> long
# SPA --> {'long', 'longer'}
#
#
# SYN --> retentive
# SPA --> {'long', 'longer'}
#
#
# SYN --> farseeing
# SPA --> {'long', 'longer'}
#
#
# SYN --> doomed
# SPA --> {'lost', 'fated'}
#
#
# SYN --> lose
# SPA --> {'loses', 'losing', 'lost', 'lose'}
#
#
# SYN --> misplace
# SPA --> {'loses', 'losing', 'lost', 'lose'}
#
#
# SYN --> fall_back
# SPA --> {'loses', 'losing', 'lost', 'lose'}
#
#
# SYN --> miss
# SPA --> {'loses', 'losing', 'lost', 'lose', 'miss', 'escape', 'escaped', 'lack'}
#
#
# SYN --> confused
# SPA --> {'scattered', 'lost'}
#
#
# SYN --> helpless
# SPA --> {'lost', 'helpless'}
#
#
# SYN --> make
# SPA --> {'does', 'made', 'created', 'works', 'pretended', 'worked', 'getting', 'weeses', 'done', 'doing', 'create', 'makes', 'wrought', 'working', 'make', 'work', 'making'}
#
#
# SYN --> cause
# SPA --> {'does', 'made', 'causes', 'cause', 'reasons', 'done', 'doing', 'makes', 'reason', 'make', 'making'}
#
#
# SYN --> produce
# SPA --> {'made', 'created', 'makes', 'making', 'make', 'create'}
#
#
# SYN --> draw
# SPA --> {'cast', 'made', 'draws', 'draw', 'pulls', 'haul', 'getting', 'drawn', 'pull', 'makes', 'pulled', 'drew', 'make', 'making'}
#
#
# SYN --> create
# SPA --> {'made', 'created', 'makes', 'making', 'make', 'create'}
#
#
# SYN --> gain
# SPA --> {'made', 'winning', 'earned', 'gathered', 'gathering', 'gather', 'gains', 'gained', 'makes', 'cleared', 'clear', 'earnings', 'make', 'making'}
#
#
# SYN --> do
# SPA --> {'does', 'made', 'managed', 'coming', 'done', 'doing', 'comes', 'makes', 'perform', 'came', 'make', 'come', 'making'}
#
#
# SYN --> form
# SPA --> {'spring', 'springs', 'cast', 'made', 'sprang', 'pattern', 'strains', 'formed', 'patterns', 'shapes', 'shape', 'makes', 'form', 'sprung', 'strain', 'make', 'making'}
#
#
# SYN --> reach
# SPA --> {'reached', 'made', 'touches', 'reaching', 'gains', 'reach', 'touch', 'touched', 'stretch', 'makes', 'making', 'gained', 'make', 'reaches'}
#
#
# SYN --> construct
# SPA --> {'built', 'build', 'made', 'building', 'makes', 'make', 'making'}
#
#
# SYN --> name
# SPA --> {'name', 'figures', 'made', 'called', 'calls', 'named', 'makes', 'call', 'figure', 'names', 'calling', 'make', 'making'}
#
#
# SYN --> lay_down
# SPA --> {'makes', 'made', 'make', 'making'}
#
#
# SYN --> stool
# SPA --> {'makes', 'made', 'make', 'making'}
#
#
# SYN --> cook
# SPA --> {'prepared', 'made', 'cook', 'fixed', 'preparing', 'makes', 'ready', 'make', 'making'}
#
#
# SYN --> seduce
# SPA --> {'made', 'scored', 'makes', 'score', 'scores', 'make', 'making'}
#
#
# SYN --> passerby
# SPA --> {'passer', 'passerby', 'passers'}
#
#
# SYN --> passer
# SPA --> {'passer', 'passers'}
#
#
# SYN --> peace
# SPA --> {'repose', 'peace'}
#
#
# SYN --> picture
# SPA --> {'show', 'pictures', 'images', 'shown', 'pictured', 'showed', 'scene', 'picture', 'showing', 'image'}
#
#
# SYN --> painting
# SPA --> {'pictures', 'picture'}
#
#
# SYN --> mental_picture
# SPA --> {'pictures', 'picture'}
#
#
# SYN --> movie
# SPA --> {'pictures', 'picture'}
#
#
# SYN --> video
# SPA --> {'pictures', 'picture'}
#
#
# SYN --> word_picture
# SPA --> {'pictures', 'picture'}
#
#
# SYN --> photograph
# SPA --> {'pictures', 'exposure', 'photograph', 'photographs', 'snapped', 'shoots', 'picture', 'shot'}
#
#
# SYN --> visualize
# SPA --> {'figures', 'pictures', 'seen', 'images', 'fancy', 'figure', 'seeing', 'pictured', 'sees', 'picture', 'image'}
#
#
# SYN --> rest
# SPA --> {'breathed', 'breathe', 'rested', 'ease', 'resting', 'repose', 'rest', 'breathing', 'rests', 'sleep'}
#
#
# SYN --> repose
# SPA --> {'repose', 'quiet'}
#
#
# SYN --> rose
# SPA --> {'roses', 'rose'}
#
#
# SYN --> blush_wine
# SPA --> {'roses', 'rose'}
#
#
# SYN --> seance
# SPA --> {'sitting', 'session'}
#
#
# SYN --> sit
# SPA --> {'sits', 'sitting'}
#
#
# SYN --> sit_down
# SPA --> {'sits', 'sitting'}
#
#
# SYN --> model
# SPA --> {'modeled', 'sitting', 'model', 'pattern', 'patterns', 'molded', 'sits', 'example', 'moulds', 'mold', 'mould'}
#
#
# SYN --> ride
# SPA --> {'sitting', 'ride', 'sits', 'riding', 'rides', 'mounted', 'mount'}
#
#
# SYN --> baby-sit
# SPA --> {'sits', 'sitting'}
#
#
# SYN --> seat
# SPA --> {'seat', 'sitting', 'seats', 'places', 'sits', 'place'}
#
#
# SYN --> dirt
# SPA --> {'stains', 'filth', 'dirt', 'soil'}
#
#
# SYN --> soil
# SPA --> {'dirt', 'soil'}
#
#
# SYN --> dirty
# SPA --> {'dingy', 'filthy', 'soiling', 'soil', 'foul'}
#
#
# SYN --> sorrow
# SPA --> {'regret', 'sorrow', 'sorrows'}
#
#
# SYN --> grief
# SPA --> {'sorrow', 'sorrows', 'grief', 'griefs'}
#
#
# SYN --> sadness
# SPA --> {'sorrow', 'sorrows'}
#
#
# SYN --> grieve
# SPA --> {'sorrow', 'sorrows', 'grieved'}
#
#
# SYN --> supreme
# SPA --> {'supreme', 'supremer'}
#
#
# SYN --> sovereign
# SPA --> {'sovereign', 'supreme', 'supremer'}
#
#
# SYN --> there
# SPA --> {'there', 'thither', 'theres'}
#
#
# SYN --> done
# SPA --> {'done', 'through'}
#
#
# SYN --> tree
# SPA --> {'tree', 'trees'}
#
#
# SYN --> corner
# SPA --> {'boxes', 'tree', 'trees', 'corner'}
#
#
# SYN --> try
# SPA --> {'sought', 'essays', 'attempt', 'strains', 'strain', 'tried', 'seek', 'trying', 'essay'}
#
#
# SYN --> test
# SPA --> {'essays', 'prove', 'proved', 'trials', 'runs', 'trial', 'tried', 'trying', 'essay'}
#
#
# SYN --> judge
# SPA --> {'justice', 'judging', 'judged', 'judge', 'tried', 'trying', 'judges'}
#
#
# SYN --> sample
# SPA --> {'taste', 'tastes', 'tried', 'tasting', 'trying'}
#
#
# SYN --> hear
# SPA --> {'heard', 'hearing', 'hear', 'tried', 'trying'}
#
#
# SYN --> try_on
# SPA --> {'tried', 'trying'}
#
#
# SYN --> bend
# SPA --> {'bent', 'turns', 'turn', 'bending', 'bends', 'crook'}
#
#
# SYN --> turn
# SPA --> {'turns', 'turning', 'turn', 'round', 'grew', 'turned', 'release', 'play', 'grow', 'growing', 'grown'}
#
#
# SYN --> turning
# SPA --> {'turns', 'turning', 'turn'}
#
#
# SYN --> twist
# SPA --> {'turns', 'turning', 'turn', 'twisted', 'turned', 'pervert', 'perverted'}
#
#
# SYN --> act
# SPA --> {'does', 'bits', 'turns', 'playing', 'deeds', 'turn', 'numbers', 'deed', 'acted', 'done', 'representing', 'doing', 'played', 'move', 'moved', 'play', 'acts', 'moving', 'acting'}
#
#
# SYN --> change_state
# SPA --> {'turns', 'turning', 'turn', 'turned'}
#
#
# SYN --> change_by_reversal
# SPA --> {'turns', 'turning', 'turn', 'turned'}
#
#
# SYN --> plow
# SPA --> {'turns', 'turning', 'turn', 'ploughs', 'turned', 'plow'}
#
#
# SYN --> flex
# SPA --> {'bent', 'turns', 'turning', 'turn', 'twisted', 'turned', 'bending', 'bends'}
#
#
# SYN --> call_on
# SPA --> {'turns', 'turning', 'turn', 'turned'}
#
#
# SYN --> sour
# SPA --> {'turns', 'turning', 'turn', 'worked', 'turned', 'wrought', 'working', 'works', 'work'}
#
#
# SYN --> under
# SPA --> {'below', 'under'}
#
#
# SYN --> white
# SPA --> {'white', 'whiter', 'whiteness', 'snowy'}
#
#
# SYN --> whiten
# SPA --> {'white', 'whiteness'}
#
#
# SYN --> blank
# SPA --> {'white', 'dummy', 'whiter', 'clean'}
#
#
# SYN --> ashen
# SPA --> {'white', 'whiter'}
#
#
# SYN --> withdraw
# SPA --> {'withdrawing', 'draws', 'withdraws', 'drawn', 'withdrew', 'drew', 'draw'}
#
#
# SYN --> retire
# SPA --> {'withdrew', 'withdrawing', 'withdraws'}
#
#
# SYN --> disengage
# SPA --> {'withdrew', 'withdrawing', 'withdraws'}
#
#
# SYN --> recall
# SPA --> {'withdrew', 'withdrawing', 'withdraws'}
#
#
# SYN --> swallow
# SPA --> {'swallowed', 'withdrawing', 'drinks', 'withdraws', 'swallows', 'withdrew', 'drink', 'swallow'}
#
#
# SYN --> seclude
# SPA --> {'withdrew', 'withdrawing', 'withdraws'}
#
#
# SYN --> adjourn
# SPA --> {'withdrew', 'withdrawing', 'withdraws'}
#
#
# SYN --> bow_out
# SPA --> {'withdrew', 'withdrawing', 'withdraws'}
#
#
# SYN --> retreat
# SPA --> {'withdrew', 'withdrawing', 'withdraws', 'crawfishs'}
#
#
# SYN --> write
# SPA --> {'save', 'saved', 'savings', 'writes', 'saving', 'written', 'pent', 'writing', 'write', 'wrote'}
#
#
# SYN --> publish
# SPA --> {'published', 'writes', 'written', 'release', 'writing', 'publishing', 'write', 'wrote'}
#
#
# SYN --> compose
# SPA --> {'writes', 'written', 'writing', 'write', 'wrote'}
#
#
# SYN --> spell
# SPA --> {'writes', 'spelled', 'written', 'writing', 'write', 'wrote'}
#
#
# SYN --> old_age
# SPA --> {'years', 'ages'}
#
#
# SYN --> long_time
# SPA --> {'years', 'ages'}
#
#
# SYN --> days
# SPA --> {'years', 'days'}
#
#
# SYN --> year
# SPA --> {'years', 'year'}
#
#
# SYN --> class
# SPA --> {'course', 'familys', 'years', 'year', 'form', 'family'}
#
#
# SYN --> subsequently
# SPA --> {'after', 'afterwards', 'afterward', 'later'}
#
#
# SYN --> arm
# SPA --> {'arms', 'limbs', 'girded', 'branches'}
#
#
# SYN --> branch
# SPA --> {'legs', 'separate', 'fork', 'arms', 'branches'}
#
#
# SYN --> away
# SPA --> {'outside', 'away', 'forth'}
#
#
# SYN --> aside
# SPA --> {'away', 'apart'}
#
#
# SYN --> off
# SPA --> {'away', 'turned'}
#
#
# SYN --> earlier
# SPA --> {'earliest', 'earlier', 'before'}
#
#
# SYN --> ahead
# SPA --> {'ahead', 'leading', 'forward', 'before'}
#
#
# SYN --> bite
# SPA --> {'burn', 'bitten', 'burning', 'stung', 'burns', 'burnt', 'bite', 'burned', 'bites'}
#
#
# SYN --> morsel
# SPA --> {'bits', 'bite', 'bites'}
#
#
# SYN --> sting
# SPA --> {'stung', 'bite', 'bitten', 'pricked', 'bites'}
#
#
# SYN --> pungency
# SPA --> {'bite', 'bites'}
#
#
# SYN --> shed_blood
# SPA --> {'bleeding', 'bled'}
#
#
# SYN --> bleed
# SPA --> {'bleeding', 'bled'}
#
#
# SYN --> city
# SPA --> {'city', 'cities', 'metropolis'}
#
#
# SYN --> crying
# SPA --> {'weeping', 'crying', 'tears', 'grosser'}
#
#
# SYN --> cry
# SPA --> {'cries', 'crying', 'wept', 'cried', 'calls', 'shouts', 'call', 'weeping', 'weep', 'yells'}
#
#
# SYN --> war_cry
# SPA --> {'crying', 'cries'}
#
#
# SYN --> shout
# SPA --> {'cries', 'crying', 'called', 'cried', 'calls', 'yelled', 'shouts', 'call', 'shouting', 'screams', 'calling', 'yells', 'scream'}
#
#
# SYN --> exclaim
# SPA --> {'cries', 'crying', 'cried', 'shouts', 'shouting'}
#
#
# SYN --> daughter
# SPA --> {'daughters', 'girl', 'daughter', 'girls'}
#
#
# SYN --> effect
# SPA --> {'burden', 'force', 'core', 'effect', 'essence', 'effects', 'forces'}
#
#
# SYN --> face
# SPA --> {'face', 'faces', 'faced', 'facing'}
#
#
# SYN --> expression
# SPA --> {'look', 'face', 'faces', 'looks'}
#
#
# SYN --> side
# SPA --> {'sides', 'sided', 'siding', 'face', 'faces', 'side'}
#
#
# SYN --> grimace
# SPA --> {'face', 'faces'}
#
#
# SYN --> font
# SPA --> {'face', 'faces', 'case', 'cases'}
#
#
# SYN --> boldness
# SPA --> {'face', 'nerves', 'faces', 'cheeks'}
#
#
# SYN --> confront
# SPA --> {'faced', 'presented', 'facing', 'face', 'faces'}
#
#
# SYN --> boom
# SPA --> {'flourished', 'flourish', 'roaring', 'roar', 'dined', 'thunder'}
#
#
# SYN --> thrive
# SPA --> {'prospering', 'flourished', 'prosper', 'flourish'}
#
#
# SYN --> brandish
# SPA --> {'waves', 'flourished', 'flourish', 'brandishing', 'waving', 'waved'}
#
#
# SYN --> free
# SPA --> {'free', 'unloosened', 'release', 'liberal', 'freer', 'loose', 'discharge'}
#
#
# SYN --> rid
# SPA --> {'free', 'riding', 'rides'}
#
#
# SYN --> dislodge
# SPA --> {'bump', 'free'}
#
#
# SYN --> exempt
# SPA --> {'free', 'exempted'}
#
#
# SYN --> release
# SPA --> {'free', 'release', 'resign', 'discharge'}
#
#
# SYN --> unblock
# SPA --> {'free', 'release'}
#
#
# SYN --> complimentary
# SPA --> {'free', 'freer'}
#
#
# SYN --> detached
# SPA --> {'free', 'freer'}
#
#
# SYN --> spare
# SPA --> {'save', 'trim', 'saved', 'savings', 'free', 'saving', 'freer'}
#
#
# SYN --> barren
# SPA --> {'free', 'innocent', 'waste', 'barren', 'wastes', 'freer'}
#
#
# SYN --> loose
# SPA --> {'slack', 'free', 'open', 'loose'}
#
#
# SYN --> garden
# SPA --> {'garden', 'gardens'}
#
#
# SYN --> eden
# SPA --> {'eden', 'heavens', 'paradise', 'nirvana', 'heaven'}
#
#
# SYN --> heaven
# SPA --> {'heavens', 'heaven'}
#
#
# SYN --> kind
# SPA --> {'sorts', 'form', 'sort', 'kind'}
#
#
# SYN --> kiss
# SPA --> {'kissed', 'kiss', 'kisses', 'kissing'}
#
#
# SYN --> snog
# SPA --> {'kissed', 'kiss', 'kisses', 'kissing'}
#
#
# SYN --> lover
# SPA --> {'lover', 'lovers'}
#
#
# SYN --> fan
# SPA --> {'lover', 'lovers'}
#
#
# SYN --> mary
# SPA --> {'marys', 'mary'}
#
#
# SYN --> mean
# SPA --> {'means', 'meant', 'mean', 'meaning', 'tight'}
#
#
# SYN --> entail
# SPA --> {'meant', 'means', 'mean', 'meaning'}
#
#
# SYN --> think_of
# SPA --> {'meant', 'means', 'mean', 'meaning'}
#
#
# SYN --> meet
# SPA --> {'playing', 'fill', 'seen', 'meet', 'received', 'gathered', 'gathering', 'gather', 'receive', 'meetings', 'match', 'played', 'play', 'filled', 'fulfill', 'seeing', 'fitting', 'sees', 'assembled', 'fills'}
#
#
# SYN --> converge
# SPA --> {'meetings', 'meet'}
#
#
# SYN --> touch
# SPA --> {'trace', 'meet', 'speck', 'touches', 'stir', 'disturbed', 'feelings', 'touch', 'meetings', 'touched', 'ghosts', 'stirred', 'specks', 'mites', 'stirring', 'feeling', 'adjoined', 'ghost'}
#
#
# SYN --> fitting
# SPA --> {'fitting', 'meet'}
#
#
# SYN --> nose
# SPA --> {'nosing', 'nose'}
#
#
# SYN --> intrude
# SPA --> {'nosing', 'nose'}
#
#
# SYN --> scent
# SPA --> {'nosing', 'winds', 'winding', 'wind', 'nose', 'wound'}
#
#
# SYN --> nuzzle
# SPA --> {'nosing', 'nose'}
#
#
# SYN --> once
# SPA --> {'once', 'erstwhile'}
#
#
# SYN --> one
# SPA --> {'aner', 'single', 'ones'}
#
#
# SYN --> complete
# SPA --> {'ended', 'over', 'nail', 'concluded', 'complete', 'finished', 'finish', 'nailed', 'nails'}
#
#
# SYN --> tax_return
# SPA --> {'return', 'returns'}
#
#
# SYN --> return
# SPA --> {'takes', 'returning', 'yield', 'returns', 'return', 'take', 'returned'}
#
#
# SYN --> restitution
# SPA --> {'return', 'returns'}
#
#
# SYN --> recurrence
# SPA --> {'return', 'returns'}
#
#
# SYN --> rejoinder
# SPA --> {'return', 'returns'}
#
#
# SYN --> return_key
# SPA --> {'return', 'returns'}
#
#
# SYN --> reappearance
# SPA --> {'return', 'returns'}
#
#
# SYN --> render
# SPA --> {'give', 'yielded', 'returning', 'given', 'yield', 'delivers', 'gives', 'returns', 'return', 'submit', 'giving', 'returned', 'gave'}
#
#
# SYN --> revert
# SPA --> {'return', 'returned', 'returning', 'returns'}
#
#
# SYN --> hark_back
# SPA --> {'return', 'returned', 'returning', 'returns'}
#
#
# SYN --> retort
# SPA --> {'returning', 'returns', 'return', 'repaid', 'returned'}
#
#
# SYN --> come_back
# SPA --> {'return', 'returned', 'returning', 'returns'}
#
#
# SYN --> refund
# SPA --> {'returning', 'returns', 'return', 'repaid', 'returned'}
#
#
# SYN --> reelect
# SPA --> {'return', 'returned', 'returning', 'returns'}
#
#
# SYN --> fall
# SPA --> {'pass', 'light', 'fallen', 'shine', 'returning', 'return', 'strike', 'striking', 'settle', 'comes', 'shone', 'shines', 'came', 'passing', 'come', 'autumn', 'shining', 'lighted', 'passed', 'descend', 'falling', 'fell', 'pins', 'returns', 'lights', 'coming', 'fall', 'struck', 'passes', 'falls', 'returned'}
#
#
# SYN --> gown
# SPA --> {'robe', 'gown', 'gowns'}
#
#
# SYN --> clothe
# SPA --> {'clothes', 'clothing', 'cloaks', 'clothe', 'robe', 'cloak'}
#
#
# SYN --> running
# SPA --> {'running', 'working'}
#
#
# SYN --> track
# SPA --> {'track', 'running', 'tracks'}
#
#
# SYN --> scat
# SPA --> {'runs', 'scates', 'running', 'escape', 'escaped'}
#
#
# SYN --> operate
# SPA --> {'running', 'runs', 'control'}
#
#
# SYN --> range
# SPA --> {'chain', 'chains', 'runs', 'reach', 'running', 'reaches'}
#
#
# SYN --> campaign
# SPA --> {'causes', 'runs', 'running', 'drive', 'cause', 'crusade'}
#
#
# SYN --> play
# SPA --> {'drama', 'playing', 'runs', 'running', 'play', 'played', 'toys'}
#
#
# SYN --> tend
# SPA --> {'runs', 'leaning', 'tend', 'running', 'leaned'}
#
#
# SYN --> guide
# SPA --> {'pass', 'draws', 'passed', 'runs', 'drawn', 'running', 'passes', 'steer', 'passing', 'drew', 'draw'}
#
#
# SYN --> ply
# SPA --> {'running', 'runs', 'plied'}
#
#
# SYN --> hunt
# SPA --> {'hunting', 'runs', 'running', 'hunted', 'hunt'}
#
#
# SYN --> race
# SPA --> {'rushing', 'races', 'rushed', 'runs', 'running', 'race'}
#
#
# SYN --> melt
# SPA --> {'running', 'runs', 'disappear', 'disappeared'}
#
#
# SYN --> ladder
# SPA --> {'ladder', 'running', 'runs'}
#
#
# SYN --> sludge
# SPA --> {'slimes', 'slime'}
#
#
# SYN --> slime
# SPA --> {'slimes', 'slime'}
#
#
# SYN --> reduce
# SPA --> {'slimes', 'tightened', 'trim', 'thin'}
#
#
# SYN --> smell
# SPA --> {'sense', 'smell', 'smelling', 'smells', 'senses', 'smelled'}
#
#
# SYN --> smack
# SPA --> {'smell', 'smelling', 'smells', 'taste', 'tastes', 'smelled', 'tasting'}
#
#
# SYN --> consolation
# SPA --> {'consolation', 'solace', 'comfort'}
#
#
# SYN --> comfort
# SPA --> {'solace', 'comfort', 'soothed', 'ease'}
#
#
# SYN --> approximately
# SPA --> {'around', 'some', 'about'}
#
#
# SYN --> spring
# SPA --> {'spring', 'springtime', 'springs', 'sprang', 'fountain', 'sprung'}
#
#
# SYN --> leap
# SPA --> {'spring', 'springs', 'jumped', 'leapt', 'leaps', 'bound', 'leaped', 'leap'}
#
#
# SYN --> jump
# SPA --> {'spring', 'springs', 'jumped', 'leapt', 'skipped', 'sprang', 'leaps', 'skipping', 'sprung', 'bound', 'leaped', 'leap'}
#
#
# SYN --> bounce
# SPA --> {'spring', 'springs', 'sprang', 'sprung', 'bound'}
#
#
# SYN --> sprout
# SPA --> {'sprout', 'stock'}
#
#
# SYN --> shoot
# SPA --> {'sprout', 'shoots', 'shot'}
#
#
# SYN --> stand
# SPA --> {'stood', 'stand', 'standing', 'stands'}
#
#
# SYN --> rack
# SPA --> {'wheels', 'wheel', 'stand', 'stands'}
#
#
# SYN --> point_of_view
# SPA --> {'stands', 'stand'}
#
#
# SYN --> stall
# SPA --> {'stands', 'stand', 'stall'}
#
#
# SYN --> bandstand
# SPA --> {'stands', 'stand'}
#
#
# SYN --> digest
# SPA --> {'enduring', 'suffer', 'stands', 'born', 'brook', 'suffers', 'supported', 'stand', 'supporting', 'suffering', 'bear', 'bearing', 'stood', 'borne', 'support', 'standing', 'bore'}
#
#
# SYN --> resist
# SPA --> {'stands', 'refused', 'refusing', 'stand', 'reject', 'rejected', 'withstood', 'stood', 'standing'}
#
#
# SYN --> force
# SPA --> {'forced', 'driven', 'forcing', 'drove', 'force', 'strength', 'thrust', 'drive', 'forces', 'driving'}
#
#
# SYN --> forte
# SPA --> {'strength', 'loud', 'louder'}
#
#
# SYN --> thing
# SPA --> {'thing', 'things'}
#
#
# SYN --> matter
# SPA --> {'matters', 'matter', 'thing', 'things', 'affairs'}
#
#
# SYN --> tire
# SPA --> {'worn', 'tired', 'wore', 'wear', 'wearing', 'tiring', 'weary', 'pall'}
#
#
# SYN --> run_down
# SPA --> {'exhaust', 'exhausted', 'saps', 'tired', 'tiring'}
#
#
# SYN --> bore
# SPA --> {'bores', 'tired', 'dullards', 'tiring', 'bored', 'bore'}
#
#
# SYN --> banal
# SPA --> {'tired', 'stock'}
#
#
# SYN --> nothingness
# SPA --> {'voids', 'nothingness', 'void'}
#
#
# SYN --> void
# SPA --> {'voids', 'void'}
#
#
# SYN --> invalidate
# SPA --> {'voids', 'avoided', 'void'}
#
#
# SYN --> evacuate
# SPA --> {'voids', 'void', 'emptied', 'empty'}
#
#
# SYN --> wrath
# SPA --> {'anger', 'wrath'}
#
#
# SYN --> ask
# SPA --> {'asked', 'inquiring', 'asking'}
#
#
# SYN --> bearing
# SPA --> {'bearing', 'presence'}
#
#
# SYN --> carriage
# SPA --> {'bearing', 'carriage'}
#
#
# SYN --> charge
# SPA --> {'accused', 'burden', 'burdened', 'point', 'leveled', 'bearing', 'bill', 'pointed', 'points', 'pointing', 'charged', 'charge'}
#
#
# SYN --> wear
# SPA --> {'enduring', 'born', 'worn', 'wore', 'bear', 'bearing', 'wear', 'wearing', 'borne', 'bore'}
#
#
# SYN --> behave
# SPA --> {'carrying', 'born', 'carry', 'bear', 'bearing', 'conduct', 'carried', 'borne', 'conducted', 'bore'}
#
#
# SYN --> have_a_bun_in_the_oven
# SPA --> {'carrying', 'born', 'carry', 'bear', 'bearing', 'carried', 'borne', 'bore'}
#
#
# SYN --> beg
# SPA --> {'praying', 'begged', 'prayed', 'pray'}
#
#
# SYN --> bluff
# SPA --> {'bluffs', 'sheer', 'bold', 'bluff'}
#
#
# SYN --> body
# SPA --> {'bodies', 'bodys', 'body'}
#
#
# SYN --> torso
# SPA --> {'bodies', 'body', 'trunk', 'bodys', 'trunks'}
#
#
# SYN --> consistency
# SPA --> {'bodies', 'bodys', 'body'}
#
#
# SYN --> soundbox
# SPA --> {'bodies', 'bodys', 'body'}
#
#
# SYN --> call
# SPA --> {'ring', 'called', 'rang', 'calls', 'rings', 'call', 'rung', 'ringing', 'claims', 'telephones', 'claim', 'calling'}
#
#
# SYN --> visit
# SPA --> {'seen', 'called', 'calls', 'call', 'seeing', 'visit', 'sees', 'calling'}
#
#
# SYN --> address
# SPA --> {'destination', 'speeches', 'spoke', 'called', 'direct', 'speech', 'calls', 'speak', 'call', 'calling', 'speaking'}
#
#
# SYN --> bid
# SPA --> {'bade', 'tender', 'called', 'calls', 'play', 'call', 'press', 'calling', 'bidding'}
#
#
# SYN --> predict
# SPA --> {'called', 'promised', 'calls', 'prognosticate', 'call', 'promise', 'calling', 'promising'}
#
#
# SYN --> opportunity
# SPA --> {'chances', 'chance'}
#
#
# SYN --> chance
# SPA --> {'chanced', 'chances', 'chance'}
#
#
# SYN --> probability
# SPA --> {'chances', 'chance'}
#
#
# SYN --> prospect
# SPA --> {'prospect', 'chances', 'chance'}
#
#
# SYN --> gamble
# SPA --> {'hazards', 'chanced', 'chance', 'adventures', 'chances'}
#
#
# SYN --> casual
# SPA --> {'daily', 'passing', 'chance'}
#
#
# SYN --> gyrate
# SPA --> {'coiled', 'spiral'}
#
#
# SYN --> coil
# SPA --> {'coiled', 'curl', 'roll', 'loop', 'spiral', 'curled'}
#
#
# SYN --> complain
# SPA --> {'kick', 'complained', 'complain', 'kicking', 'plain'}
#
#
# SYN --> craft
# SPA --> {'cunning', 'guile', 'trade'}
#
#
# SYN --> daniel
# SPA --> {'daniels', 'daniel'}
#
#
# SYN --> dead
# SPA --> {'dead', 'drained', 'numb', 'idle'}
#
#
# SYN --> all_in
# SPA --> {'dead', 'beat'}
#
#
# SYN --> abruptly
# SPA --> {'dead', 'short', 'abruptly', 'suddenly'}
#
#
# SYN --> absolutely
# SPA --> {'dead', 'utterly'}
#
#
# SYN --> contemn
# SPA --> {'despised', 'scorn', 'disdaining'}
#
#
# SYN --> despised
# SPA --> {'despised', 'hated'}
#
#
# SYN --> drove
# SPA --> {'swarms', 'drove', 'hordes'}
#
#
# SYN --> repel
# SPA --> {'driven', 'drove', 'repulse', 'repel', 'drive', 'driving'}
#
#
# SYN --> tug
# SPA --> {'driven', 'pushing', 'drove', 'labors', 'push', 'labor', 'drive', 'driving'}
#
#
# SYN --> embitter
# SPA --> {'envenomed', 'embittering'}
#
#
# SYN --> prostitute
# SPA --> {'whores', 'cocotte', 'harlot'}
#
#
# SYN --> hate
# SPA --> {'hating', 'hatred', 'hate', 'hated'}
#
#
# SYN --> hat
# SPA --> {'hating', 'hats', 'hated'}
#
#
# SYN --> award
# SPA --> {'presented', 'honors', 'grants', 'grant', 'honor'}
#
#
# SYN --> honor
# SPA --> {'honors', 'honored', 'purity', 'honor'}
#
#
# SYN --> respect
# SPA --> {'respect', 'honors', 'values', 'prize', 'prized', 'honored', 'regard', 'honor', 'observe', 'observed'}
#
#
# SYN --> husband
# SPA --> {'husband', 'husbands'}
#
#
# SYN --> conserve
# SPA --> {'husband', 'husbands', 'preserve'}
#
#
# SYN --> rather
# SPA --> {'rather', 'instead'}
#
#
# SYN --> entire
# SPA --> {'full', 'intact', 'fuller'}
#
#
# SYN --> fair
# SPA --> {'fair', 'just', 'fairer'}
#
#
# SYN --> merely
# SPA --> {'merely', 'only', 'just'}
#
#
# SYN --> barely
# SPA --> {'scarcely', 'scarce', 'just'}
#
#
# SYN --> know
# SPA --> {'live', 'living', 'lives', 'knew', 'knowing', 'knows', 'known', 'lived', 'know'}
#
#
# SYN --> acknowledge
# SPA --> {'knew', 'knowing', 'knows', 'known', 'know'}
#
#
# SYN --> memorize
# SPA --> {'learning', 'learned', 'memorized', 'learn', 'memorize'}
#
#
# SYN --> teach
# SPA --> {'learning', 'learned', 'learn', 'taught'}
#
#
# SYN --> erudite
# SPA --> {'erudite', 'learned'}
#
#
# SYN --> knowing
# SPA --> {'knowing', 'learned', 'wiser', 'wisest', 'wise'}
#
#
# SYN --> letter
# SPA --> {'letters', 'letter'}
#
#
# SYN --> lie
# SPA --> {'rested', 'lies', 'lied', 'resting', 'rest', 'lying', 'rests'}
#
#
# SYN --> dwell
# SPA --> {'lies', 'lied', 'dwell', 'lying'}
#
#
# SYN --> lie_down
# SPA --> {'lies', 'lied', 'lying'}
#
#
# SYN --> be_active
# SPA --> {'moving', 'move', 'moved'}
#
#
# SYN --> affect
# SPA --> {'touches', 'touch', 'touched', 'strike', 'striking', 'move', 'moved', 'struck', 'moving'}
#
#
# SYN --> motivate
# SPA --> {'moving', 'move', 'moved'}
#
#
# SYN --> moved
# SPA --> {'touched', 'stirred', 'moved'}
#
#
# SYN --> bare
# SPA --> {'bare', 'bared', 'naked', 'stripped', 'desolate', 'barren', 'simple', 'mere'}
#
#
# SYN --> following
# SPA --> {'followers', 'next', 'following'}
#
#
# SYN --> future
# SPA --> {'next', 'future', 'hereafter'}
#
#
# SYN --> nothing
# SPA --> {'aught', 'nothing', 'naughts'}
#
#
# SYN --> lone
# SPA --> {'lonely', 'only', 'solitary'}
#
#
# SYN --> alone
# SPA --> {'lonely', 'alone', 'only', 'solitary'}
#
#
# SYN --> entirely
# SPA --> {'alone', 'only'}
#
#
# SYN --> parasite
# SPA --> {'parasites', 'parasite'}
#
#
# SYN --> leech
# SPA --> {'parasites', 'parasite'}
#
#
# SYN --> fix
# SPA --> {'prepared', 'setting', 'fixed', 'preparing', 'hole', 'ready'}
#
#
# SYN --> prepare
# SPA --> {'preparing', 'trains', 'prepared', 'train'}
#
#
# SYN --> organize
# SPA --> {'preparing', 'prepared', 'devised'}
#
#
# SYN --> train
# SPA --> {'prepared', 'railing', 'preparing', 'trains', 'train'}
#
#
# SYN --> individual
# SPA --> {'private', 'single'}
#
#
# SYN --> secret
# SPA --> {'private', 'secret', 'secrets'}
#
#
# SYN --> prove
# SPA --> {'show', 'prove', 'shown', 'showed', 'proved', 'showing', 'demonstrating'}
#
#
# SYN --> testify
# SPA --> {'show', 'prove', 'shown', 'showed', 'proved', 'showing'}
#
#
# SYN --> rise
# SPA --> {'ascending', 'rise', 'arises', 'proved', 'climbed', 'lifted', 'rose', 'lift', 'lifting', 'rear', 'reared', 'rises', 'rising', 'arise', 'arose', 'rearing', 'climb', 'lifts', 'jumped', 'prove', 'ascended'}
#
#
# SYN --> raise
# SPA --> {'lifts', 'lift', 'rise', 'lifting', 'prove', 'rear', 'reared', 'rises', 'lifted', 'raising', 'raised', 'erected', 'evoked', 'stir', 'rearing', 'stirred', 'stirring', 'proved'}
#
#
# SYN --> pursuit
# SPA --> {'chases', 'chase', 'pursuit', 'quest', 'following'}
#
#
# SYN --> pastime
# SPA --> {'pursuit', 'interest'}
#
#
# SYN --> group
# SPA --> {'radical', 'radicals', 'group'}
#
#
# SYN --> free_radical
# SPA --> {'radical', 'radicals'}
#
#
# SYN --> radical
# SPA --> {'radical', 'radicals'}
#
#
# SYN --> root
# SPA --> {'roots', 'radicals', 'radical', 'root', 'themes', 'base', 'rooted', 'theme'}
#
#
# SYN --> rebuff
# SPA --> {'slight', 'repulse', 'repel'}
#
#
# SYN --> revenge
# SPA --> {'avenge', 'revenge', 'avenged', 'revenged', 'avenging'}
#
#
# SYN --> shot
# SPA --> {'shaft', 'cracks', 'crack', 'slam', 'shot'}
#
#
# SYN --> stroke
# SPA --> {'strokes', 'shot'}
#
#
# SYN --> scene
# SPA --> {'scene', 'view', 'shot'}
#
#
# SYN --> nip
# SPA --> {'zest', 'shot'}
#
#
# SYN --> guess
# SPA --> {'hazards', 'shot', 'pretended'}
#
#
# SYN --> blast
# SPA --> {'shell', 'blast', 'shells', 'blasted', 'shoots', 'shot'}
#
#
# SYN --> dart
# SPA --> {'flash', 'shoots', 'flashes', 'shot'}
#
#
# SYN --> tear
# SPA --> {'tore', 'tears', 'snapped', 'rupturing', 'shoots', 'shot', 'bust', 'charged', 'torn', 'charge'}
#
#
# SYN --> inject
# SPA --> {'shoots', 'shot'}
#
#
# SYN --> fritter
# SPA --> {'fool', 'fools', 'fooled', 'shoots', 'shot'}
#
#
# SYN --> changeable
# SPA --> {'shot', 'changeable'}
#
#
# SYN --> screening
# SPA --> {'showing', 'viewing'}
#
#
# SYN --> display
# SPA --> {'show', 'showing'}
#
#
# SYN --> show
# SPA --> {'show', 'presented', 'shown', 'showed', 'showing', 'demonstrating'}
#
#
# SYN --> express
# ...
#
#
# SYN --> behold
# SPA --> {'behold', 'beholding', 'beheld'}
#
#
# SYN --> dim
# SPA --> {'vague', 'faint', 'shadowy', 'fainter'}
#
#
# SYN --> hearing
# SPA --> {'hearing', 'audience'}
#
#
# SYN --> stretch
# SPA --> {'extends', 'stretch'}
#
#
# SYN --> check_mark
# SPA --> {'check', 'tick'}
#
#
# SYN --> mystic
# SPA --> {'mystical', 'mystic'}
#
#
# SYN --> pioneer
# SPA --> {'pioneers', 'pioneer'}
#
#
# SYN --> initiate
# SPA --> {'pioneers', 'pioneer'}
#
#
# SYN --> request
# SPA --> {'asking', 'quest'}
#
#
# SYN --> dismissal
# SPA --> {'firing', 'release', 'discharge'}
#
#
# SYN --> throng
# SPA --> {'thronged', 'james'}
#
#
# SYN --> dancing
# SPA --> {'dance', 'dances', 'dancing'}
#
#
# SYN --> gather
# SPA --> {'gathered', 'gathering', 'gather', 'collecting'}
#
#
# SYN --> accumulate
# SPA --> {'gathered', 'gathering', 'gather'}
#
#
# SYN --> husk
# SPA --> {'shells', 'shell'}
#
#
# SYN --> abuse
# SPA --> {'shouts', 'insult', 'shouting'}
#
#
# SYN --> finish
# SPA --> {'finish', 'destination', 'goal', 'finished'}
#
#
# SYN --> material
# SPA --> {'stuff', 'material'}
#
#
# SYN --> fagot
# SPA --> {'queens', 'queer'}
#
#
# SYN --> surely
# SPA --> {'surely', 'certainly', 'sure'}
#
#
# SYN --> teem
# SPA --> {'swarmed', 'swarms'}
#
#
# SYN --> liar
# SPA --> {'liar', 'liars'}
#
#
# SYN --> distorted
# SPA --> {'twisted', 'perverted'}
#
#
# SYN --> butterfly
# SPA --> {'butterfly', 'butterflies'}
#
#
# SYN --> chat_up
# SPA --> {'butterfly', 'romance', 'butterflies'}
#
#
# SYN --> crushed_leather
# SPA --> {'crushes', 'crush'}
#
#
# SYN --> puppy_love
# SPA --> {'crushes', 'crush'}
#
#
# SYN --> decoration
# SPA --> {'palms', 'ribbons'}
#
#
# SYN --> anguish
# SPA --> {'anguish', 'torture'}
#
#
# SYN --> flap
# SPA --> {'flap', 'flapping', 'fluttering', 'flutterings'}
#
#
# SYN --> dither
# SPA --> {'flap', 'flapping'}
#
#
# SYN --> hood
# SPA --> {'hooded', 'hoodlums'}
#
#
# SYN --> sidetrack
# SPA --> {'departed', 'departing', 'straggling'}
#
#
# SYN --> sprawl
# SPA --> {'sprawls', 'straggling'}
#
#
# SYN --> previous
# SPA --> {'older', 'previous'}
#
#
# SYN --> willow
# SPA --> {'willows', 'willow'}
#
#
# SYN --> breeze
# SPA --> {'breeze', 'breezes'}
#
#
# SYN --> cinch
# SPA --> {'breeze', 'picnic', 'breezes'}
#
#
# SYN --> less
# SPA --> {'lesser', 'less'}
#
#
# SYN --> flood
# SPA --> {'torrent', 'flood'}
#
#
# SYN --> aftermath
# SPA --> {'wakes', 'wake'}
#
#
# SYN --> wake_island
# SPA --> {'wakes', 'wake'}
#
#
# SYN --> awaken
# SPA --> {'wakes', 'wakens', 'waking', 'woke', 'awaken', 'wake'}
#
#
# SYN --> worship
# SPA --> {'worshipped', 'worshipping', 'worship'}
#
#
# SYN --> idolize
# SPA --> {'worshipped', 'worshipping', 'worship'}
#
#
# SYN --> crevice
# SPA --> {'cracks', 'crack'}
#
#
# SYN --> wisecrack
# SPA --> {'cracks', 'crack'}
#
#
# SYN --> snap
# SPA --> {'snapped', 'cracks', 'crack'}
#
#
# SYN --> break_through
# SPA --> {'cracks', 'crack'}
#
#
# SYN --> eddy
# SPA --> {'eddy', 'whirling', 'whirls', 'whirled'}
#
#
# SYN --> phase
# SPA --> {'form', 'stage'}
#
#
# SYN --> mannequin
# SPA --> {'model', 'form'}
#
#
# SYN --> imprint
# SPA --> {'formed', 'form'}
#
#
# SYN --> picking
# SPA --> {'picking', 'picks'}
#
#
# SYN --> peck
# SPA --> {'picking', 'picks'}
#
#
# SYN --> peg
# SPA --> {'pins', 'legs'}
#
#
# SYN --> reign
# SPA --> {'sovereignty', 'reigned', 'reign'}
#
#
# SYN --> suggest
# SPA --> {'evoked', 'intimate'}
#
#
# SYN --> minerva
# SPA --> {'minervas', 'minerva'}
#
#
# SYN --> desegregate
# SPA --> {'mixes', 'mixed', 'mixing'}
#
#
# SYN --> mix
# SPA --> {'mingled', 'mixing', 'mixes', 'mixed', 'mingling'}
#
#
# SYN --> assorted
# SPA --> {'mixed', 'sundry', 'various'}
#
#
# SYN --> potato
# SPA --> {'potatoes', 'potato'}
#
#
# SYN --> disperse
# SPA --> {'scatters', 'dispel', 'scatter', 'scattered'}
#
#
# SYN --> break_up
# SPA --> {'scatters', 'scatter', 'scattered'}
#
#
# SYN --> spread
# SPA --> {'scatters', 'scatter', 'scattered', 'spread'}
#
#
# SYN --> sigh
# SPA --> {'sighs', 'sigh'}
#
#
# SYN --> lax
# SPA --> {'slack', 'loose'}
#
#
# SYN --> trough
# SPA --> {'troughs', 'trough'}
#
#
# SYN --> gutter
# SPA --> {'sewers', 'troughs', 'trough'}
#
#
# SYN --> bowl
# SPA --> {'troughs', 'trough'}
#
#
# SYN --> manger
# SPA --> {'troughs', 'trough'}
#
#
# SYN --> grip
# SPA --> {'grip', 'traction', 'gripped', 'grasp'}
#
#
# SYN --> diligence
# SPA --> {'industry', 'diligence'}
#
#
# SYN --> thick
# SPA --> {'deeper', 'deep'}
#
#
# SYN --> cryptic
# SPA --> {'deeper', 'deep'}
#
#
# SYN --> abstruse
# SPA --> {'deeper', 'deep'}
#
#
# SYN --> deeply
# SPA --> {'deeper', 'deep', 'deeply'}
#
#
# SYN --> quantify
# SPA --> {'measuring', 'measured'}
#
#
# SYN --> rejoice
# SPA --> {'rejoices', 'rejoice', 'rejoicing'}
#
#
# SYN --> trunk
# SPA --> {'trunk', 'trunks'}
#
#
# SYN --> luggage_compartment
# SPA --> {'trunk', 'trunks'}
#
#
# SYN --> proboscis
# SPA --> {'trunk', 'trunks'}
#
#
# SYN --> twirl
# SPA --> {'whirling', 'whirls', 'whirled'}
#
#
# SYN --> foster
# SPA --> {'nurturing', 'further'}
#
#
# SYN --> curious
# SPA --> {'queer', 'curious'}
#
#
# SYN --> march
# SPA --> {'marched', 'processes', 'march'}
#
#
# SYN --> demonstrate
# SPA --> {'marched', 'march', 'demonstrating'}
#
#
# SYN --> parade
# SPA --> {'marched', 'troops', 'march', 'troop'}
#
#
# SYN --> stamp
# SPA --> {'pestle', 'stamp', 'stamped'}
#
#
# SYN --> pigeonhole
# SPA --> {'stamp', 'stamped'}
#
#
# SYN --> curiosity
# SPA --> {'wonders', 'wonder'}
#
#
# SYN --> profoundly
# SPA --> {'deeper', 'deeply'}
#
#
# SYN --> peal
# SPA --> {'roll', 'rolling'}
#
#
# SYN --> wheeling
# SPA --> {'wheeling', 'rolling'}
#
#
# SYN --> roll_out
# SPA --> {'roll', 'rolling', 'rolled'}
#
#
# SYN --> seethe
# SPA --> {'roll', 'rolling', 'rolled'}
#
#
# SYN --> rolled
# SPA --> {'rolling', 'rolled'}
#
#
# SYN --> bat
# SPA --> {'fluttering', 'bats', 'flutterings'}
#
#
# SYN --> cream
# SPA --> {'bats', 'picks'}
#
#
# SYN --> balmy
# SPA --> {'balmy', 'buggy', 'nuts', 'bats'}
#
#
# SYN --> bay
# SPA --> {'bays', 'quest'}
#
#
# SYN --> bell
# SPA --> {'bell', 'bells'}
#
#
# SYN --> doorbell
# SPA --> {'bell', 'bells'}
#
#
# SYN --> chime
# SPA --> {'bell', 'bells'}
#
#
# SYN --> mingle
# SPA --> {'mingling', 'mingled'}
#
#
# SYN --> jumble
# SPA --> {'mingling', 'mingled'}
#
#
# SYN --> radiance
# SPA --> {'shine', 'glow', 'shines'}
#
#
# SYN --> gleam
# SPA --> {'glow', 'gleams'}
#
#
# SYN --> substance
# SPA --> {'substances', 'substance'}
#
#
# SYN --> meaning
# SPA --> {'substances', 'substance', 'meaning'}
#
#
# SYN --> congregation
# SPA --> {'faithful', 'congregation'}
#
#
# SYN --> stage
# SPA --> {'presented', 'representing', 'stage', 'legs'}
#
#
# SYN --> stable
# SPA --> {'stabled', 'stable'}
#
#
# SYN --> action
# SPA --> {'processes', 'action', 'activity'}
#
#
# SYN --> natural_process
# SPA --> {'action', 'activity'}
#
#
# SYN --> harden
# SPA --> {'indurate', 'hardened'}
#
#
# SYN --> inure
# SPA --> {'indurate', 'hardened'}
#
#
# SYN --> snuff_out
# SPA --> {'quenches', 'extinguish'}
#
#
# SYN --> intimate
# SPA --> {'versed', 'intimate'}
#
#
# SYN --> alienated
# SPA --> {'alienated', 'estranged'}
#
#
# SYN --> professor
# SPA --> {'prof', 'professor'}
#
#
# SYN --> beard
# SPA --> {'bearded', 'beard'}
#
#
# SYN --> grocery_store
# SPA --> {'market', 'grocery'}
#
#
# SYN --> valet
# SPA --> {'mans', 'gentleman', 'gentlemen'}
#
#
# SYN --> bulk
# SPA --> {'mass', 'bulk'}
#
#
# SYN --> flat
# SPA --> {'flat', 'matted'}
#
#
# SYN --> make_noise
# SPA --> {'resounded', 'resounding'}
#
#
# SYN --> sidewalk
# SPA --> {'sidewalks', 'sidewalk'}
#
#
# SYN --> trash
# SPA --> {'scrapes', 'scraping', 'trash'}
#
#
# SYN --> recently
# SPA --> {'late', 'lately'}
#
#
# SYN --> chatter
# SPA --> {'twaddle', 'chattering'}
#
#
# SYN --> ease
# SPA --> {'comfort', 'ease'}
#
#
# SYN --> noon
# SPA --> {'noonday', 'noon'}
#
#
# SYN --> eagle
# SPA --> {'eagles', 'eagle'}
#
#
# SYN --> poet
# SPA --> {'poet', 'poets'}
#
#
# SYN --> gay
# SPA --> {'festal', 'jocund', 'queer'}
#
#
# SYN --> consecrate
# SPA --> {'blessed', 'blest', 'hallows'}
#
#
# SYN --> blessed
# SPA --> {'blessed', 'blest'}
#
#
# SYN --> familiar
# SPA --> {'familiar', 'intimate'}
#
#
# SYN --> horizon
# SPA --> {'view', 'horizon'}
#
#
# SYN --> explode
# SPA --> {'bursted', 'exploded', 'burst'}
#
#
# SYN --> abound
# SPA --> {'bursted', 'bristling', 'burst', 'bristles'}
#
#
# SYN --> pinch
# SPA --> {'twitched', 'pinching'}
#
#
# SYN --> piano
# SPA --> {'pianos', 'softly'}
#
#
# SYN --> candle
# SPA --> {'candles', 'candle'}
#
#
# SYN --> captain
# SPA --> {'chieftains', 'captain'}
#
#
# SYN --> denial
# SPA --> {'denial', 'denials'}
#
#
# SYN --> abnegation
# SPA --> {'denial', 'denials'}
#
#
# SYN --> defense
# SPA --> {'denial', 'denials'}
#
#
# SYN --> newcomer
# SPA --> {'fledglings', 'newcomer'}
#
#
# SYN --> hasty
# SPA --> {'hasty', 'headlong', 'precipitate'}
#
#
# SYN --> drab
# SPA --> {'drab', 'sober'}
#
#
# SYN --> harmonica
# SPA --> {'harp', 'harps'}
#
#
# SYN --> issue
# SPA --> {'emerged', 'numbers'}
#
#
# SYN --> wire
# SPA --> {'wires', 'wired'}
#
#
# SYN --> electrify
# SPA --> {'wires', 'wired'}
#
#
# SYN --> comfortable
# SPA --> {'comfortable', 'easy'}
#
#
# SYN --> take_down
# SPA --> {'disgrace', 'disgraced'}
#
#
# SYN --> finish_up
# SPA --> {'finish', 'finished'}
#
#
# SYN --> eat_up
# SPA --> {'finish', 'finished'}
#
#
# SYN --> stem
# SPA --> {'halted', 'halt'}
#
#
# SYN --> goodly
# SPA --> {'healthy', 'goodly'}
#
#
# SYN --> savage
# SPA --> {'crucified', 'blast', 'blasted'}
#
#
# SYN --> fruit
# SPA --> {'fruits', 'fruit'}
#
#
# SYN --> quilt
# SPA --> {'comforter', 'comfort'}
#
#
# SYN --> flute
# SPA --> {'flutes', 'flute'}
#
#
# SYN --> trumpet
# SPA --> {'trumpets', 'trumpet'}
#
#
# SYN --> arbor
# SPA --> {'arbors', 'bower', 'arbor'}
#
#
# SYN --> salt
# SPA --> {'salt', 'salts'}
#
#
# SYN --> strategic_arms_limitation_talks
# SPA --> {'salt', 'salts'}
#
#
# SYN --> scepter
# SPA --> {'wand', 'sceptre'}
#
#
# SYN --> hermit
# SPA --> {'recluse', 'solitary'}
#
#
# SYN --> staff
# SPA --> {'staves', 'staff'}
#
#
# SYN --> wreath
# SPA --> {'coronal', 'wreaths'}
#
#
# SYN --> fearful
# SPA --> {'frightful', 'fearful'}
#
#
# SYN --> flutter
# SPA --> {'fluttering', 'flutterings'}
#
#
# SYN --> palpitate
# SPA --> {'fluttering', 'flutterings'}
#
#
# SYN --> jester
# SPA --> {'fools', 'fool'}
#
#
# SYN --> host
# SPA --> {'hosts', 'host'}
#
#
# SYN --> master_of_ceremonies
# SPA --> {'hosts', 'host'}
#
#
# SYN --> server
# SPA --> {'hosts', 'host'}
#
#
# SYN --> furled
# SPA --> {'furled', 'rolled'}
#
#
# SYN --> basement
# SPA --> {'basement', 'cellars'}
#
#
# SYN --> wild_boar
# SPA --> {'boar', 'boars'}
#
#
# SYN --> boar
# SPA --> {'boar', 'boars'}
#
#
# SYN --> brick
# SPA --> {'brick', 'bricks'}
#
#
# SYN --> bristle
# SPA --> {'bristles', 'bristling'}
#
#
# SYN --> busy
# SPA --> {'busy', 'engaged'}
#
#
# SYN --> chartered
# SPA --> {'chartered', 'hired'}
#
#
# SYN --> thorax
# SPA --> {'chest', 'chests'}
#
#
# SYN --> chest
# SPA --> {'chest', 'chests'}
#
#
# SYN --> chest_of_drawers
# SPA --> {'chest', 'chests'}
#
#
# SYN --> sanction
# SPA --> {'countenance', 'warrant'}
#
#
# SYN --> murmur
# SPA --> {'murmur', 'croaks', 'gnarled', 'murmured'}
#
#
# SYN --> bridle
# SPA --> {'curb', 'check'}
#
#
# SYN --> restrict
# SPA --> {'bound', 'curb'}
#
#
# SYN --> drain
# SPA --> {'drained', 'drain'}
#
#
# SYN --> enfeeble
# SPA --> {'drained', 'drain'}
#
#
# SYN --> echo
# SPA --> {'echoed', 'echoes'}
#
#
# SYN --> erstwhile
# SPA --> {'older', 'erstwhile'}
#
#
# SYN --> bonny
# SPA --> {'fair', 'fairer'}
#
#
# SYN --> ending
# SPA --> {'finish', 'ending'}
#
#
# SYN --> troop
# SPA --> {'troops', 'flock', 'flocks', 'troop'}
#
#
# SYN --> grapple
# SPA --> {'grip', 'gripped'}
#
#
# SYN --> fascinate
# SPA --> {'grip', 'gripped'}
#
#
# SYN --> hire
# SPA --> {'engaged', 'hired'}
#
#
# SYN --> roll_up
# SPA --> {'hoards', 'collecting', 'furled'}
#
#
# SYN --> idiot
# SPA --> {'idiots', 'idiot'}
#
#
# SYN --> aerodynamic_lift
# SPA --> {'lifts', 'lift'}
#
#
# SYN --> ski_tow
# SPA --> {'lifts', 'lift'}
#
#
# SYN --> elevator
# SPA --> {'lifts', 'lift'}
#
#
# SYN --> face_lift
# SPA --> {'lifts', 'lift'}
#
#
# SYN --> lion
# SPA --> {'lion', 'lions'}
#
#
# SYN --> leo
# SPA --> {'lion', 'lions'}
#
#
# SYN --> lock
# SPA --> {'locked', 'curl'}
#
#
# SYN --> interlock
# SPA --> {'locked', 'mesh'}
#
#
# SYN --> lower
# SPA --> {'lower', 'lowered'}
#
#
# SYN --> turn_down
# SPA --> {'lower', 'lowered'}
#
#
# SYN --> lynch
# SPA --> {'lynch', 'lynched'}
#
#
# SYN --> marshal
# SPA --> {'marshal', 'marshall', 'marshals'}
#
#
# SYN --> peer
# SPA --> {'equal', 'match'}
#
#
# SYN --> menace
# SPA --> {'menace', 'threats'}
#
#
# SYN --> musician
# SPA --> {'musicians', 'players'}
#
#
# SYN --> rattle
# SPA --> {'rattle', 'rattled'}
#
#
# SYN --> regenerate
# SPA --> {'restores', 'regenerate'}
#
#
# SYN --> get_rid_of
# SPA --> {'remove', 'removed'}
#
#
# SYN --> take_out
# SPA --> {'remove', 'removed'}
#
#
# SYN --> gross
# SPA --> {'grosser', 'revenue'}
#
#
# SYN --> exuberant
# SPA --> {'lush', 'riotous'}
#
#
# SYN --> orgy
# SPA --> {'riots', 'debauch'}
#
#
# SYN --> haste
# SPA --> {'rushing', 'hurry', 'haste'}
#
#
# SYN --> serpent
# SPA --> {'serpents', 'serpent'}
#
#
# SYN --> sneer
# SPA --> {'sneers', 'sneered', 'sneer'}
#
#
# SYN --> present
# SPA --> {'presented', 'representing', 'submit'}
#
#
# SYN --> suit
# SPA --> {'suits', 'fitting'}
#
#
# SYN --> typify
# SPA --> {'representing', 'symbolized'}
#
#
# SYN --> toll
# SPA --> {'tolled', 'tolling'}
#
#
# SYN --> carry_through
# SPA --> {'fulfill', 'action', 'accomplished'}
#
#
# SYN --> guarantee
# SPA --> {'insured', 'warrant', 'assuring'}
#
#
# SYN --> calamity
# SPA --> {'cataclysm', 'tragedy'}
#
#
# SYN --> conceal
# SPA --> {'concealing', 'concealed'}
#
#
# SYN --> creature
# SPA --> {'creature', 'creatures'}
#
#
# SYN --> damp
# SPA --> {'damps', 'dampness'}
#
#
# SYN --> dead_person
# SPA --> {'departed', 'deceased'}
#
#
# SYN --> deviate
# SPA --> {'departed', 'departing'}
#
#
# SYN --> enmesh
# SPA --> {'mesh', 'enmesh'}
#
#
# SYN --> strain
# SPA --> {'strains', 'extends', 'strain'}
#
#
# SYN --> apartment
# SPA --> {'flat', 'apartment'}
#
#
# SYN --> compressed
# SPA --> {'flat', 'tight'}
#
#
# SYN --> satisfy
# SPA --> {'fulfill', 'gratify'}
#
#
# SYN --> gentleman
# SPA --> {'gentleman', 'gentlemen'}
#
#
# SYN --> hurry
# SPA --> {'haste', 'hurry'}
#
#
# SYN --> feverish
# SPA --> {'hectic', 'feverish'}
#
#
# SYN --> hero
# SPA --> {'heros', 'hero'}
#
#
# SYN --> heroine
# SPA --> {'heroine', 'heroines'}
#
#
# SYN --> delusion
# SPA --> {'delusion', 'illusion'}
#
#
# SYN --> component
# SPA --> {'elements', 'ingredients'}
#
#
# SYN --> citation
# SPA --> {'credit', 'mention'}
#
#
# SYN --> engagement
# SPA --> {'engagement', 'mesh'}
#
#
# SYN --> brawn
# SPA --> {'muscle', 'brawn'}
#
#
# SYN --> apparent
# SPA --> {'seeming', 'patent', 'plain'}
#
#
# SYN --> repugnance
# SPA --> {'repulsion', 'revulsion'}
#
#
# SYN --> scenery
# SPA --> {'scenery', 'scene'}
#
#
# SYN --> scrap
# SPA --> {'scrapes', 'scraping'}
#
#
# SYN --> seedling
# SPA --> {'seedlings', 'seedling'}
#
#
# SYN --> speck
# SPA --> {'specks', 'speck'}
#
#
# SYN --> bustle
# SPA --> {'bustled', 'stir'}
#
#
# SYN --> stress
# SPA --> {'strains', 'strain'}
#
#
# SYN --> tenor
# SPA --> {'strains', 'strain'}
#
#
# SYN --> striving
# SPA --> {'strains', 'strain'}
#
#
# SYN --> sift
# SPA --> {'strains', 'strain'}
#
#
# SYN --> tense
# SPA --> {'strains', 'strain'}
#
#
# SYN --> filter
# SPA --> {'strains', 'strain'}
#
#
# SYN --> puree
# SPA --> {'strains', 'strain'}
#
#
# SYN --> deform
# SPA --> {'strains', 'strain'}
#
#
# SYN --> darnel
# SPA --> {'tares', 'cheat'}
#
#
# SYN --> trick
# SPA --> {'tricks', 'trick'}
#
#
# SYN --> flim-flam
# SPA --> {'tricks', 'trick'}
#
#
# SYN --> protest
# SPA --> {'protest', 'protested', 'objection'}
#
#
# SYN --> testis
# SPA --> {'eggs', 'nuts'}
#
#
# SYN --> suck
# SPA --> {'sucked', 'suck'}
#
#
# SYN --> curl_up
# SPA --> {'curled', 'curl'}
#
#
# SYN --> frank
# SPA --> {'frank', 'dogs'}
#
#
# SYN --> burrow
# SPA --> {'burrow', 'burrows'}
#
#
# SYN --> grudge
# SPA --> {'score', 'grudges', 'scores'}
#
#
# SYN --> expostulation
# SPA --> {'remonstrance', 'objection'}
#
#
# SYN --> baptize
# SPA --> {'baptized', 'christening'}
#
#
# SYN --> probate
# SPA --> {'probate', 'probated'}
#
#
# SYN --> bound
# SPA --> {'bound', 'destined'}
#
#
# SYN --> expectation
# SPA --> {'prospect', 'expectation'}
#
#
# SYN --> nest
# SPA --> {'nesting', 'nest'}
#
#
# SYN --> drill
# SPA --> {'practicing', 'practice'}
#
#
# SYN --> rehearse
# SPA --> {'practicing', 'practice'}
#
#
# SYN --> frequent
# SPA --> {'haunted', 'haunt'}
#
#
# SYN --> entrance
# SPA --> {'entering', 'entries'}
#
#
# SYN --> lavish
# SPA --> {'lush', 'showered', 'lavished'}
#
#
# SYN --> minister
# SPA --> {'minister', 'ministers'}
#
#
# SYN --> revival
# SPA --> {'revival', 'revivals'}
#
#
# SYN --> sooner
# SPA --> {'earlier', 'sooner'}
#
#
# SYN --> process
# SPA --> {'processes', 'treat'}
#
#
# SYN --> abandoned
# SPA --> {'abandoned', 'deserted'}
#
#
# SYN --> insidious
# SPA --> {'subtle', 'insidious'}
#
#
# SYN --> sexual_conquest
# SPA --> {'score', 'scores'}
#
#
# SYN --> low
# SPA --> {'lower', 'lowest'}
#
#
# SYN --> abject
# SPA --> {'lower', 'lowest'}
#
#
# SYN --> depleted
# SPA --> {'lower', 'lowest'}
#
#
# SYN --> essay
# SPA --> {'essays', 'essay'}
#
#
# SYN --> spindle
# SPA --> {'arbors', 'arbor'}
#
#
# SYN --> orphan
# SPA --> {'orphan', 'orphans', 'orphaned'}
#
#
# SYN --> heroism
# SPA --> {'valor', 'heroism'}
#
#
# SYN --> rondeau
# SPA --> {'rondels', 'rondeaus'}
#
#
# SYN --> advise
# SPA --> {'advised', 'advise'}
#
#
# SYN --> collection
# SPA --> {'collecting', 'accumulations'}

# %%
import networkx as nx
pickled_graph = nx.read_gpickle("../logic/test.gpickle")

# %%
for ind, node in pickled_graph.nodes(data=True):
    pickled_graph.node[ind]['type'] = 'SPA'

# %%
pickled_graph.node[1]
# Out:
# {'vector_ind': 0, 'term_id': 20, 'freq_per_doc': 1.0, 'type': 'SPA'}

# %%
dictionary[pickled_graph.node[1]['term_id']]
# Out:
# 'hands'

# %%
syns_per_term = defaultdict(set)

syn_dict = Dictionary()
syn_to_node_map = dict()

# Keep updating this as we add in the synonyms
node_count = len(pickled_graph.nodes)

for term_ind, node in pickled_graph.nodes(data=True):
    term = dictionary[node['term_id']]
    
    # syn nodes have already been created, the values are in in the list
    if term in syns_per_term:
        for syn_id in syns_per_term[term]:
            pickled_graph.add_edge(term_ind, syn_id, attr_dict={'weight': 0.5})
         
    # synonyms have not been created for this term
    else:
        # get syns for term
        syns = wn.synsets(term)
        
        for syn_obj in syns:
            # extracts the text value from the syn object
            syn = syn_obj.name().split('.')[0]
            
            if syn not in syn_dict.token2id:
                # add syn term to dictionary
                syn_dict.add_documents([[syn]])
                
                # add syn node to graph
                SPA_graph.add_node(node_count, type='SYN', term_id=syn_dict.token2id[syn], freq_per_doc=-1, vector_ind=-1)
                syn_to_node_map[syn_dict.token2id[syn]] = node_count
                
                # Keep track of values
                node_count += 1
            
            if syn not in syns_per_term[term]:
                pickled_graph.add_edge(ind, syn_id, attr_dict={'weight': 0.5})
