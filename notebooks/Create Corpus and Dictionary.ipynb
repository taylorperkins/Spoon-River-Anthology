# %% [markdown]
# ## Dictionary
# This is just a collection of words that get assigned a number. It is much easier and faster to process integers than text, so creating a map is useful. This is a dictionary over the entire book of SPA.
#
# ## Corpus
# This will be a processed corpus per poem.
# 1. Excluding stopwords
# 2. Lowercased

# %%
import os
import fnmatch
import logging
from collections import defaultdict
from pprint import pprint

import re

from gensim import corpora

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
def remove_ascii(line):
    return re.sub(r'[\x90-\x99]','', line)

poems = defaultdict(list)

for file_name in os.listdir('../data/poems/'):
    if fnmatch.fnmatch(file_name, '*_cleaned_poem.txt'):
        poem_num = file_name.split('_')[0]
        
        with open(f'../data/poems/{file_name}', 'r') as f:
            poems[poem_num] = [remove_ascii(line) for line in f.read().splitlines()]

# %%
poems['6']
# Out:
# ['THEY have chiseled on my stone the words:',
#  'His life was gentle, and the elements so mixed in him',
#  'That nature might stand up and say to all the world,',
#  'This was a man.',
#  'Those who knew me smile',
#  'As they read this empty rhetoric.',
#  'My epitaph should have been:',
#  'Life was not gentle to him,',
#  'And the elements so mixed in him',
#  'That he made warfare on life,',
#  'In the which he was slain.',
#  'While I lived I could not cope with slanderous tongues,',
#  'Now that I am dead I must submit to an epitaph',
#  'Graven by a fool!']

# %%
# remove some stop words, lowercase everything, and split it up
# each poem is it's own corpus.
stoplist = set('for a of the and to in'.split())
texts = {
    poem_num: [[word for word in document.lower().split() 
                 if word not in stoplist]
                for document in corpus]
    for poem_num, corpus in poems.items()
}

# %%
pprint(texts)
# Out:
# {'1': [['where', 'are', 'elmer,', 'herman,', 'bert,', 'tom', 'charley,'],
#        ['weak', 'will,', 'strong', 'arm,', 'clown,', 'boozer,', 'fighter?'],
#        ['all,', 'all,', 'are', 'sleeping', 'on', 'hill.'],
#        ['one', 'passed', 'fever,'],
#        ['one', 'was', 'burned', 'mine,'],
#        ['one', 'was', 'killed', 'brawl,'],
#        ['one', 'died', 'jail,'],
#        ['one', 'fell', 'from', 'bridge', 'toiling', 'children', 'wife'],
#        ['all,',
#         'all',
#         'are',
#         'sleeping,',
#         'sleeping,',
#         'sleeping',
#         'on',
#         'hill.'],
#        ['where', 'are', 'ella,', 'kate,', 'mag,', 'lizzie', 'edith,'],
#        ['tender',
#         'heart,',
#         'simple',
#         'soul,',
#         'loud,',
#         'proud,',
#         'happy',
#         'one?'],
#        ['all,', 'all,', 'are', 'sleeping', 'on', 'hill.'],
#        ['one', 'died', 'shameful', 'child-birth,'],
#        ['one', 'thwarted', 'love,'],
#        ['one', 'at', 'hands', 'brute', 'brothel,'],
#        ['one', 'broken', 'pride,', 'search', 'hearts', 'desire,'],
#        ['one', 'after', 'life', 'far-away', 'london', 'paris'],
#        ['was',
#         'brought',
#         'her',
#         'little',
#         'space',
#         'by',
#         'ella',
#         'kate',
#         'mag'],
#        ['all,',
#         'all',
#         'are',
#         'sleeping,',
#         'sleeping,',
#         'sleeping',
#         'on',
#         'hill.'],
#        ['where', 'are', 'uncle', 'isaac', 'aunt', 'emily,'],
#        ['old', 'towny', 'kincaid', 'sevigne', 'houghton,'],
#        ['major', 'walker', 'who', 'had', 'talked'],
#        ['with', 'venerable', 'men', 'revolution?'],
#        ['all,', 'all,', 'are', 'sleeping', 'on', 'hill.'],
#        ['they', 'brought', 'them', 'dead', 'sons', 'from', 'war,'],
#        ['daughters', 'whom', 'life', 'had', 'crushed,'],
#        ['their', 'children', 'fatherless,', 'crying'],
#        ['all,',
#         'all',
#         'are',
#         'sleeping,',
#         'sleeping,',
#         'sleeping',
#         'on',
#         'hill.'],
#        ['where', 'is', 'old', 'fiddler', 'jones'],
#        ['who', 'played', 'with', 'life', 'all', 'his', 'ninety', 'years,'],
#        ['braving', 'sleet', 'with', 'bared', 'breast,'],
#        ['drinking,', 'rioting,', 'thinking', 'neither', 'wife', 'nor', 'kin,'],
#        ['nor', 'gold,', 'nor', 'love,', 'nor', 'heaven?'],
#        ['lo!', 'he', 'babbles', 'fish-frys', 'long', 'ago,'],
#        ['horse-races', 'long', 'ago', 'at', 'clarys', 'grove,'],
#        ['what', 'abe', 'lincoln', 'said'],
#        ['one', 'time', 'at', 'springfield.']],
#  '10': [['life', 'i', 'was', 'town', 'drunkard;'],
#         ['when', 'i', 'died', 'priest', 'denied', 'me', 'burial'],
#         ['holy', 'ground.'],
#         ['which', 'redounded', 'my', 'good', 'fortune.'],
#         ['protestants', 'bought', 'this', 'lot,'],
#         ['buried', 'my', 'body', 'here,'],
#         ['close', 'grave', 'banker', 'nicholas,'],
#         ['his', 'wife', 'priscilla.'],
#         ['take', 'note,', 'ye', 'prudent', 'pious', 'souls,'],
#         ['cross-currents', 'life'],
#         ['which', 'bring', 'honor', 'dead,', 'who', 'lived', 'shame.']],
#  '100': [['dear', 'jane!', 'dear', 'winsome', 'jane!'],
#          ['how', 'you', 'stole', 'room', '(where', 'i', 'lay', 'so', 'ill)'],
#          ['your', 'nurses', 'cap', 'linen', 'cuffs,'],
#          ['took', 'my', 'hand', 'said', 'with', 'smile:'],
#          ['you', 'are', 'not', 'so', 'ill', 'youll', 'soon', 'be', 'well.'],
#          ['how', 'liquid', 'thought', 'your', 'eyes'],
#          ['sank', 'my', 'eyes', 'like', 'dew', 'that', 'slips'],
#          ['into', 'heart', 'flower.'],
#          ['dear', 'jane!', 'whole', 'mcneely', 'fortune'],
#          ['could', 'not', 'have', 'bought', 'your', 'care', 'me,'],
#          ['by', 'day', 'night,', 'night', 'day;'],
#          ['nor', 'paid', 'you', 'smile,', 'nor', 'warmth', 'your', 'soul,'],
#          ['your', 'little', 'hands', 'laid', 'on', 'my', 'brow.'],
#          ['jane,', 'till', 'flame', 'life', 'went', 'out'],
#          ['dark', 'above', 'disk', 'night'],
#          ['i', 'longed', 'hoped', 'be', 'well', 'again'],
#          ['pillow', 'my', 'head', 'on', 'your', 'little', 'breasts,'],
#          ['hold', 'you', 'fast', 'clasp', 'love'],
#          ['did', 'my', 'father', 'provide', 'you', 'when', 'he', 'died,'],
#          ['jane,', 'dear', 'jane?']],
#  '101': [['passer', 'by,'],
#          ['love', 'is', 'find', 'your', 'own', 'soul'],
#          ['through', 'soul', 'beloved', 'one.'],
#          ['when',
#           'beloved',
#           'one',
#           'withdraws',
#           'itself',
#           'from',
#           'your',
#           'soul'],
#          ['then', 'you', 'have', 'lost', 'your', 'soul.'],
#          ['it', 'is', 'written:', 'i', 'have', 'friend,'],
#          ['but', 'my', 'sorrow', 'has', 'no', 'friend.'],
#          ['hence',
#           'my',
#           'long',
#           'years',
#           'solitude',
#           'at',
#           'home',
#           'my',
#           'father,'],
#          ['trying', 'get', 'myself', 'back,'],
#          ['turn', 'my', 'sorrow', 'into', 'supremer', 'self.'],
#          ['but', 'there', 'was', 'my', 'father', 'with', 'his', 'sorrows,'],
#          ['sitting', 'under', 'cedar', 'tree,'],
#          ['picture', 'that', 'sank', 'into', 'my', 'heart', 'at', 'last'],
#          ['bringing', 'infinite', 'repose.'],
#          ['oh,', 'ye', 'souls', 'who', 'have', 'made', 'life'],
#          ['fragrant', 'white', 'as', 'tube', 'roses'],
#          ['from', 'earths', 'dark', 'soil,'],
#          ['eternal', 'peace!']],
#  '102': [['when', 'i', 'went', 'city,', 'mary', 'mcneely,'],
#          ['i', 'meant', 'return', 'you,', 'yes', 'i', 'did.'],
#          ['but', 'laura,', 'my', 'landladys', 'daughter,'],
#          ['stole', 'into', 'my', 'life', 'somehow,', 'won', 'me', 'away.'],
#          ['then', 'after', 'some', 'years', 'whom', 'should', 'i', 'meet'],
#          ['but', 'georgine', 'miner', 'from', 'nilesa', 'sprout'],
#          ['free', 'love,', 'fourierist', 'gardens', 'that', 'flourished'],
#          ['before', 'war', 'all', 'over', 'ohio.'],
#          ['her', 'dilettante', 'lover', 'had', 'tired', 'her,'],
#          ['she', 'turned', 'me', 'strength', 'solace.'],
#          ['she', 'was', 'some', 'kind', 'crying', 'thing'],
#          ['one', 'takes', 'ones', 'arms,', 'all', 'at', 'once'],
#          ['it', 'slimes', 'your', 'face', 'with', 'its', 'running', 'nose,'],
#          ['voids', 'its', 'essence', 'all', 'over', 'you;'],
#          ['then', 'bites', 'your', 'hand', 'springs', 'away.'],
#          ['there', 'you', 'stand', 'bleeding', 'smelling', 'heaven!'],
#          ['why,', 'mary', 'mcneely,', 'i', 'was', 'not', 'worthy'],
#          ['kiss', 'hem', 'your', 'robe!']],
#  '103': [['step-mother', 'drove', 'me', 'from', 'home,', 'embittering', 'me.'],
#          ['squaw-man,', 'flaneur', 'dilettante', 'took', 'my', 'virtue.'],
#          ['years', 'i', 'was', 'his', 'mistressno', 'one', 'knew.'],
#          ['i', 'learned', 'from', 'him', 'parasite', 'cunning'],
#          ['with',
#           'which',
#           'i',
#           'moved',
#           'with',
#           'bluffs,',
#           'like',
#           'flea',
#           'on',
#           'dog.'],
#          ['all',
#           'time',
#           'i',
#           'was',
#           'nothing',
#           'but',
#           'very',
#           'private',
#           'with',
#           'different',
#           'men.'],
#          ['then', 'daniel,', 'radical,', 'had', 'me', 'years.'],
#          ['his', 'sister', 'called', 'me', 'his', 'mistress;'],
#          ['daniel',
#           'wrote',
#           'me:',
#           'shameful',
#           'word,',
#           'soiling',
#           'our',
#           'beautiful',
#           'love!'],
#          ['but', 'my', 'anger', 'coiled,', 'preparing', 'its', 'fangs.'],
#          ['my', 'lesbian', 'friend', 'next', 'took', 'hand.'],
#          ['she', 'hated', 'daniels', 'sister.'],
#          ['daniel', 'despised', 'her', 'midget', 'husband.'],
#          ['she', 'saw', 'chance', 'poisonous', 'thrust:'],
#          ['i', 'must', 'complain', 'wife', 'daniels', 'pursuit!'],
#          ['but',
#           'before',
#           'i',
#           'did',
#           'that',
#           'i',
#           'begged',
#           'him',
#           'fly',
#           'london',
#           'with',
#           'me.'],
#          ['why',
#           'not',
#           'stay',
#           'city',
#           'just',
#           'as',
#           'we',
#           'have?',
#           'he',
#           'asked.'],
#          ['then', 'i', 'turned', 'submarine', 'revenged', 'his', 'repulse'],
#          ['arms', 'my', 'dilettante', 'friend.', 'then', 'up', 'surface,'],
#          ['bearing', 'letter', 'that', 'daniel', 'wrote', 'me,'],
#          ['prove',
#           'my',
#           'honor',
#           'was',
#           'all',
#           'intact,',
#           'showing',
#           'it',
#           'his',
#           'wife,'],
#          ['my', 'lesbian', 'friend', 'everyone.'],
#          ['if', 'daniel', 'had', 'only', 'shot', 'me', 'dead!'],
#          ['instead', 'stripping', 'me', 'naked', 'lies,'],
#          ['harlot', 'body', 'soul!']],
#  '104': [['very', 'well,', 'you', 'liberals,'],
#          ['navigators', 'into', 'realms', 'intellectual,'],
#          ['you', 'sailors', 'through', 'heights', 'imaginative,'],
#          ['blown',
#           'about',
#           'by',
#           'erratic',
#           'currents,',
#           'tumbling',
#           'into',
#           'air',
#           'pockets,'],
#          ['you', 'margaret', 'fuller', 'slacks,', 'petits,'],
#          ['tennessee', 'claflin', 'shopes'],
#          ['you', 'found', 'with', 'all', 'your', 'boasted', 'wisdom'],
#          ['how', 'hard', 'at', 'last', 'it', 'is'],
#          ['keep', 'soul', 'from', 'splitting', 'into', 'cellular', 'atoms.'],
#          ['while', 'we,', 'seekers', 'earths', 'treasures,'],
#          ['getters', 'hoarders', 'gold,'],
#          ['are', 'self-contained,', 'compact,', 'harmonized,'],
#          ['even', 'end.']],
#  '105': [['after', 'i', 'had', 'attended', 'lectures'],
#          ['at', 'our', 'chautauqua,', 'studied', 'french'],
#          ['twenty', 'years,', 'committing', 'grammar'],
#          ['almost', 'by', 'heart,'],
#          ['i', 'thought', 'id', 'take', 'trip', 'paris'],
#          ['give', 'my', 'culture', 'final', 'polish.'],
#          ['so', 'i', 'went', 'peoria', 'passport'],
#          ['(thomas', 'rhodes', 'was', 'on', 'train', 'that', 'morning.)'],
#          ['there', 'clerk', 'district', 'court'],
#          ['made', 'me', 'swear', 'support', 'defend'],
#          ['constitutionyes,', 'even', 'me'],
#          ['who', 'couldnt', 'defend', 'or', 'support', 'it', 'at', 'all!'],
#          ['what', 'do', 'you', 'think?', 'that', 'very', 'morning'],
#          ['federal', 'judge,', 'very', 'next', 'room'],
#          ['room', 'where', 'i', 'took', 'oath,'],
#          ['decided', 'constitution'],
#          ['exempted', 'rhodes', 'from', 'paying', 'taxes'],
#          ['water', 'works', 'spoon', 'river!']],
#  '106': [['i', 'lost', 'my', 'patronage', 'spoon', 'river'],
#          ['from', 'trying', 'put', 'my', 'mind', 'camera'],
#          ['catch', 'soul', 'person.'],
#          ['very', 'best', 'picture', 'i', 'ever', 'took'],
#          ['was', 'judge', 'somers,', 'attorney', 'at', 'law.'],
#          ['he', 'sat', 'upright', 'had', 'me', 'pause'],
#          ['till', 'he', 'got', 'his', 'cross-eye', 'straight.'],
#          ['then', 'when', 'he', 'was', 'ready', 'he', 'said', 'all', 'right.'],
#          ['i', 'yelled', 'overruled', 'his', 'eye', 'turned', 'up.'],
#          ['i', 'caught', 'him', 'just', 'as', 'he', 'used', 'look'],
#          ['when', 'saying', 'i', 'except.']],
#  '107': [['while', 'i', 'was', 'handling', 'dom', 'pedro'],
#          ['i',
#           'got',
#           'at',
#           'thing',
#           'that',
#           'divides',
#           'race',
#           'between',
#           'men',
#           'who',
#           'are'],
#          ['singing',
#           'turkey',
#           'straw',
#           'or',
#           'there',
#           'is',
#           'fountain',
#           'filled',
#           'with',
#           'blood'],
#          ['(like',
#           'rile',
#           'potter',
#           'used',
#           'sing',
#           'it',
#           'over',
#           'at',
#           'concord);'],
#          ['cards,', 'or', 'rev.', 'peets', 'lecture', 'on', 'holy', 'land;'],
#          ['skipping', 'light', 'fantastic,', 'or', 'passing', 'plate;'],
#          ['pinafore,', 'or', 'sunday', 'school', 'cantata;'],
#          ['men,', 'or', 'money;'],
#          ['people', 'or', 'against', 'them.'],
#          ['this', 'was', 'it:'],
#          ['rev.', 'peet', 'social', 'purity', 'club,'],
#          ['headed', 'by', 'ben', 'pantiers', 'wife,'],
#          ['went', 'village', 'trustees,'],
#          ['asked', 'them', 'make', 'me', 'take', 'dom', 'pedro'],
#          ['from', 'barn', 'wash', 'mcneely,', 'there', 'at', 'edge', 'town,'],
#          ['barn', 'outside', 'corporation,'],
#          ['on', 'ground', 'that', 'it', 'corrupted', 'public', 'morals.'],
#          ['well,', 'ben', 'pantier', 'fiddler', 'jones', 'saved', 'day'],
#          ['they', 'thought', 'it', 'slam', 'on', 'colts.']],
#  '108': [['i', 'grew', 'spiritually', 'fat', 'living', 'off', 'souls', 'men.'],
#          ['if', 'i', 'saw', 'soul', 'that', 'was', 'strong'],
#          ['i', 'wounded', 'its', 'pride', 'devoured', 'its', 'strength.'],
#          ['shelters', 'friendship', 'knew', 'my', 'cunning,'],
#          ['where', 'i', 'could', 'steal', 'friend', 'i', 'did', 'so.'],
#          ['wherever', 'i', 'could', 'enlarge', 'my', 'power'],
#          ['by', 'undermining', 'ambition,', 'i', 'did', 'so,'],
#          ['thus', 'make', 'smooth', 'my', 'own.'],
#          ['triumph', 'over', 'other', 'souls,'],
#          ['just', 'assert', 'prove', 'my', 'superior', 'strength,'],
#          ['was', 'with', 'me', 'delight,'],
#          ['keen', 'exhilaration', 'soul', 'gymnastics.'],
#          ['devouring', 'souls,', 'i', 'should', 'have', 'lived', 'forever.'],
#          ['but',
#           'their',
#           'undigested',
#           'remains',
#           'bred',
#           'me',
#           'deadly',
#           'nephritis,'],
#          ['with', 'fear,', 'restlessness,', 'sinking', 'spirits,'],
#          ['hatred,', 'suspicion,', 'vision', 'disturbed.'],
#          ['i', 'collapsed', 'at', 'last', 'with', 'shriek.'],
#          ['remember', 'acorn;'],
#          ['it', 'does', 'not', 'devour', 'other', 'acorns.']],
#  '109': [['i', 'was', 'peasant', 'girl', 'from', 'germany,'],
#          ['blue-eyed,', 'rosy,', 'happy', 'strong.'],
#          ['first', 'place', 'i', 'worked', 'was', 'at', 'thomas', 'greenes.'],
#          ['on', 'summers', 'day', 'when', 'she', 'was', 'away'],
#          ['he', 'stole', 'into', 'kitchen', 'took', 'me'],
#          ['right', 'his', 'arms', 'kissed', 'me', 'on', 'my', 'throat,'],
#          ['i', 'turning', 'my', 'head.', 'then', 'neither', 'us'],
#          ['seemed', 'know', 'what', 'happened.'],
#          ['i', 'cried', 'what', 'would', 'become', 'me.'],
#          ['cried', 'cried', 'as', 'my', 'secret', 'began', 'show.'],
#          ['one', 'day', 'mrs.', 'greene', 'said', 'she', 'understood,'],
#          ['would', 'make', 'no', 'trouble', 'me,'],
#          ['and,', 'being', 'childless,', 'would', 'adopt', 'it.'],
#          ['(he', 'had', 'given', 'her', 'farm', 'be', 'still.)'],
#          ['so', 'she', 'hid', 'house', 'sent', 'out', 'rumors,'],
#          ['as', 'if', 'it', 'were', 'going', 'happen', 'her.'],
#          ['all',
#           'went',
#           'well',
#           'child',
#           'was',
#           'bornthey',
#           'were',
#           'so',
#           'kind',
#           'me.'],
#          ['later', 'i', 'married', 'gus', 'wertman,', 'years', 'passed.'],
#          ['butat',
#           'political',
#           'rallies',
#           'when',
#           'sitters-by',
#           'thought',
#           'i',
#           'was',
#           'crying'],
#          ['at', 'eloquence', 'hamilton', 'greene'],
#          ['that', 'was', 'not', 'it.'],
#          ['no!', 'i', 'wanted', 'say:'],
#          ['thats', 'my', 'son!', 'thats', 'my', 'son!']],
#  '11': [['you', 'never', 'marveled,', 'dullards', 'spoon', 'river,'],
#         ['when', 'chase', 'henry', 'voted', 'against', 'saloons'],
#         ['revenge', 'himself', 'being', 'shut', 'off.'],
#         ['but', 'none', 'you', 'was', 'keen', 'enough'],
#         ['follow', 'my', 'steps,', 'or', 'trace', 'me', 'home'],
#         ['as', 'chases', 'spiritual', 'brother.'],
#         ['do', 'you', 'remember', 'when', 'i', 'fought'],
#         ['bank', 'courthouse', 'ring,'],
#         ['pocketing', 'interest', 'on', 'public', 'funds?'],
#         ['when', 'i', 'fought', 'our', 'leading', 'citizens'],
#         ['making', 'poor', 'pack-horses', 'taxes?'],
#         ['when', 'i', 'fought', 'water', 'works'],
#         ['stealing', 'streets', 'raising', 'rates?'],
#         ['when', 'i', 'fought', 'business', 'men'],
#         ['who', 'fought', 'me', 'these', 'fights?'],
#         ['then', 'do', 'you', 'remember:'],
#         ['that', 'staggering', 'up', 'from', 'wreck', 'defeat,'],
#         ['wreck', 'ruined', 'career,'],
#         ['i', 'slipped', 'from', 'my', 'cloak', 'my', 'last', 'ideal,'],
#         ['hidden', 'from', 'all', 'eyes', 'until', 'then,'],
#         ['like', 'cherished', 'jawbone', 'an', 'ass,'],
#         ['smote', 'bank', 'water', 'works,'],
#         ['business', 'men', 'with', 'prohibition,'],
#         ['made', 'spoon', 'river', 'pay', 'cost'],
#         ['fights', 'that', 'i', 'had', 'lost?']],
#  '110': [['i', 'was', 'only', 'child', 'frances', 'harris', 'virginia'],
#          ['thomas', 'greene', 'kentucky,'],
#          ['valiant', 'honorable', 'blood', 'both.'],
#          ['them', 'i', 'owe', 'all', 'that', 'i', 'became,'],
#          ['judge,', 'member', 'congress,', 'leader', 'state.'],
#          ['from', 'my', 'mother', 'i', 'inherited'],
#          ['vivacity,', 'fancy,', 'language;'],
#          ['from', 'my', 'father', 'will,', 'judgment,', 'logic.'],
#          ['all', 'honor', 'them'],
#          ['what', 'service', 'i', 'was', 'people!']],
#  '111': [['my', 'mind', 'was', 'mirror:'],
#          ['it',
#           'saw',
#           'what',
#           'it',
#           'saw,',
#           'it',
#           'knew',
#           'what',
#           'it',
#           'knew.'],
#          ['youth', 'my', 'mind', 'was', 'just', 'mirror'],
#          ['rapidly', 'flying', 'car,'],
#          ['which', 'catches', 'loses', 'bits', 'landscape.'],
#          ['then', 'time'],
#          ['great', 'scratches', 'were', 'made', 'on', 'mirror,'],
#          ['letting', 'outside', 'world', 'come', 'in,'],
#          ['letting', 'my', 'inner', 'self', 'look', 'out.'],
#          ['this', 'is', 'birth', 'soul', 'sorrow,'],
#          ['birth', 'with', 'gains', 'losses.'],
#          ['mind', 'sees', 'world', 'as', 'thing', 'apart,'],
#          ['soul', 'makes', 'world', 'at', 'one', 'with', 'itself.'],
#          ['mirror', 'scratched', 'reflects', 'no', 'image'],
#          ['this', 'is', 'silence', 'wisdom.']],
#  '112': [['oh', 'many', 'times', 'did', 'ernest', 'hyde', 'i'],
#          ['argue', 'about', 'freedom', 'will.'],
#          ['my', 'favorite', 'metaphor', 'was', 'pricketts', 'cow'],
#          ['roped', 'out', 'grass,', 'free', 'you', 'know', 'as', 'far'],
#          ['as', 'length', 'rope.'],
#          ['one', 'day', 'while', 'arguing', 'so,', 'watching', 'cow'],
#          ['pull', 'at', 'rope', 'get', 'beyond', 'circle'],
#          ['which', 'she', 'had', 'eaten', 'bare,'],
#          ['out', 'came', 'stake,', 'tossing', 'up', 'her', 'head,'],
#          ['she', 'ran', 'us.'],
#          ['whats',
#           'that,',
#           'free-will',
#           'or',
#           'what?',
#           'said',
#           'ernest,',
#           'running.'],
#          ['i', 'fell', 'just', 'as', 'she', 'gored', 'me', 'my', 'death.']],
#  '113': [['not', 'character,', 'not', 'fortitude,', 'not', 'patience'],
#          ['were', 'mine,', 'which', 'village', 'thought', 'i', 'had'],
#          ['bearing', 'with', 'my', 'wife,', 'while', 'preaching', 'on,'],
#          ['doing', 'work', 'god', 'chose', 'me.'],
#          ['i', 'loathed', 'her', 'as', 'termagant,', 'as', 'wanton.'],
#          ['i', 'knew', 'her', 'adulteries,', 'every', 'one.'],
#          ['but', 'even', 'so,', 'if', 'i', 'divorced', 'woman'],
#          ['i', 'must', 'forsake', 'ministry.'],
#          ['therefore', 'do', 'gods', 'work', 'have', 'it', 'crop,'],
#          ['i', 'bore', 'with', 'her!'],
#          ['so', 'lied', 'i', 'myself!'],
#          ['so', 'lied', 'i', 'spoon', 'river!'],
#          ['yet', 'i', 'tried', 'lecturing,', 'ran', 'legislature,'],
#          ['canvassed', 'books,', 'with', 'just', 'thought', 'mind:'],
#          ['if', 'i', 'make', 'money', 'thus,', 'i', 'will', 'divorce', 'her.']],
#  '114': [['secret', 'stars,gravitation.'],
#          ['secret', 'earth,layers', 'rock.'],
#          ['secret', 'soil,to', 'receive', 'seed.'],
#          ['secret', 'seed,the', 'germ.'],
#          ['secret', 'man,the', 'sower.'],
#          ['secret', 'woman,the', 'soil.'],
#          ['my',
#           'secret:',
#           'under',
#           'mound',
#           'that',
#           'you',
#           'shall',
#           'never',
#           'find.']],
#  '115': [['i', 'was', 'crushed', 'between', 'altgeld', 'armour.'],
#          ['i', 'lost', 'many', 'friends,', 'much', 'time', 'money'],
#          ['fighting', 'altgeld', 'whom', 'editor', 'whedon'],
#          ['denounced', 'as', 'candidate', 'gamblers', 'anarchists.'],
#          ['then',
#           'armour',
#           'started',
#           'ship',
#           'dressed',
#           'meat',
#           'spoon',
#           'river,'],
#          ['forcing', 'me', 'shut', 'down', 'my', 'slaughter-house,'],
#          ['my', 'butcher', 'shop', 'went', 'all', 'pieces.'],
#          ['new', 'forces', 'altgeld', 'armour', 'caught', 'me'],
#          ['at', 'same', 'time.'],
#          ['i', 'thought', 'it', 'due', 'me,', 'recoup', 'money', 'i', 'lost'],
#          ['make', 'good', 'friends', 'that', 'left', 'me,'],
#          ['governor', 'appoint', 'me', 'canal', 'commissioner.'],
#          ['instead', 'he', 'appointed', 'whedon', 'spoon', 'river', 'argus,'],
#          ['so', 'i', 'ran', 'legislature', 'was', 'elected.'],
#          ['i', 'said', 'hell', 'with', 'principle', 'sold', 'my', 'vote'],
#          ['on', 'charles', 't.', 'yerkes', 'street-car', 'franchise.'],
#          ['course', 'i', 'was', 'one', 'fellows', 'they', 'caught.'],
#          ['who', 'was', 'it,', 'armour,', 'altgeld', 'or', 'myself'],
#          ['that', 'ruined', 'me?']],
#  '116': [['chaplain', 'army,'],
#          ['chaplain', 'prisons,'],
#          ['an', 'exhorter', 'spoon', 'river,'],
#          ['drunk', 'with', 'divinity,', 'spoon', 'river'],
#          ['yet', 'bringing', 'poor', 'eliza', 'johnson', 'shame,'],
#          ['myself', 'scorn', 'wretchedness.'],
#          ['but',
#           'why',
#           'will',
#           'you',
#           'never',
#           'see',
#           'that',
#           'love',
#           'women,'],
#          ['even', 'love', 'wine,'],
#          ['are',
#           'stimulants',
#           'by',
#           'which',
#           'soul,',
#           'hungering',
#           'divinity,'],
#          ['reaches', 'ecstatic', 'vision'],
#          ['sees', 'celestial', 'outposts?'],
#          ['only', 'after', 'many', 'trials', 'strength,'],
#          ['only', 'when', 'all', 'stimulants', 'fail,'],
#          ['does', 'aspiring', 'soul'],
#          ['by', 'its', 'own', 'sheer', 'power'],
#          ['find', 'divine'],
#          ['by', 'resting', 'upon', 'itself.']],
#  '117': [['yes,', 'here', 'i', 'lie', 'close', 'stunted', 'rose', 'bush'],
#          ['forgotten', 'place', 'near', 'fence'],
#          ['where', 'thickets', 'from', 'sievers', 'woods'],
#          ['have', 'crept', 'over,', 'growing', 'sparsely.'],
#          ['you,', 'you', 'are', 'leader', 'new', 'york,'],
#          ['wife', 'noted', 'millionaire,'],
#          ['name', 'society', 'columns,'],
#          ['beautiful,', 'admired,', 'magnified', 'perhaps'],
#          ['by', 'mirage', 'distance.'],
#          ['you', 'have', 'succeeded,', 'i', 'have', 'failed'],
#          ['eyes', 'world.'],
#          ['you', 'are', 'alive,', 'i', 'am', 'dead.'],
#          ['yet', 'i', 'know', 'that', 'i', 'vanquished', 'your', 'spirit;'],
#          ['i', 'know', 'that', 'lying', 'here', 'far', 'from', 'you,'],
#          ['unheard', 'among', 'your', 'great', 'friends'],
#          ['brilliant', 'world', 'where', 'you', 'move,'],
#          ['i',
#           'am',
#           'really',
#           'unconquerable',
#           'power',
#           'over',
#           'your',
#           'life'],
#          ['that', 'robs', 'it', 'complete', 'triumph.']],
#  '118': [['as', 'democracy,', 'fellow', 'citizens,'],
#          ['are', 'you', 'not', 'prepared', 'admit'],
#          ['that', 'i,', 'who', 'inherited', 'riches', 'was', 'manner', 'born,'],
#          ['was', 'second', 'none', 'spoon', 'river'],
#          ['my', 'devotion', 'cause', 'liberty?'],
#          ['while', 'my', 'contemporary,', 'anthony', 'findlay,'],
#          ['born', 'shanty', 'beginning', 'life'],
#          ['as', 'water', 'carrier', 'section', 'hands,'],
#          ['then', 'becoming', 'section', 'hand', 'when', 'he', 'was', 'grown,'],
#          ['afterwards', 'foreman', 'gang,', 'until', 'he', 'rose'],
#          ['superintendency', 'railroad,'],
#          ['living', 'chicago,'],
#          ['was', 'veritable', 'slave', 'driver,'],
#          ['grinding', 'faces', 'labor,'],
#          ['bitter', 'enemy', 'democracy.'],
#          ['i', 'say', 'you,', 'spoon', 'river,'],
#          ['you,', 'o', 'republic,'],
#          ['beware', 'man', 'who', 'rises', 'power'],
#          ['from', 'one', 'suspender.']],
#  '119': [['both', 'country', 'man,'],
#          ['country', 'as', 'well', 'as', 'man,'],
#          ['tis', 'better', 'be', 'feared', 'than', 'loved.'],
#          ['if', 'this', 'country', 'would', 'rather', 'part'],
#          ['with', 'friendship', 'every', 'nation'],
#          ['than', 'surrender', 'its', 'wealth,'],
#          ['i', 'say', 'man', 'tis', 'worse', 'lose'],
#          ['money', 'than', 'friends.'],
#          ['i', 'rend', 'curtain', 'that', 'hides', 'soul'],
#          ['an', 'ancient', 'aspiration:'],
#          ['when', 'people', 'clamor', 'freedom'],
#          ['they', 'really', 'seek', 'power', 'oer', 'strong.'],
#          ['i,', 'anthony', 'findlay,', 'rising', 'greatness'],
#          ['from', 'humble', 'water', 'carrier,'],
#          ['until', 'i', 'could', 'say', 'thousands', 'come,'],
#          ['say', 'thousands', 'go,'],
#          ['affirm', 'that', 'nation', 'can', 'never', 'be', 'good,'],
#          ['or', 'achieve', 'good,'],
#          ['where', 'strong', 'wise', 'have', 'not', 'rod'],
#          ['use', 'on', 'dull', 'weak.']],
#  '12': [['how', 'does', 'it', 'happen,', 'tell', 'me,'],
#         ['that', 'i', 'who', 'was', 'most', 'erudite', 'lawyers,'],
#         ['who', 'knew', 'blackstone', 'coke'],
#         ['almost', 'by', 'heart,', 'who', 'made', 'greatest', 'speech'],
#         ['court-house', 'ever', 'heard,', 'wrote'],
#         ['brief', 'that', 'won', 'praise', 'justice', 'breese'],
#         ['how', 'does', 'it', 'happen,', 'tell', 'me,'],
#         ['that', 'i', 'lie', 'here', 'unmarked,', 'forgotten,'],
#         ['while', 'chase', 'henry,', 'town', 'drunkard,'],
#         ['has', 'marble', 'block,', 'topped', 'by', 'an', 'urn,'],
#         ['wherein', 'nature,', 'mood', 'ironical,'],
#         ['has', 'sown', 'flowering', 'weed?']],
#  '120': [['neither', 'spite,', 'fellow', 'citizens,'],
#          ['nor', 'forgetfulness', 'shiftlessness,'],
#          ['lawlessness', 'waste'],
#          ['under', 'democracys', 'rule', 'spoon', 'river'],
#          ['made', 'me', 'desert', 'party', 'law', 'order'],
#          ['lead', 'liberal', 'party.'],
#          ['fellow',
#           'citizens!',
#           'i',
#           'saw',
#           'as',
#           'one',
#           'with',
#           'second',
#           'sight'],
#          ['that', 'every', 'man', 'millions', 'men'],
#          ['who', 'give', 'themselves', 'freedom,'],
#          ['fail', 'while', 'freedom', 'fails,'],
#          ['enduring', 'waste', 'lawlessness,'],
#          ['rule', 'weak', 'blind,'],
#          ['dies', 'hope', 'building', 'earth,'],
#          ['like', 'coral', 'insect,', 'temple'],
#          ['stand', 'on', 'at', 'last.'],
#          ['i', 'swear', 'that', 'freedom', 'will', 'wage', 'end'],
#          ['war', 'making', 'every', 'soul'],
#          ['wise', 'strong', 'as', 'fit', 'rule'],
#          ['as', 'platos', 'lofty', 'guardians'],
#          ['world', 'republic', 'girdled!']],
#  '121': [['ye', 'aspiring', 'ones,', 'listen', 'story', 'unknown'],
#          ['who', 'lies', 'here', 'with', 'no', 'stone', 'mark', 'place.'],
#          ['as', 'boy', 'reckless', 'wanton,'],
#          ['wandering', 'with', 'gun', 'hand', 'through', 'forest'],
#          ['near', 'mansion', 'aaron', 'hatfield,'],
#          ['i', 'shot', 'hawk', 'perched', 'on', 'top'],
#          ['dead', 'tree.'],
#          ['he', 'fell', 'with', 'guttural', 'cry'],
#          ['at', 'my', 'feet,', 'his', 'wing', 'broken.'],
#          ['then', 'i', 'put', 'him', 'cage'],
#          ['where',
#           'he',
#           'lived',
#           'many',
#           'days',
#           'cawing',
#           'angrily',
#           'at',
#           'me'],
#          ['when', 'i', 'offered', 'him', 'food.'],
#          ['daily', 'i', 'search', 'realms', 'hades'],
#          ['soul', 'hawk,'],
#          ['that', 'i', 'may', 'offer', 'him', 'friendship'],
#          ['one', 'whom', 'life', 'wounded', 'caged.']],
#  '122': [['youth', 'my', 'wings', 'were', 'strong', 'tireless,'],
#          ['but', 'i', 'did', 'not', 'know', 'mountains.'],
#          ['age', 'i', 'knew', 'mountains'],
#          ['but',
#           'my',
#           'weary',
#           'wings',
#           'could',
#           'not',
#           'follow',
#           'my',
#           'vision'],
#          ['genius', 'is', 'wisdom', 'youth.']],
#  '123': [['after', 'you', 'have', 'enriched', 'your', 'soul'],
#          ['highest', 'point,'],
#          ['with',
#           'books,',
#           'thought,',
#           'suffering,',
#           'understanding',
#           'many',
#           'personalities,'],
#          ['power', 'interpret', 'glances,', 'silences,'],
#          ['pauses', 'momentous', 'transformations,'],
#          ['genius', 'divination', 'prophecy;'],
#          ['so', 'that', 'you', 'feel', 'able', 'at', 'times', 'hold', 'world'],
#          ['hollow', 'your', 'hand;'],
#          ['then,', 'if,', 'by', 'crowding', 'so', 'many', 'powers'],
#          ['into', 'compass', 'your', 'soul,'],
#          ['your', 'soul', 'takes', 'fire,'],
#          ['conflagration', 'your', 'soul'],
#          ['evil', 'world', 'is', 'lighted', 'up', 'made', 'clear'],
#          ['be', 'thankful', 'if', 'that', 'hour', 'supreme', 'vision'],
#          ['life', 'does', 'not', 'fiddle.'],
#          ['*author', 'spooniad.', '15']],
#  '124': [['i', 'was', 'widow', 'mcfarlane,'],
#          ['weaver', 'carpets', 'all', 'village.'],
#          ['i', 'pity', 'you', 'still', 'at', 'loom', 'life,'],
#          ['you', 'who', 'are', 'singing', 'shuttle'],
#          ['lovingly', 'watching', 'work', 'your', 'hands,'],
#          ['if', 'you', 'reach', 'day', 'hate,', 'terrible', 'truth.'],
#          ['cloth', 'life', 'is', 'woven,', 'you', 'know,'],
#          ['pattern', 'hidden', 'under', 'loom'],
#          ['pattern', 'you', 'never', 'see!'],
#          ['you', 'weave', 'high-hearted,', 'singing,', 'singing,'],
#          ['you', 'guard', 'threads', 'love', 'friendship'],
#          ['noble', 'figures', 'gold', 'purple.'],
#          ['long', 'after', 'other', 'eyes', 'can', 'see'],
#          ['you', 'have', 'woven', 'moon-white', 'strip', 'cloth,'],
#          ['you', 'laugh', 'your', 'strength,', 'hope', 'oerlays', 'it'],
#          ['with', 'shapes', 'love', 'beauty.'],
#          ['loom', 'stops', 'short!', 'patterns', 'out!'],
#          ['youre', 'alone', 'room!', 'you', 'have', 'woven', 'shroud!'],
#          ['hate', 'it', 'lays', 'you', 'it!']],
#  '125': [['press', 'spoon', 'river', 'clarion', 'was', 'wrecked,'],
#          ['i', 'was', 'tarred', 'feathered,'],
#          ['publishing',
#           'this',
#           'on',
#           'day',
#           'anarchists',
#           'were',
#           'hanged',
#           'chicago:'],
#          ['i', 'saw', 'beautiful', 'woman', 'with', 'bandaged', 'eyes'],
#          ['standing', 'on', 'steps', 'marble', 'temple.'],
#          ['great', 'multitudes', 'passed', 'front', 'her,'],
#          ['lifting', 'their', 'faces', 'her', 'imploringly.'],
#          ['her', 'left', 'hand', 'she', 'held', 'sword.'],
#          ['she', 'was', 'brandishing', 'sword,'],
#          ['sometimes', 'striking', 'child,', 'again', 'laborer,'],
#          ['again', 'slinking', 'woman,', 'again', 'lunatic.'],
#          ['her', 'right', 'hand', 'she', 'held', 'scale;'],
#          ['into', 'scale', 'pieces', 'gold', 'were', 'tossed'],
#          ['by', 'those', 'who', 'dodged', 'strokes', 'sword.'],
#          ['man', 'black', 'gown', 'read', 'from', 'manuscript:'],
#          ['she', 'is', 'no', 'respecter', 'persons.'],
#          ['then', 'youth', 'wearing', 'red', 'cap'],
#          ['leaped', 'her', 'side', 'snatched', 'away', 'bandage.'],
#          ['lo,', 'lashes', 'had', 'been', 'eaten', 'away'],
#          ['from', 'oozy', 'eye-lids;'],
#          ['eye-balls', 'were', 'seared', 'with', 'milky', 'mucus;'],
#          ['madness', 'dying', 'soul'],
#          ['was', 'written', 'on', 'her', 'face'],
#          ['but', 'multitude', 'saw', 'why', 'she', 'wore', 'bandage.']],
#  '126': [['be', 'able', 'see', 'every', 'side', 'every', 'question'],
#          ['be',
#           'on',
#           'every',
#           'side,',
#           'be',
#           'everything,',
#           'be',
#           'nothing',
#           'long;'],
#          ['pervert', 'truth,', 'ride', 'it', 'purpose,'],
#          ['use', 'great', 'feelings', 'passions', 'human', 'family'],
#          ['base', 'designs,', 'cunning', 'ends,'],
#          ['wear', 'mask', 'like', 'greeks', 'actors'],
#          ['your', 'eight-page', 'paperbehind', 'which', 'you', 'huddle,'],
#          ['bawling', 'through', 'megaphone', 'big', 'type:'],
#          ['this', 'is', 'i,', 'giant.'],
#          ['thereby', 'also', 'living', 'life', 'sneak-thief,'],
#          ['poisoned', 'with', 'anonymous', 'words'],
#          ['your', 'clandestine', 'soul.'],
#          ['scratch', 'dirt', 'over', 'scandal', 'money,'],
#          ['exhume', 'it', 'winds', 'revenge,'],
#          ['or', 'sell', 'papers,'],
#          ['crushing', 'reputations,', 'or', 'bodies,', 'if', 'need', 'be,'],
#          ['win', 'at', 'any', 'cost,', 'save', 'your', 'own', 'life.'],
#          ['glory', 'demoniac', 'power,', 'ditching', 'civilization,'],
#          ['as', 'paranoiac', 'boy', 'puts', 'log', 'on', 'track'],
#          ['derails', 'express', 'train.'],
#          ['be', 'an', 'editor,', 'as', 'i', 'was.'],
#          ['then', 'lie', 'here', 'close', 'by', 'river', 'over', 'place'],
#          ['where', 'sewage', 'flows', 'from', 'village,'],
#          ['empty', 'cans', 'garbage', 'are', 'dumped,'],
#          ['abortions', 'are', 'hidden.']],
#  '127': [['rhodes', 'slave!', 'selling', 'shoes', 'gingham,'],
#          ['flour', 'bacon,', 'overalls,', 'clothing,', 'all', 'day', 'long'],
#          ['fourteen', 'hours', 'day', 'three', 'hundred', 'thirteen', 'days'],
#          ['more', 'than', 'twenty', 'years.'],
#          ['saying', 'yesm', 'yes,', 'sir', 'thank', 'you'],
#          ['thousand', 'times', 'day,', 'all', 'fifty', 'dollars', 'month.'],
#          ['living', 'this', 'stinking', 'room', 'rattle-trap', 'commercial.'],
#          ['compelled', 'go', 'sunday', 'school,', 'listen'],
#          ['rev.', 'abner', 'peet', 'one', 'hundred', 'four', 'times', 'year'],
#          ['more', 'than', 'an', 'hour', 'at', 'time,'],
#          ['because', 'thomas', 'rhodes', 'ran', 'church'],
#          ['as', 'well', 'as', 'store', 'bank.'],
#          ['so',
#           'while',
#           'i',
#           'was',
#           'tying',
#           'my',
#           'neck-tie',
#           'that',
#           'morning'],
#          ['i', 'suddenly', 'saw', 'myself', 'glass:'],
#          ['my', 'hair', 'all', 'gray,', 'my', 'face', 'like', 'sodden', 'pie.'],
#          ['so', 'i', 'cursed', 'cursed:', 'you', 'damned', 'old', 'thing!'],
#          ['you', 'cowardly', 'dog!', 'you', 'rotten', 'pauper!'],
#          ['you', 'rhodes', 'slave!', 'till', 'roger', 'baughman'],
#          ['thought', 'i', 'was', 'having', 'fight', 'with', 'some', 'one,'],
#          ['looked', 'through', 'transom', 'just', 'time'],
#          ['see', 'me', 'fall', 'on', 'floor', 'heap'],
#          ['from', 'broken', 'vein', 'my', 'head.']],
#  '128': [['sudden', 'death', 'eugene', 'carman'],
#          ['put', 'me', 'line', 'be', 'promoted', 'fifty', 'dollars', 'month,'],
#          ['i', 'told', 'my', 'wife', 'children', 'that', 'night.'],
#          ['but', 'it', 'didnt', 'come,', 'so', 'i', 'thought'],
#          ['old', 'rhodes', 'suspected', 'me', 'stealing'],
#          ['blankets', 'i', 'took', 'sold', 'on', 'side'],
#          ['money', 'pay', 'doctors', 'bill', 'my', 'little', 'girl.'],
#          ['then', 'like', 'bolt', 'old', 'rhodes', 'accused', 'me,'],
#          ['promised', 'me', 'mercy', 'my', 'familys', 'sake'],
#          ['if', 'i', 'confessed,', 'so', 'i', 'confessed,'],
#          ['begged', 'him', 'keep', 'it', 'out', 'papers,'],
#          ['i', 'asked', 'editors,', 'too.'],
#          ['that', 'night', 'at', 'home', 'constable', 'took', 'me'],
#          ['every', 'paper,', 'except', 'clarion,'],
#          ['wrote', 'me', 'up', 'as', 'thief'],
#          ['because', 'old', 'rhodes', 'was', 'an', 'advertiser'],
#          ['wanted', 'make', 'an', 'example', 'me.'],
#          ['oh!', 'well,', 'you', 'know', 'how', 'children', 'cried,'],
#          ['how', 'my', 'wife', 'pitied', 'hated', 'me,'],
#          ['how', 'i', 'came', 'lie', 'here.']],
#  '129': [['vegetarian,',
#           'non-resistant,',
#           'free-thinker,',
#           'ethics',
#           'christian;'],
#          ['orator', 'apt', 'at', 'rhine-stone', 'rhythm', 'ingersoll;'],
#          ['carnivorous,', 'avenger,', 'believer', 'pagan;'],
#          ['continent,', 'promiscuous,', 'changeable,', 'treacherous,', 'vain,'],
#          ['proud,',
#           'with',
#           'pride',
#           'that',
#           'makes',
#           'struggle',
#           'thing',
#           'laughter;'],
#          ['with',
#           'heart',
#           'cored',
#           'out',
#           'by',
#           'worm',
#           'theatric',
#           'despair;'],
#          ['wearing', 'coat', 'indifference', 'hide', 'shame', 'defeat;'],
#          ['i,', 'child', 'abolitionist', 'idealism'],
#          ['sort', 'brand', 'birth', 'half-and-half.'],
#          ['what', 'other', 'thing', 'could', 'happen', 'when', 'i', 'defended'],
#          ['patriot', 'scamps', 'who', 'burned', 'court', 'house,'],
#          ['that', 'spoon', 'river', 'might', 'have', 'new', 'one,'],
#          ['than',
#           'plead',
#           'them',
#           'guilty?',
#           'when',
#           'kinsey',
#           'keene',
#           'drove',
#           'through'],
#          ['card-board', 'mask', 'my', 'life', 'with', 'spear', 'light,'],
#          ['what',
#           'could',
#           'i',
#           'do',
#           'but',
#           'slink',
#           'away,',
#           'like',
#           'beast',
#           'myself'],
#          ['which', 'i', 'raised', 'from', 'whelp,', 'corner', 'growl.'],
#          ['pyramid', 'my', 'life', 'was', 'nought', 'but', 'dune,'],
#          ['barren', 'formless,', 'spoiled', 'at', 'last', 'by', 'storm.']],
#  '13': [['your', 'attention,', 'thomas', 'rhodes,', 'president', 'bank;'],
#         ['coolbaugh', 'whedon,', 'editor', 'argus;'],
#         ['rev.', 'peet,', 'pastor', 'leading', 'church;'],
#         ['a.', 'd.', 'blood,', 'several', 'times', 'mayor', 'spoon', 'river;'],
#         ['finally', 'all', 'you,', 'members', 'social', 'purity', 'club'],
#         ['your', 'attention', 'cambronnes', 'dying', 'words,'],
#         ['standing', 'with', 'heroic', 'remnant'],
#         ['napoleons', 'guard', 'on', 'mount', 'saint', 'jean'],
#         ['at', 'battle', 'field', 'waterloo,'],
#         ['when', 'maitland,', 'englishman,', 'called', 'them:'],
#         ['surrender,', 'brave', 'frenchmen!'],
#         ['there',
#          'at',
#          'close',
#          'day',
#          'with',
#          'battle',
#          'hopelessly',
#          'lost,'],
#         ['hordes', 'men', 'no', 'longer', 'army'],
#         ['great', 'napoleon'],
#         ['streamed', 'from', 'field', 'like', 'ragged', 'strips'],
#         ['thunder', 'clouds', 'storm.'],
#         ['well,', 'what', 'cambronne', 'said', 'maitland'],
#         ['ere', 'english', 'fire', 'made', 'smooth', 'brow', 'hill'],
#         ['against', 'sinking', 'light', 'day'],
#         ['say', 'i', 'you,', 'all', 'you,'],
#         ['you,', 'o', 'world.'],
#         ['i', 'charge', 'you', 'carve', 'it'],
#         ['upon', 'my', 'stone.']],
#  '130': [['everyone', 'laughed', 'at', 'col.', 'prichard'],
#          ['buying', 'an', 'engine', 'so', 'powerful'],
#          ['that', 'it', 'wrecked', 'itself,', 'wrecked', 'grinder'],
#          ['he', 'ran', 'it', 'with.'],
#          ['but', 'here', 'is', 'joke', 'cosmic', 'size:'],
#          ['urge', 'nature', 'that', 'made', 'man'],
#          ['evolve', 'from', 'his', 'brain', 'spiritual', 'life'],
#          ['oh', 'miracle', 'world!'],
#          ['very', 'same', 'brain', 'with', 'which', 'ape', 'wolf'],
#          ['get', 'food', 'shelter', 'procreate', 'themselves.'],
#          ['nature', 'has', 'made', 'man', 'do', 'this,'],
#          ['world', 'where', 'she', 'gives', 'him', 'nothing', 'do'],
#          ['after', 'all(though', 'strength', 'his', 'soul', 'goes', 'round'],
#          ['futile', 'waste', 'power,'],
#          ['gear', 'itself', 'mills', 'gods)'],
#          ['but', 'get', 'food', 'shelter', 'procreate', 'himself!']],
#  '131': [['all', 'they', 'said', 'was', 'true:'],
#          ['i', 'wrecked', 'my', 'fathers', 'bank', 'with', 'my', 'loans'],
#          ['dabble', 'wheat;', 'but', 'this', 'was', 'true'],
#          ['i', 'was', 'buying', 'wheat', 'him', 'as', 'well,'],
#          ['who', 'couldnt', 'margin', 'deal', 'his', 'name'],
#          ['because', 'his', 'church', 'relationship.'],
#          ['while', 'george', 'reece', 'was', 'serving', 'his', 'term'],
#          ['i', 'chased', 'will-o-the-wisp', 'women,'],
#          ['mockery', 'wine', 'new', 'york.'],
#          ['its', 'deathly', 'sicken', 'wine', 'women'],
#          ['when', 'nothing', 'else', 'is', 'left', 'life.'],
#          ['but', 'suppose', 'your', 'head', 'is', 'gray,', 'bowed'],
#          ['on', 'table', 'covered', 'with', 'acrid', 'stubs'],
#          ['cigarettes', 'empty', 'glasses,'],
#          ['knock', 'is', 'heard,', 'you', 'know', 'its', 'knock'],
#          ['so', 'long', 'drowned', 'out', 'by', 'popping', 'corks'],
#          ['pea-cock', 'screams', 'demireps'],
#          ['you', 'look', 'up,', 'theres', 'your', 'theft,'],
#          ['who', 'waited', 'until', 'your', 'head', 'was', 'gray,'],
#          ['your', 'heart', 'skipped', 'beats', 'say', 'you:'],
#          ['game', 'is', 'ended.', 'ive', 'called', 'you,'],
#          ['go', 'out', 'on', 'broadway', 'be', 'run', 'over,'],
#          ['theyll', 'ship', 'you', 'back', 'spoon', 'river.']],
#  '132': [['it', 'was', 'just', 'like', 'everything', 'else', 'life:'],
#          ['something', 'outside', 'myself', 'drew', 'me', 'down,'],
#          ['my', 'own', 'strength', 'never', 'failed', 'me.'],
#          ['why,', 'there', 'was', 'time', 'i', 'earned', 'money'],
#          ['with', 'which', 'go', 'away', 'school,'],
#          ['my', 'father', 'suddenly', 'needed', 'help'],
#          ['i', 'had', 'give', 'him', 'all', 'it.'],
#          ['just', 'so', 'it', 'went', 'till', 'i', 'ended', 'up'],
#          ['man-of-all-work', 'spoon', 'river.'],
#          ['thus', 'when', 'i', 'got', 'water-tower', 'cleaned,'],
#          ['they', 'hauled', 'me', 'up', 'seventy', 'feet,'],
#          ['i', 'unhooked', 'rope', 'from', 'my', 'waist,'],
#          ['laughingly', 'flung', 'my', 'giant', 'arms'],
#          ['over', 'smooth', 'steel', 'lips', 'top', 'tower'],
#          ['but', 'they', 'slipped', 'from', 'treacherous', 'slime,'],
#          ['down,', 'down,', 'down,', 'i', 'plunged'],
#          ['through', 'bellowing', 'darkness!']],
#  '133': [['i',
#           'was',
#           'sick,',
#           'but',
#           'more',
#           'than',
#           'that,',
#           'i',
#           'was',
#           'mad'],
#          ['at', 'crooked', 'police,', 'crooked', 'game', 'life.'],
#          ['so', 'i', 'wrote', 'chief', 'police', 'at', 'peoria:'],
#          ['i', 'am', 'here', 'my', 'girlhood', 'home', 'spoon', 'river,'],
#          ['gradually', 'wasting', 'away.'],
#          ['but', 'come', 'take', 'me,', 'i', 'killed', 'son'],
#          ['merchant', 'prince,', 'madam', 'lous,'],
#          ['papers', 'that', 'said', 'he', 'killed', 'himself'],
#          ['his', 'home', 'while', 'cleaning', 'hunting', 'gun'],
#          ['lied', 'like', 'devil', 'hush', 'up', 'scandal,'],
#          ['bribe', 'advertising.'],
#          ['my', 'room', 'i', 'shot', 'him,', 'at', 'madam', 'lous,'],
#          ['because', 'he', 'knocked', 'me', 'down', 'when', 'i', 'said'],
#          ['that,', 'spite', 'all', 'money', 'he', 'had,'],
#          ['id', 'see', 'my', 'lover', 'that', 'night.']],
#  '134': [['i', 'staggered', 'on', 'through', 'darkness,'],
#          ['there', 'was', 'hazy', 'sky,', 'few', 'stars'],
#          ['which', 'i', 'followed', 'as', 'best', 'i', 'could.'],
#          ['it', 'was', 'nine', 'oclock,', 'i', 'was', 'trying', 'get', 'home.'],
#          ['but', 'somehow', 'i', 'was', 'lost,'],
#          ['though', 'really', 'keeping', 'road.'],
#          ['then', 'i', 'reeled', 'through', 'gate', 'into', 'yard,'],
#          ['called', 'at', 'top', 'my', 'voice:'],
#          ['oh,', 'fiddler!', 'oh,', 'mr.', 'jones!'],
#          ['(i',
#           'thought',
#           'it',
#           'was',
#           'his',
#           'house',
#           'he',
#           'would',
#           'show',
#           'me',
#           'way',
#           'home.)'],
#          ['but', 'who', 'should', 'step', 'out', 'but', 'a.', 'd.', 'blood,'],
#          ['his', 'night', 'shirt,', 'waving', 'stick', 'wood,'],
#          ['roaring', 'about', 'cursed', 'saloons,'],
#          ['criminals', 'they', 'made?'],
#          ['you', 'drunken', 'oscar', 'hummel,', 'he', 'said,'],
#          ['as', 'i', 'stood', 'there', 'weaving', 'fro,'],
#          ['taking', 'blows', 'from', 'stick', 'his', 'hand'],
#          ['till', 'i', 'dropped', 'down', 'dead', 'at', 'his', 'feet.']],
#  '135': [['she', 'loved', 'me.', 'oh!', 'how', 'she', 'loved', 'me!'],
#          ['i', 'never', 'had', 'chance', 'escape'],
#          ['from', 'day', 'she', 'first', 'saw', 'me.'],
#          ['but', 'then', 'after', 'we', 'were', 'married', 'i', 'thought'],
#          ['she', 'might', 'prove', 'her', 'mortality', 'let', 'me', 'out,'],
#          ['or', 'she', 'might', 'divorce', 'me.'],
#          ['but', 'few', 'die,', 'none', 'resign.'],
#          ['then', 'i', 'ran', 'away', 'was', 'gone', 'year', 'on', 'lark.'],
#          ['but',
#           'she',
#           'never',
#           'complained.',
#           'she',
#           'said',
#           'all',
#           'would',
#           'be',
#           'well,'],
#          ['that', 'i', 'would', 'return.', 'i', 'did', 'return.'],
#          ['i', 'told', 'her', 'that', 'while', 'taking', 'row', 'boat'],
#          ['i', 'had', 'been', 'captured', 'near', 'van', 'buren', 'street'],
#          ['by', 'pirates', 'on', 'lake', 'michigan,'],
#          ['kept', 'chains,', 'so', 'i', 'could', 'not', 'write', 'her.'],
#          ['she', 'cried', 'kissed', 'me,', 'said', 'it', 'was', 'cruel,'],
#          ['outrageous,', 'inhuman!'],
#          ['i', 'then', 'concluded', 'our', 'marriage'],
#          ['was', 'divine', 'dispensation'],
#          ['could', 'not', 'be', 'dissolved,'],
#          ['except', 'by', 'death.'],
#          ['i', 'was', 'right.']],
#  '136': [['he', 'ran', 'away', 'was', 'gone', 'year.'],
#          ['when', 'he', 'came', 'home', 'he', 'told', 'me', 'silly', 'story'],
#          ['being', 'kidnapped', 'by', 'pirates', 'on', 'lake', 'michigan'],
#          ['kept', 'chains', 'so', 'he', 'could', 'not', 'write', 'me.'],
#          ['i',
#           'pretended',
# ...
#         ['ballades', 'by', 'score', 'with', 'same', 'old', 'thought:'],
#         ['snows', 'roses', 'yesterday', 'are', 'vanished;'],
#         ['what', 'is', 'love', 'but', 'rose', 'that', 'fades?'],
#         ['life', 'all', 'around', 'me', 'here', 'village:'],
#         ['tragedy,', 'comedy,', 'valor', 'truth,'],
#         ['courage,', 'constancy,', 'heroism,', 'failure'],
#         ['all', 'loom,', 'oh', 'what', 'patterns!'],
#         ['woodlands,', 'meadows,', 'streams', 'rivers'],
#         ['blind', 'all', 'it', 'all', 'my', 'life', 'long.'],
#         ['triolets,', 'villanelles,', 'rondels,', 'rondeaus,'],
#         ['seeds', 'dry', 'pod,', 'tick,', 'tick,', 'tick,'],
#         ['tick,', 'tick,', 'tick,', 'what', 'little', 'iambics,'],
#         ['while', 'homer', 'whitman', 'roared', 'pines?']],
#  '87': [['almost', 'shell', 'woman', 'after', 'surgeons', 'knife!'],
#         ['almost', 'year', 'creep', 'back', 'into', 'strength,'],
#         ['till', 'dawn', 'our', 'wedding', 'decennial'],
#         ['found', 'me', 'my', 'seeming', 'self', 'again.'],
#         ['we', 'walked', 'forest', 'together,'],
#         ['by', 'path', 'soundless', 'moss', 'turf.'],
#         ['but', 'i', 'could', 'not', 'look', 'your', 'eyes,'],
#         ['you', 'could', 'not', 'look', 'my', 'eyes,'],
#         ['such',
#          'sorrow',
#          'was',
#          'oursthe',
#          'beginning',
#          'gray',
#          'your',
#          'hair,'],
#         ['i', 'but', 'shell', 'myself.'],
#         ['what', 'did', 'we', 'talk', 'of?sky', 'water,'],
#         ['anything,', 'most,', 'hide', 'our', 'thoughts.'],
#         ['then', 'your', 'gift', 'wild', 'roses,'],
#         ['set', 'on', 'table', 'grace', 'our', 'dinner.'],
#         ['poor', 'heart,', 'how', 'bravely', 'you', 'struggled'],
#         ['imagine', 'live', 'remembered', 'rapture!'],
#         ['then', 'my', 'spirit', 'drooped', 'as', 'night', 'came', 'on,'],
#         ['you', 'left', 'me', 'alone', 'my', 'room', 'while,'],
#         ['as', 'you', 'did', 'when', 'i', 'was', 'bride,', 'poor', 'heart.'],
#         ['i', 'looked', 'mirror', 'something', 'said:'],
#         ['one',
#          'should',
#          'be',
#          'all',
#          'dead',
#          'when',
#          'one',
#          'is',
#          'half-dead'],
#         ['nor', 'ever', 'mock', 'life,', 'nor', 'ever', 'cheat', 'love.'],
#         ['i', 'did', 'it', 'looking', 'there', 'mirror'],
#         ['dear,', 'have', 'you', 'ever', 'understood?']],
#  '88': [['reverend', 'wiley', 'advised', 'me', 'not', 'divorce', 'him'],
#         ['sake', 'children,'],
#         ['judge', 'somers', 'advised', 'him', 'same.'],
#         ['so', 'we', 'stuck', 'end', 'path.'],
#         ['but', 'two', 'children', 'thought', 'he', 'was', 'right,'],
#         ['two', 'children', 'thought', 'i', 'was', 'right.'],
#         ['two', 'who', 'sided', 'with', 'him', 'blamed', 'me,'],
#         ['two', 'who', 'sided', 'with', 'me', 'blamed', 'him,'],
#         ['they', 'grieved', 'one', 'they', 'sided', 'with.'],
#         ['all', 'were', 'torn', 'with', 'guilt', 'judging,'],
#         ['tortured', 'soul', 'because', 'they', 'could', 'not', 'admire'],
#         ['equally', 'him', 'me.'],
#         ['now',
#          'every',
#          'gardener',
#          'knows',
#          'that',
#          'plants',
#          'grown',
#          'cellars'],
#         ['or', 'under', 'stones', 'are', 'twisted', 'yellow', 'weak.'],
#         ['no', 'mother', 'would', 'let', 'her', 'baby', 'suck'],
#         ['diseased', 'milk', 'from', 'her', 'breast.'],
#         ['yet', 'preachers', 'judges', 'advise', 'raising', 'souls'],
#         ['where', 'there', 'is', 'no', 'sunlight,', 'but', 'only', 'twilight,'],
#         ['no', 'warmth,', 'but', 'only', 'dampness', 'cold'],
#         ['preachers', 'judges!']],
#  '89': [['this', 'generation', 'i', 'would', 'say:'],
#         ['memorize', 'some', 'bit', 'verse', 'truth', 'or', 'beauty.'],
#         ['it', 'may', 'serve', 'turn', 'your', 'life.'],
#         ['my', 'husband', 'had', 'nothing', 'do'],
#         ['with', 'fall', 'bankhe', 'was', 'only', 'cashier.'],
#         ['wreck', 'was', 'due', 'president,', 'thomas', 'rhodes,'],
#         ['his', 'vain,', 'unscrupulous', 'son.'],
#         ['yet', 'my', 'husband', 'was', 'sent', 'prison,'],
#         ['i', 'was', 'left', 'with', 'children,'],
#         ['feed', 'clothe', 'school', 'them.'],
#         ['i', 'did', 'it,', 'sent', 'them', 'forth'],
#         ['into', 'world', 'all', 'clean', 'strong,'],
#         ['all', 'through', 'wisdom', 'pope,', 'poet:'],
#         ['act', 'well', 'your', 'part,', 'there', 'all', 'honor', 'lies.']],
#  '9': [['you', 'praise', 'my', 'self-sacrifice,', 'spoon', 'river,'],
#        ['rearing', 'irene', 'mary,'],
#        ['orphans', 'my', 'older', 'sister!'],
#        ['you', 'censure', 'irene', 'mary'],
#        ['their', 'contempt', 'me!'],
#        ['but', 'praise', 'not', 'my', 'self-sacrifice,'],
#        ['censure', 'not', 'their', 'contempt;'],
#        ['i', 'reared', 'them,', 'i', 'cared', 'them,', 'true', 'enough!'],
#        ['but', 'i', 'poisoned', 'my', 'benefactions'],
#        ['with', 'constant', 'reminders', 'their', 'dependence.']],
#  '90': [['i', 'preached', 'four', 'thousand', 'sermons,'],
#         ['i', 'conducted', 'forty', 'revivals,'],
#         ['baptized', 'many', 'converts.'],
#         ['yet', 'no', 'deed', 'mine'],
#         ['shines', 'brighter', 'memory', 'world,'],
#         ['none', 'is', 'treasured', 'more', 'by', 'me:'],
#         ['look', 'how', 'i', 'saved', 'blisses', 'from', 'divorce,'],
#         ['kept', 'children', 'free', 'from', 'that', 'disgrace,'],
#         ['grow', 'up', 'into', 'moral', 'men', 'women,'],
#         ['happy', 'themselves,', 'credit', 'village.']],
#  '91': [['this', 'i', 'saw', 'with', 'my', 'own', 'eyes:'],
#         ['cliff-swallow'],
#         ['made', 'her', 'nest', 'hole', 'high', 'clay-bank'],
#         ['there', 'near', 'millers', 'ford.'],
#         ['but', 'no', 'sooner', 'were', 'young', 'hatched'],
#         ['than', 'snake', 'crawled', 'up', 'nest'],
#         ['devour', 'brood.'],
#         ['then', 'mother', 'swallow', 'with', 'swift', 'flutterings'],
#         ['shrill', 'cries'],
#         ['fought', 'at', 'snake,'],
#         ['blinding', 'him', 'with', 'beat', 'her', 'wings,'],
#         ['until', 'he,', 'wriggling', 'rearing', 'his', 'head,'],
#         ['fell', 'backward', 'down', 'bank'],
#         ['into', 'spoon', 'river', 'was', 'drowned.'],
#         ['scarcely', 'an', 'hour', 'passed'],
#         ['until', 'shrike'],
#         ['impaled', 'mother', 'swallow', 'on', 'thorn.'],
#         ['as', 'myself', 'i', 'overcame', 'my', 'lower', 'nature'],
#         ['only', 'be', 'destroyed', 'by', 'my', 'brothers', 'ambition.']],
#  '92': [['i', 'had', 'no', 'objection', 'at', 'all'],
#         ['selling', 'my', 'household', 'effects', 'at', 'auction'],
#         ['on', 'village', 'square.'],
#         ['it', 'gave', 'my', 'beloved', 'flock', 'chance'],
#         ['get', 'something', 'which', 'had', 'belonged', 'me'],
#         ['memorial.'],
#         ['but', 'that', 'trunk', 'which', 'was', 'struck', 'off'],
#         ['burchard,', 'grog-keeper!'],
#         ['did', 'you', 'know', 'it', 'contained', 'manuscripts'],
#         ['lifetime', 'sermons?'],
#         ['he', 'burned', 'them', 'as', 'waste', 'paper.']],
#  '93': [['my', 'valiant', 'fight!', 'i', 'call', 'it', 'valiant,'],
#         ['with', 'my', 'fathers', 'beliefs', 'from', 'old', 'virginia:'],
#         ['hating', 'slavery,', 'but', 'no', 'less', 'war.'],
#         ['i,', 'full', 'spirit,', 'audacity,', 'courage'],
#         ['thrown', 'into', 'life', 'here', 'spoon', 'river,'],
#         ['with',
#          'its',
#          'dominant',
#          'forces',
#          'drawn',
#          'from',
#          'new',
#          'england,'],
#         ['republicans,', 'calvinists,', 'merchants,', 'bankers,'],
#         ['hating', 'me,', 'yet', 'fearing', 'my', 'arm.'],
#         ['with', 'wife', 'children', 'heavy', 'carry'],
#         ['yet', 'fruits', 'my', 'very', 'zest', 'life.'],
#         ['stealing', 'odd', 'pleasures', 'that', 'cost', 'me', 'prestige,'],
#         ['reaping', 'evils', 'i', 'had', 'not', 'sown;'],
#         ['foe', 'church', 'with', 'its', 'charnel', 'dankness,'],
#         ['friend', 'human', 'touch', 'tavern;'],
#         ['tangled', 'with', 'fates', 'all', 'alien', 'me,'],
#         ['deserted', 'by', 'hands', 'i', 'called', 'my', 'own.'],
#         ['then', 'just', 'as', 'i', 'felt', 'my', 'giant', 'strength'],
#         ['short', 'breath,', 'behold', 'my', 'children'],
#         ['had', 'wound', 'their', 'lives', 'stranger', 'gardens'],
#         ['i', 'stood', 'alone,', 'as', 'i', 'started', 'alone!'],
#         ['my', 'valiant', 'life!', 'i', 'died', 'on', 'my', 'feet,'],
#         ['facing', 'silencefacing', 'prospect'],
#         ['that', 'no', 'one', 'would', 'know', 'fight', 'i', 'made.']],
#  '94': [['suppose', 'you', 'stood', 'just', 'five', 'feet', 'two,'],
#         ['had', 'worked', 'your', 'way', 'as', 'grocery', 'clerk,'],
#         ['studying', 'law', 'by', 'candle', 'light'],
#         ['until', 'you', 'became', 'an', 'attorney', 'at', 'law?'],
#         ['then', 'suppose', 'through', 'your', 'diligence,'],
#         ['regular', 'church', 'attendance,'],
#         ['you', 'became', 'attorney', 'thomas', 'rhodes,'],
#         ['collecting', 'notes', 'mortgages,'],
#         ['representing', 'all', 'widows'],
#         ['probate', 'court?', 'through', 'it', 'all'],
#         ['they',
#          'jeered',
#          'at',
#          'your',
#          'size,',
#          'laughed',
#          'at',
#          'your',
#          'clothes'],
#         ['your', 'polished', 'boots?', 'then', 'suppose'],
#         ['you', 'became', 'county', 'judge?'],
#         ['jefferson', 'howard', 'kinsey', 'keene,'],
#         ['harmon', 'whitney,', 'all', 'giants'],
#         ['who', 'had', 'sneered', 'at', 'you,', 'were', 'forced', 'stand'],
#         ['before', 'bar', 'say', 'your', 'honor'],
#         ['well,', 'dont', 'you', 'think', 'it', 'was', 'natural'],
#         ['that', 'i', 'made', 'it', 'hard', 'them?']],
#  '95': [['jonas', 'keene', 'thought', 'his', 'lot', 'hard', 'one'],
#         ['because', 'his', 'children', 'were', 'all', 'failures.'],
#         ['but', 'i', 'know', 'fate', 'more', 'trying', 'than', 'that:'],
#         ['it',
#          'is',
#          'be',
#          'failure',
#          'while',
#          'your',
#          'children',
#          'are',
#          'successes.'],
#         ['i', 'raised', 'brood', 'eagles'],
#         ['who', 'flew', 'away', 'at', 'last,', 'leaving', 'me'],
#         ['crow', 'on', 'abandoned', 'bough.'],
#         ['then,', 'with', 'ambition', 'prefix', 'honorable', 'my', 'name,'],
#         ['thus', 'win', 'my', 'childrens', 'admiration,'],
#         ['i', 'ran', 'county', 'superintendent', 'schools,'],
#         ['spending', 'my', 'accumulations', 'winand', 'lost.'],
#         ['that',
#          'fall',
#          'my',
#          'daughter',
#          'received',
#          'first',
#          'prize',
#          'paris'],
#         ['her', 'picture,', 'entitled,', 'old', 'mill'],
#         ['(it',
#          'was',
#          'water',
#          'mill',
#          'before',
#          'henry',
#          'wilkin',
#          'put',
#          'steam.)'],
#         ['feeling',
#          'that',
#          'i',
#          'was',
#          'not',
#          'worthy',
#          'her',
#          'finished',
#          'me.']],
#  '96': [['why', 'did', 'albert', 'schirding', 'kill', 'himself'],
#         ['trying', 'be', 'county', 'superintendent', 'schools,'],
#         ['blest', 'as', 'he', 'was', 'with', 'means', 'life'],
#         ['wonderful', 'children,', 'bringing', 'him', 'honor'],
#         ['ere', 'he', 'was', 'sixty?'],
#         ['if',
#          'even',
#          'one',
#          'my',
#          'boys',
#          'could',
#          'have',
#          'run',
#          'news-stand,'],
#         ['or',
#          'one',
#          'my',
#          'girls',
#          'could',
#          'have',
#          'married',
#          'decent',
#          'man,'],
#         ['i', 'should', 'not', 'have', 'walked', 'rain'],
#         ['jumped', 'into', 'bed', 'with', 'clothes', 'all', 'wet,'],
#         ['refusing', 'medical', 'aid.']],
#  '97': [['have', 'any', 'you,', 'passers-by,'],
#         ['had',
#          'an',
#          'old',
#          'tooth',
#          'that',
#          'was',
#          'an',
#          'unceasing',
#          'discomfort?'],
#         ['or', 'pain', 'side', 'that', 'never', 'quite', 'left', 'you?'],
#         ['or', 'malignant', 'growth', 'that', 'grew', 'with', 'time?'],
#         ['so', 'that', 'even', 'profoundest', 'slumber'],
#         ['there',
#          'was',
#          'shadowy',
#          'consciousness',
#          'or',
#          'phantom',
#          'thought'],
#         ['tooth,', 'side,', 'growth?'],
#         ['even', 'so', 'thwarted', 'love,', 'or', 'defeated', 'ambition,'],
#         ['or', 'blunder', 'life', 'which', 'mixed', 'your', 'life'],
#         ['hopelessly', 'end,'],
#         ['will,', 'like', 'tooth,', 'or', 'pain', 'side,'],
#         ['float', 'through', 'your', 'dreams', 'final', 'sleep'],
#         ['till', 'perfect', 'freedom', 'from', 'earth-sphere'],
#         ['comes', 'you', 'as', 'one', 'who', 'wakes'],
#         ['healed', 'glad', 'morning!']],
#  '98': [['they', 'got', 'me', 'into', 'sunday-school'],
#         ['spoon', 'river'],
#         ['tried', 'get', 'me', 'drop', 'confucius', 'jesus.'],
#         ['i', 'could', 'have', 'been', 'no', 'worse', 'off'],
#         ['if',
#          'i',
#          'had',
#          'tried',
#          'get',
#          'them',
#          'drop',
#          'jesus',
#          'confucius.'],
#         ['for,',
#          'without',
#          'any',
#          'warning,',
#          'as',
#          'if',
#          'it',
#          'were',
#          'prank,'],
#         ['sneaking', 'up', 'behind', 'me,', 'harry', 'wiley,'],
#         ['ministers', 'son,', 'caved', 'my', 'ribs', 'into', 'my', 'lungs,'],
#         ['with', 'blow', 'his', 'fist.'],
#         ['now',
#          'i',
#          'shall',
#          'never',
#          'sleep',
#          'with',
#          'my',
#          'ancestors',
#          'pekin,'],
#         ['no', 'children', 'shall', 'worship', 'at', 'my', 'grave.']],
#  '99': [['rich,', 'honored', 'by', 'my', 'fellow', 'citizens,'],
#         ['father', 'many', 'children,', 'born', 'noble', 'mother,'],
#         ['all', 'raised', 'there'],
#         ['great', 'mansion-house,', 'at', 'edge', 'town.'],
#         ['note', 'cedar', 'tree', 'on', 'lawn!'],
#         ['i',
#          'sent',
#          'all',
#          'boys',
#          'ann',
#          'arbor,',
#          'all',
#          'girls',
#          'rockford,'],
#         ['while',
#          'my',
#          'life',
#          'went',
#          'on,',
#          'getting',
#          'more',
#          'riches',
#          'honors'],
#         ['resting', 'under', 'my', 'cedar', 'tree', 'at', 'evening.'],
#         ['years', 'went', 'on.'],
#         ['i', 'sent', 'girls', 'europe;'],
#         ['i', 'dowered', 'them', 'when', 'married.'],
#         ['i', 'gave', 'boys', 'money', 'start', 'business.'],
#         ['they', 'were', 'strong', 'children,', 'promising', 'as', 'apples'],
#         ['before', 'bitten', 'places', 'show.'],
#         ['but', 'john', 'fled', 'country', 'disgrace.'],
#         ['jenny', 'died', 'child-birth'],
#         ['i', 'sat', 'under', 'my', 'cedar', 'tree.'],
#         ['harry', 'killed', 'himself', 'after', 'debauch,'],
#         ['susan', 'was', 'divorced'],
#         ['i', 'sat', 'under', 'my', 'cedar', 'tree.'],
#         ['paul', 'was', 'invalided', 'from', 'over', 'study,'],
#         ['mary', 'became', 'recluse', 'at', 'home', 'love', 'man'],
#         ['i', 'sat', 'under', 'my', 'cedar', 'tree.'],
#         ['all',
#          'were',
#          'gone,',
#          'or',
#          'broken-winged',
#          'or',
#          'devoured',
#          'by',
#          'life'],
#         ['i', 'sat', 'under', 'my', 'cedar', 'tree.'],
#         ['my', 'mate,', 'mother', 'them,', 'was', 'taken'],
#         ['i', 'sat', 'under', 'my', 'cedar', 'tree,'],
#         ['till', 'ninety', 'years', 'were', 'tolled.'],
#         ['o',
#          'maternal',
#          'earth,',
#          'which',
#          'rocks',
#          'fallen',
#          'leaf',
#          'sleep!']]}

# %%
text_dictionary = corpora.Dictionary()
for text in texts.values():
    text_dictionary.add_documents(text)
# Out:
# 2018-06-26 21:19:09,243 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2018-06-26 21:19:09,245 : INFO : built Dictionary(91 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 20 documents (total 120 corpus positions)
# 2018-06-26 21:19:09,246 : INFO : adding document #0 to Dictionary(91 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,247 : INFO : built Dictionary(156 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 38 documents (total 218 corpus positions)
# 2018-06-26 21:19:09,249 : INFO : adding document #0 to Dictionary(156 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,250 : INFO : built Dictionary(226 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 56 documents (total 330 corpus positions)
# 2018-06-26 21:19:09,251 : INFO : adding document #0 to Dictionary(226 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,253 : INFO : built Dictionary(323 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 81 documents (total 502 corpus positions)
# 2018-06-26 21:19:09,255 : INFO : adding document #0 to Dictionary(323 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,256 : INFO : built Dictionary(365 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 94 documents (total 566 corpus positions)
# 2018-06-26 21:19:09,257 : INFO : adding document #0 to Dictionary(365 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,260 : INFO : built Dictionary(417 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 112 documents (total 654 corpus positions)
# 2018-06-26 21:19:09,260 : INFO : adding document #0 to Dictionary(417 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,262 : INFO : built Dictionary(447 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 123 documents (total 721 corpus positions)
# 2018-06-26 21:19:09,263 : INFO : adding document #0 to Dictionary(447 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,264 : INFO : built Dictionary(516 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 142 documents (total 837 corpus positions)
# 2018-06-26 21:19:09,266 : INFO : adding document #0 to Dictionary(516 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,267 : INFO : built Dictionary(575 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 161 documents (total 945 corpus positions)
# 2018-06-26 21:19:09,268 : INFO : adding document #0 to Dictionary(575 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,271 : INFO : built Dictionary(645 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 184 documents (total 1091 corpus positions)
# 2018-06-26 21:19:09,294 : INFO : adding document #0 to Dictionary(645 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,296 : INFO : built Dictionary(671 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 195 documents (total 1140 corpus positions)
# 2018-06-26 21:19:09,299 : INFO : adding document #0 to Dictionary(671 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,301 : INFO : built Dictionary(694 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 205 documents (total 1188 corpus positions)
# 2018-06-26 21:19:09,303 : INFO : adding document #0 to Dictionary(694 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,309 : INFO : built Dictionary(728 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 220 documents (total 1266 corpus positions)
# 2018-06-26 21:19:09,311 : INFO : adding document #0 to Dictionary(728 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,317 : INFO : built Dictionary(768 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 232 documents (total 1339 corpus positions)
# 2018-06-26 21:19:09,334 : INFO : adding document #0 to Dictionary(768 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,340 : INFO : built Dictionary(805 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 247 documents (total 1429 corpus positions)
# 2018-06-26 21:19:09,342 : INFO : adding document #0 to Dictionary(805 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,355 : INFO : built Dictionary(822 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 254 documents (total 1456 corpus positions)
# 2018-06-26 21:19:09,358 : INFO : adding document #0 to Dictionary(822 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,364 : INFO : built Dictionary(879 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 273 documents (total 1572 corpus positions)
# 2018-06-26 21:19:09,403 : INFO : adding document #0 to Dictionary(879 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,404 : INFO : built Dictionary(908 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 290 documents (total 1643 corpus positions)
# 2018-06-26 21:19:09,439 : INFO : adding document #0 to Dictionary(908 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,450 : INFO : built Dictionary(954 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 308 documents (total 1737 corpus positions)
# 2018-06-26 21:19:09,453 : INFO : adding document #0 to Dictionary(954 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,456 : INFO : built Dictionary(1002 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 327 documents (total 1821 corpus positions)
# 2018-06-26 21:19:09,459 : INFO : adding document #0 to Dictionary(1002 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,461 : INFO : built Dictionary(1042 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 347 documents (total 1915 corpus positions)
# 2018-06-26 21:19:09,468 : INFO : adding document #0 to Dictionary(1042 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,470 : INFO : built Dictionary(1097 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 372 documents (total 2042 corpus positions)
# 2018-06-26 21:19:09,471 : INFO : adding document #0 to Dictionary(1097 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,473 : INFO : built Dictionary(1138 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 392 documents (total 2128 corpus positions)
# 2018-06-26 21:19:09,474 : INFO : adding document #0 to Dictionary(1138 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,479 : INFO : built Dictionary(1178 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 408 documents (total 2212 corpus positions)
# 2018-06-26 21:19:09,481 : INFO : adding document #0 to Dictionary(1178 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,489 : INFO : built Dictionary(1186 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 413 documents (total 2241 corpus positions)
# 2018-06-26 21:19:09,493 : INFO : adding document #0 to Dictionary(1186 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,496 : INFO : built Dictionary(1221 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 429 documents (total 2317 corpus positions)
# 2018-06-26 21:19:09,498 : INFO : adding document #0 to Dictionary(1221 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,502 : INFO : built Dictionary(1269 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 448 documents (total 2417 corpus positions)
# 2018-06-26 21:19:09,504 : INFO : adding document #0 to Dictionary(1269 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,508 : INFO : built Dictionary(1332 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 472 documents (total 2547 corpus positions)
# 2018-06-26 21:19:09,509 : INFO : adding document #0 to Dictionary(1332 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,515 : INFO : built Dictionary(1408 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 497 documents (total 2679 corpus positions)
# 2018-06-26 21:19:09,517 : INFO : adding document #0 to Dictionary(1408 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,522 : INFO : built Dictionary(1473 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 519 documents (total 2817 corpus positions)
# 2018-06-26 21:19:09,524 : INFO : adding document #0 to Dictionary(1473 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,526 : INFO : built Dictionary(1509 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 539 documents (total 2935 corpus positions)
# 2018-06-26 21:19:09,529 : INFO : adding document #0 to Dictionary(1509 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,531 : INFO : built Dictionary(1572 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 557 documents (total 3053 corpus positions)
# 2018-06-26 21:19:09,533 : INFO : adding document #0 to Dictionary(1572 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,534 : INFO : built Dictionary(1601 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 569 documents (total 3119 corpus positions)
# 2018-06-26 21:19:09,535 : INFO : adding document #0 to Dictionary(1601 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,537 : INFO : built Dictionary(1637 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 585 documents (total 3204 corpus positions)
# 2018-06-26 21:19:09,539 : INFO : adding document #0 to Dictionary(1637 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,542 : INFO : built Dictionary(1690 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 608 documents (total 3337 corpus positions)
# 2018-06-26 21:19:09,544 : INFO : adding document #0 to Dictionary(1690 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,549 : INFO : built Dictionary(1717 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 625 documents (total 3433 corpus positions)
# 2018-06-26 21:19:09,552 : INFO : adding document #0 to Dictionary(1717 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,554 : INFO : built Dictionary(1745 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 640 documents (total 3526 corpus positions)
# 2018-06-26 21:19:09,555 : INFO : adding document #0 to Dictionary(1745 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,557 : INFO : built Dictionary(1795 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 658 documents (total 3639 corpus positions)
# 2018-06-26 21:19:09,558 : INFO : adding document #0 to Dictionary(1795 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,560 : INFO : built Dictionary(1826 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 679 documents (total 3767 corpus positions)
# 2018-06-26 21:19:09,561 : INFO : adding document #0 to Dictionary(1826 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,563 : INFO : built Dictionary(1854 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 693 documents (total 3857 corpus positions)
# 2018-06-26 21:19:09,564 : INFO : adding document #0 to Dictionary(1854 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,566 : INFO : built Dictionary(1880 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 711 documents (total 3972 corpus positions)
# 2018-06-26 21:19:09,567 : INFO : adding document #0 to Dictionary(1880 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,570 : INFO : built Dictionary(1930 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 732 documents (total 4098 corpus positions)
# 2018-06-26 21:19:09,571 : INFO : adding document #0 to Dictionary(1930 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,575 : INFO : built Dictionary(1992 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 758 documents (total 4253 corpus positions)
# 2018-06-26 21:19:09,578 : INFO : adding document #0 to Dictionary(1992 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,582 : INFO : built Dictionary(2045 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 781 documents (total 4366 corpus positions)
# 2018-06-26 21:19:09,584 : INFO : adding document #0 to Dictionary(2045 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,585 : INFO : built Dictionary(2095 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 801 documents (total 4484 corpus positions)
# 2018-06-26 21:19:09,587 : INFO : adding document #0 to Dictionary(2095 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,588 : INFO : built Dictionary(2163 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 827 documents (total 4621 corpus positions)
# 2018-06-26 21:19:09,589 : INFO : adding document #0 to Dictionary(2163 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,591 : INFO : built Dictionary(2195 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 849 documents (total 4741 corpus positions)
# 2018-06-26 21:19:09,592 : INFO : adding document #0 to Dictionary(2195 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,594 : INFO : built Dictionary(2215 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 861 documents (total 4808 corpus positions)
# 2018-06-26 21:19:09,595 : INFO : adding document #0 to Dictionary(2215 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,597 : INFO : built Dictionary(2260 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 883 documents (total 4916 corpus positions)
# 2018-06-26 21:19:09,599 : INFO : adding document #0 to Dictionary(2260 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,601 : INFO : built Dictionary(2302 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 902 documents (total 5023 corpus positions)
# 2018-06-26 21:19:09,602 : INFO : adding document #0 to Dictionary(2302 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,604 : INFO : built Dictionary(2339 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 924 documents (total 5131 corpus positions)
# 2018-06-26 21:19:09,605 : INFO : adding document #0 to Dictionary(2339 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,607 : INFO : built Dictionary(2376 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 945 documents (total 5247 corpus positions)
# 2018-06-26 21:19:09,608 : INFO : adding document #0 to Dictionary(2376 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,610 : INFO : built Dictionary(2418 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 967 documents (total 5389 corpus positions)
# 2018-06-26 21:19:09,611 : INFO : adding document #0 to Dictionary(2418 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,613 : INFO : built Dictionary(2473 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 995 documents (total 5545 corpus positions)
# 2018-06-26 21:19:09,615 : INFO : adding document #0 to Dictionary(2473 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,617 : INFO : built Dictionary(2503 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1007 documents (total 5639 corpus positions)
# 2018-06-26 21:19:09,619 : INFO : adding document #0 to Dictionary(2503 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,622 : INFO : built Dictionary(2557 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1029 documents (total 5764 corpus positions)
# 2018-06-26 21:19:09,624 : INFO : adding document #0 to Dictionary(2557 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,627 : INFO : built Dictionary(2604 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1047 documents (total 5872 corpus positions)
# 2018-06-26 21:19:09,628 : INFO : adding document #0 to Dictionary(2604 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,630 : INFO : built Dictionary(2665 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1074 documents (total 6026 corpus positions)
# 2018-06-26 21:19:09,631 : INFO : adding document #0 to Dictionary(2665 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,633 : INFO : built Dictionary(2712 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1101 documents (total 6154 corpus positions)
# 2018-06-26 21:19:09,634 : INFO : adding document #0 to Dictionary(2712 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,636 : INFO : built Dictionary(2745 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1118 documents (total 6251 corpus positions)
# 2018-06-26 21:19:09,638 : INFO : adding document #0 to Dictionary(2745 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,639 : INFO : built Dictionary(2793 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1137 documents (total 6356 corpus positions)
# 2018-06-26 21:19:09,640 : INFO : adding document #0 to Dictionary(2793 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,642 : INFO : built Dictionary(2822 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1155 documents (total 6457 corpus positions)
# 2018-06-26 21:19:09,643 : INFO : adding document #0 to Dictionary(2822 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,644 : INFO : built Dictionary(2866 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1181 documents (total 6604 corpus positions)
# 2018-06-26 21:19:09,645 : INFO : adding document #0 to Dictionary(2866 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,646 : INFO : built Dictionary(2920 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1206 documents (total 6747 corpus positions)
# 2018-06-26 21:19:09,648 : INFO : adding document #0 to Dictionary(2920 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,649 : INFO : built Dictionary(2952 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1223 documents (total 6857 corpus positions)
# 2018-06-26 21:19:09,651 : INFO : adding document #0 to Dictionary(2952 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,652 : INFO : built Dictionary(2977 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1243 documents (total 6976 corpus positions)
# 2018-06-26 21:19:09,653 : INFO : adding document #0 to Dictionary(2977 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,655 : INFO : built Dictionary(3020 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1263 documents (total 7080 corpus positions)
# 2018-06-26 21:19:09,657 : INFO : adding document #0 to Dictionary(3020 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,660 : INFO : built Dictionary(3049 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1282 documents (total 7185 corpus positions)
# 2018-06-26 21:19:09,662 : INFO : adding document #0 to Dictionary(3049 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,665 : INFO : built Dictionary(3092 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1305 documents (total 7319 corpus positions)
# 2018-06-26 21:19:09,667 : INFO : adding document #0 to Dictionary(3092 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,668 : INFO : built Dictionary(3113 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1324 documents (total 7429 corpus positions)
# 2018-06-26 21:19:09,670 : INFO : adding document #0 to Dictionary(3113 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,671 : INFO : built Dictionary(3146 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1346 documents (total 7553 corpus positions)
# 2018-06-26 21:19:09,672 : INFO : adding document #0 to Dictionary(3146 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,674 : INFO : built Dictionary(3180 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1364 documents (total 7648 corpus positions)
# 2018-06-26 21:19:09,675 : INFO : adding document #0 to Dictionary(3180 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,676 : INFO : built Dictionary(3197 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1382 documents (total 7757 corpus positions)
# 2018-06-26 21:19:09,677 : INFO : adding document #0 to Dictionary(3197 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,678 : INFO : built Dictionary(3249 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1407 documents (total 7877 corpus positions)
# 2018-06-26 21:19:09,680 : INFO : adding document #0 to Dictionary(3249 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,682 : INFO : built Dictionary(3297 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1429 documents (total 7980 corpus positions)
# 2018-06-26 21:19:09,684 : INFO : adding document #0 to Dictionary(3297 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,687 : INFO : built Dictionary(3339 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1453 documents (total 8083 corpus positions)
# 2018-06-26 21:19:09,689 : INFO : adding document #0 to Dictionary(3339 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,692 : INFO : built Dictionary(3373 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1478 documents (total 8242 corpus positions)
# 2018-06-26 21:19:09,693 : INFO : adding document #0 to Dictionary(3373 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,694 : INFO : built Dictionary(3408 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1499 documents (total 8356 corpus positions)
# 2018-06-26 21:19:09,695 : INFO : adding document #0 to Dictionary(3408 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,698 : INFO : built Dictionary(3442 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1519 documents (total 8482 corpus positions)
# 2018-06-26 21:19:09,699 : INFO : adding document #0 to Dictionary(3442 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,700 : INFO : built Dictionary(3468 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1538 documents (total 8569 corpus positions)
# 2018-06-26 21:19:09,702 : INFO : adding document #0 to Dictionary(3468 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,705 : INFO : built Dictionary(3503 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1563 documents (total 8715 corpus positions)
# 2018-06-26 21:19:09,706 : INFO : adding document #0 to Dictionary(3503 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,710 : INFO : built Dictionary(3526 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1582 documents (total 8812 corpus positions)
# 2018-06-26 21:19:09,711 : INFO : adding document #0 to Dictionary(3526 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,713 : INFO : built Dictionary(3559 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1604 documents (total 8923 corpus positions)
# 2018-06-26 21:19:09,714 : INFO : adding document #0 to Dictionary(3559 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,716 : INFO : built Dictionary(3588 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1623 documents (total 9035 corpus positions)
# 2018-06-26 21:19:09,718 : INFO : adding document #0 to Dictionary(3588 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,719 : INFO : built Dictionary(3610 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1637 documents (total 9099 corpus positions)
# 2018-06-26 21:19:09,721 : INFO : adding document #0 to Dictionary(3610 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,723 : INFO : built Dictionary(3649 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1664 documents (total 9212 corpus positions)
# 2018-06-26 21:19:09,725 : INFO : adding document #0 to Dictionary(3649 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,736 : INFO : built Dictionary(3672 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1683 documents (total 9308 corpus positions)
# 2018-06-26 21:19:09,738 : INFO : adding document #0 to Dictionary(3672 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,740 : INFO : built Dictionary(3688 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1702 documents (total 9408 corpus positions)
# 2018-06-26 21:19:09,740 : INFO : adding document #0 to Dictionary(3688 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,742 : INFO : built Dictionary(3713 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1723 documents (total 9530 corpus positions)
# 2018-06-26 21:19:09,743 : INFO : adding document #0 to Dictionary(3713 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,745 : INFO : built Dictionary(3733 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1736 documents (total 9607 corpus positions)
# 2018-06-26 21:19:09,747 : INFO : adding document #0 to Dictionary(3733 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,749 : INFO : built Dictionary(3753 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1753 documents (total 9710 corpus positions)
# 2018-06-26 21:19:09,751 : INFO : adding document #0 to Dictionary(3753 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,752 : INFO : built Dictionary(3771 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1763 documents (total 9771 corpus positions)
# 2018-06-26 21:19:09,753 : INFO : adding document #0 to Dictionary(3771 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,755 : INFO : built Dictionary(3806 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1789 documents (total 9925 corpus positions)
# 2018-06-26 21:19:09,757 : INFO : adding document #0 to Dictionary(3806 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,762 : INFO : built Dictionary(3847 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1812 documents (total 10066 corpus positions)
# 2018-06-26 21:19:09,764 : INFO : adding document #0 to Dictionary(3847 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,766 : INFO : built Dictionary(3893 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1837 documents (total 10180 corpus positions)
# 2018-06-26 21:19:09,767 : INFO : adding document #0 to Dictionary(3893 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,769 : INFO : built Dictionary(3927 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1860 documents (total 10306 corpus positions)
# 2018-06-26 21:19:09,771 : INFO : adding document #0 to Dictionary(3927 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,773 : INFO : built Dictionary(3943 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1873 documents (total 10385 corpus positions)
# 2018-06-26 21:19:09,774 : INFO : adding document #0 to Dictionary(3943 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,776 : INFO : built Dictionary(3966 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1888 documents (total 10471 corpus positions)
# 2018-06-26 21:19:09,777 : INFO : adding document #0 to Dictionary(3966 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,779 : INFO : built Dictionary(3988 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1901 documents (total 10535 corpus positions)
# 2018-06-26 21:19:09,780 : INFO : adding document #0 to Dictionary(3988 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,782 : INFO : built Dictionary(4004 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1914 documents (total 10601 corpus positions)
# 2018-06-26 21:19:09,783 : INFO : adding document #0 to Dictionary(4004 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,785 : INFO : built Dictionary(4025 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1935 documents (total 10720 corpus positions)
# 2018-06-26 21:19:09,787 : INFO : adding document #0 to Dictionary(4025 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,789 : INFO : built Dictionary(4057 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1957 documents (total 10837 corpus positions)
# 2018-06-26 21:19:09,790 : INFO : adding document #0 to Dictionary(4057 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,794 : INFO : built Dictionary(4105 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 1987 documents (total 10988 corpus positions)
# 2018-06-26 21:19:09,797 : INFO : adding document #0 to Dictionary(4105 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,801 : INFO : built Dictionary(4146 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2014 documents (total 11129 corpus positions)
# 2018-06-26 21:19:09,804 : INFO : adding document #0 to Dictionary(4146 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,805 : INFO : built Dictionary(4176 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2033 documents (total 11230 corpus positions)
# 2018-06-26 21:19:09,807 : INFO : adding document #0 to Dictionary(4176 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,808 : INFO : built Dictionary(4218 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2056 documents (total 11348 corpus positions)
# 2018-06-26 21:19:09,810 : INFO : adding document #0 to Dictionary(4218 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,812 : INFO : built Dictionary(4263 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2083 documents (total 11507 corpus positions)
# 2018-06-26 21:19:09,813 : INFO : adding document #0 to Dictionary(4263 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,815 : INFO : built Dictionary(4285 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2097 documents (total 11592 corpus positions)
# 2018-06-26 21:19:09,815 : INFO : adding document #0 to Dictionary(4285 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,817 : INFO : built Dictionary(4360 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2142 documents (total 11840 corpus positions)
# 2018-06-26 21:19:09,819 : INFO : adding document #0 to Dictionary(4360 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,821 : INFO : built Dictionary(4392 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2161 documents (total 11949 corpus positions)
# 2018-06-26 21:19:09,822 : INFO : adding document #0 to Dictionary(4392 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,824 : INFO : built Dictionary(4462 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2198 documents (total 12161 corpus positions)
# 2018-06-26 21:19:09,825 : INFO : adding document #0 to Dictionary(4462 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,826 : INFO : built Dictionary(4478 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2210 documents (total 12217 corpus positions)
# 2018-06-26 21:19:09,827 : INFO : adding document #0 to Dictionary(4478 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,829 : INFO : built Dictionary(4510 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2235 documents (total 12360 corpus positions)
# 2018-06-26 21:19:09,830 : INFO : adding document #0 to Dictionary(4510 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,831 : INFO : built Dictionary(4531 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2253 documents (total 12456 corpus positions)
# 2018-06-26 21:19:09,833 : INFO : adding document #0 to Dictionary(4531 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,834 : INFO : built Dictionary(4582 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2279 documents (total 12607 corpus positions)
# 2018-06-26 21:19:09,837 : INFO : adding document #0 to Dictionary(4582 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,839 : INFO : built Dictionary(4627 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2307 documents (total 12798 corpus positions)
# 2018-06-26 21:19:09,841 : INFO : adding document #0 to Dictionary(4627 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,845 : INFO : built Dictionary(4656 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2333 documents (total 12913 corpus positions)
# 2018-06-26 21:19:09,846 : INFO : adding document #0 to Dictionary(4656 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,849 : INFO : built Dictionary(4684 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2356 documents (total 13059 corpus positions)
# 2018-06-26 21:19:09,851 : INFO : adding document #0 to Dictionary(4684 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,854 : INFO : built Dictionary(4723 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2378 documents (total 13176 corpus positions)
# 2018-06-26 21:19:09,855 : INFO : adding document #0 to Dictionary(4723 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,857 : INFO : built Dictionary(4752 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2398 documents (total 13292 corpus positions)
# 2018-06-26 21:19:09,858 : INFO : adding document #0 to Dictionary(4752 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,859 : INFO : built Dictionary(4776 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2419 documents (total 13410 corpus positions)
# 2018-06-26 21:19:09,860 : INFO : adding document #0 to Dictionary(4776 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,861 : INFO : built Dictionary(4805 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2442 documents (total 13545 corpus positions)
# 2018-06-26 21:19:09,863 : INFO : adding document #0 to Dictionary(4805 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,865 : INFO : built Dictionary(4831 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2457 documents (total 13623 corpus positions)
# 2018-06-26 21:19:09,867 : INFO : adding document #0 to Dictionary(4831 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,869 : INFO : built Dictionary(4845 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2468 documents (total 13679 corpus positions)
# 2018-06-26 21:19:09,871 : INFO : adding document #0 to Dictionary(4845 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,874 : INFO : built Dictionary(4877 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2486 documents (total 13814 corpus positions)
# 2018-06-26 21:19:09,876 : INFO : adding document #0 to Dictionary(4877 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,878 : INFO : built Dictionary(4899 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2499 documents (total 13884 corpus positions)
# 2018-06-26 21:19:09,879 : INFO : adding document #0 to Dictionary(4899 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,880 : INFO : built Dictionary(4927 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2516 documents (total 13975 corpus positions)
# 2018-06-26 21:19:09,882 : INFO : adding document #0 to Dictionary(4927 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,883 : INFO : built Dictionary(4989 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2547 documents (total 14155 corpus positions)
# 2018-06-26 21:19:09,884 : INFO : adding document #0 to Dictionary(4989 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,886 : INFO : built Dictionary(5014 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2562 documents (total 14234 corpus positions)
# 2018-06-26 21:19:09,887 : INFO : adding document #0 to Dictionary(5014 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,889 : INFO : built Dictionary(5047 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2583 documents (total 14339 corpus positions)
# 2018-06-26 21:19:09,892 : INFO : adding document #0 to Dictionary(5047 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,894 : INFO : built Dictionary(5069 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2597 documents (total 14416 corpus positions)
# 2018-06-26 21:19:09,895 : INFO : adding document #0 to Dictionary(5069 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,897 : INFO : built Dictionary(5092 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2612 documents (total 14514 corpus positions)
# 2018-06-26 21:19:09,899 : INFO : adding document #0 to Dictionary(5092 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,901 : INFO : built Dictionary(5114 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2624 documents (total 14587 corpus positions)
# 2018-06-26 21:19:09,902 : INFO : adding document #0 to Dictionary(5114 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,904 : INFO : built Dictionary(5130 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2637 documents (total 14664 corpus positions)
# 2018-06-26 21:19:09,914 : INFO : adding document #0 to Dictionary(5130 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,921 : INFO : built Dictionary(5146 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2648 documents (total 14729 corpus positions)
# 2018-06-26 21:19:09,922 : INFO : adding document #0 to Dictionary(5146 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,925 : INFO : built Dictionary(5165 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2667 documents (total 14840 corpus positions)
# 2018-06-26 21:19:09,926 : INFO : adding document #0 to Dictionary(5165 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,928 : INFO : built Dictionary(5194 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2690 documents (total 14952 corpus positions)
# 2018-06-26 21:19:09,936 : INFO : adding document #0 to Dictionary(5194 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,945 : INFO : built Dictionary(5220 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2715 documents (total 15098 corpus positions)
# 2018-06-26 21:19:09,952 : INFO : adding document #0 to Dictionary(5220 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,958 : INFO : built Dictionary(5237 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2730 documents (total 15184 corpus positions)
# 2018-06-26 21:19:09,961 : INFO : adding document #0 to Dictionary(5237 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,965 : INFO : built Dictionary(5264 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2748 documents (total 15258 corpus positions)
# 2018-06-26 21:19:09,967 : INFO : adding document #0 to Dictionary(5264 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,976 : INFO : built Dictionary(5281 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2766 documents (total 15392 corpus positions)
# 2018-06-26 21:19:09,978 : INFO : adding document #0 to Dictionary(5281 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:09,991 : INFO : built Dictionary(5293 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2781 documents (total 15471 corpus positions)
# 2018-06-26 21:19:09,996 : INFO : adding document #0 to Dictionary(5293 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,003 : INFO : built Dictionary(5313 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2798 documents (total 15558 corpus positions)
# 2018-06-26 21:19:10,004 : INFO : adding document #0 to Dictionary(5313 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,008 : INFO : built Dictionary(5351 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2822 documents (total 15691 corpus positions)
# 2018-06-26 21:19:10,010 : INFO : adding document #0 to Dictionary(5351 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,013 : INFO : built Dictionary(5389 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2846 documents (total 15824 corpus positions)
# 2018-06-26 21:19:10,018 : INFO : adding document #0 to Dictionary(5389 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,023 : INFO : built Dictionary(5420 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2869 documents (total 15963 corpus positions)
# 2018-06-26 21:19:10,024 : INFO : adding document #0 to Dictionary(5420 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,027 : INFO : built Dictionary(5436 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2882 documents (total 16033 corpus positions)
# 2018-06-26 21:19:10,029 : INFO : adding document #0 to Dictionary(5436 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,031 : INFO : built Dictionary(5449 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2898 documents (total 16149 corpus positions)
# 2018-06-26 21:19:10,033 : INFO : adding document #0 to Dictionary(5449 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,040 : INFO : built Dictionary(5486 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2923 documents (total 16290 corpus positions)
# 2018-06-26 21:19:10,042 : INFO : adding document #0 to Dictionary(5486 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,044 : INFO : built Dictionary(5505 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2943 documents (total 16395 corpus positions)
# 2018-06-26 21:19:10,045 : INFO : adding document #0 to Dictionary(5505 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,049 : INFO : built Dictionary(5541 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2964 documents (total 16493 corpus positions)
# 2018-06-26 21:19:10,052 : INFO : adding document #0 to Dictionary(5541 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,054 : INFO : built Dictionary(5558 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2983 documents (total 16594 corpus positions)
# 2018-06-26 21:19:10,056 : INFO : adding document #0 to Dictionary(5558 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,058 : INFO : built Dictionary(5592 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 2999 documents (total 16719 corpus positions)
# 2018-06-26 21:19:10,059 : INFO : adding document #0 to Dictionary(5592 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,061 : INFO : built Dictionary(5603 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 3012 documents (total 16791 corpus positions)
# 2018-06-26 21:19:10,062 : INFO : adding document #0 to Dictionary(5603 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,064 : INFO : built Dictionary(5628 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 3026 documents (total 16871 corpus positions)
# 2018-06-26 21:19:10,065 : INFO : adding document #0 to Dictionary(5628 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,066 : INFO : built Dictionary(5650 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 3047 documents (total 16980 corpus positions)
# 2018-06-26 21:19:10,072 : INFO : adding document #0 to Dictionary(5650 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,075 : INFO : built Dictionary(5676 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 3071 documents (total 17102 corpus positions)
# ...
# 2018-06-26 21:19:10,339 : INFO : adding document #0 to Dictionary(7504 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,341 : INFO : built Dictionary(7522 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4339 documents (total 24336 corpus positions)
# 2018-06-26 21:19:10,342 : INFO : adding document #0 to Dictionary(7522 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,345 : INFO : built Dictionary(7540 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4358 documents (total 24444 corpus positions)
# 2018-06-26 21:19:10,349 : INFO : adding document #0 to Dictionary(7540 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,351 : INFO : built Dictionary(7573 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4377 documents (total 24548 corpus positions)
# 2018-06-26 21:19:10,354 : INFO : adding document #0 to Dictionary(7573 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,357 : INFO : built Dictionary(7594 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4396 documents (total 24664 corpus positions)
# 2018-06-26 21:19:10,361 : INFO : adding document #0 to Dictionary(7594 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,364 : INFO : built Dictionary(7604 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4406 documents (total 24700 corpus positions)
# 2018-06-26 21:19:10,365 : INFO : adding document #0 to Dictionary(7604 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,367 : INFO : built Dictionary(7617 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4419 documents (total 24756 corpus positions)
# 2018-06-26 21:19:10,372 : INFO : adding document #0 to Dictionary(7617 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,375 : INFO : built Dictionary(7639 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4431 documents (total 24837 corpus positions)
# 2018-06-26 21:19:10,377 : INFO : adding document #0 to Dictionary(7639 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,384 : INFO : built Dictionary(7667 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4453 documents (total 24960 corpus positions)
# 2018-06-26 21:19:10,385 : INFO : adding document #0 to Dictionary(7667 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,387 : INFO : built Dictionary(7698 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4479 documents (total 25101 corpus positions)
# 2018-06-26 21:19:10,388 : INFO : adding document #0 to Dictionary(7698 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,391 : INFO : built Dictionary(7709 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4494 documents (total 25191 corpus positions)
# 2018-06-26 21:19:10,406 : INFO : adding document #0 to Dictionary(7709 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,426 : INFO : built Dictionary(7726 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4508 documents (total 25274 corpus positions)
# 2018-06-26 21:19:10,428 : INFO : adding document #0 to Dictionary(7726 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,430 : INFO : built Dictionary(7737 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4522 documents (total 25361 corpus positions)
# 2018-06-26 21:19:10,432 : INFO : adding document #0 to Dictionary(7737 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,434 : INFO : built Dictionary(7751 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4538 documents (total 25458 corpus positions)
# 2018-06-26 21:19:10,436 : INFO : adding document #0 to Dictionary(7751 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,437 : INFO : built Dictionary(7764 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4552 documents (total 25544 corpus positions)
# 2018-06-26 21:19:10,439 : INFO : adding document #0 to Dictionary(7764 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,442 : INFO : built Dictionary(7780 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4567 documents (total 25624 corpus positions)
# 2018-06-26 21:19:10,443 : INFO : adding document #0 to Dictionary(7780 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,446 : INFO : built Dictionary(7813 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4592 documents (total 25753 corpus positions)
# 2018-06-26 21:19:10,447 : INFO : adding document #0 to Dictionary(7813 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,448 : INFO : built Dictionary(7823 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4599 documents (total 25801 corpus positions)
# 2018-06-26 21:19:10,451 : INFO : adding document #0 to Dictionary(7823 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,458 : INFO : built Dictionary(7840 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4622 documents (total 25909 corpus positions)
# 2018-06-26 21:19:10,461 : INFO : adding document #0 to Dictionary(7840 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,464 : INFO : built Dictionary(7850 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4636 documents (total 25993 corpus positions)
# 2018-06-26 21:19:10,467 : INFO : adding document #0 to Dictionary(7850 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,469 : INFO : built Dictionary(7890 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4660 documents (total 26150 corpus positions)
# 2018-06-26 21:19:10,470 : INFO : adding document #0 to Dictionary(7890 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,472 : INFO : built Dictionary(7913 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4686 documents (total 26259 corpus positions)
# 2018-06-26 21:19:10,473 : INFO : adding document #0 to Dictionary(7913 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,476 : INFO : built Dictionary(7922 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4698 documents (total 26315 corpus positions)
# 2018-06-26 21:19:10,477 : INFO : adding document #0 to Dictionary(7922 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,481 : INFO : built Dictionary(7948 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4713 documents (total 26398 corpus positions)
# 2018-06-26 21:19:10,482 : INFO : adding document #0 to Dictionary(7948 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,484 : INFO : built Dictionary(7962 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4727 documents (total 26476 corpus positions)
# 2018-06-26 21:19:10,485 : INFO : adding document #0 to Dictionary(7962 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,490 : INFO : built Dictionary(7982 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4744 documents (total 26565 corpus positions)
# 2018-06-26 21:19:10,492 : INFO : adding document #0 to Dictionary(7982 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,494 : INFO : built Dictionary(8005 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4764 documents (total 26694 corpus positions)
# 2018-06-26 21:19:10,497 : INFO : adding document #0 to Dictionary(8005 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,499 : INFO : built Dictionary(8023 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4786 documents (total 26800 corpus positions)
# 2018-06-26 21:19:10,500 : INFO : adding document #0 to Dictionary(8023 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,505 : INFO : built Dictionary(8045 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4803 documents (total 26892 corpus positions)
# 2018-06-26 21:19:10,507 : INFO : adding document #0 to Dictionary(8045 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,510 : INFO : built Dictionary(8073 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4825 documents (total 27045 corpus positions)
# 2018-06-26 21:19:10,511 : INFO : adding document #0 to Dictionary(8073 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,513 : INFO : built Dictionary(8080 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4834 documents (total 27100 corpus positions)
# 2018-06-26 21:19:10,514 : INFO : adding document #0 to Dictionary(8080 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,518 : INFO : built Dictionary(8094 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4847 documents (total 27161 corpus positions)
# 2018-06-26 21:19:10,519 : INFO : adding document #0 to Dictionary(8094 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,522 : INFO : built Dictionary(8104 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4858 documents (total 27217 corpus positions)
# 2018-06-26 21:19:10,524 : INFO : adding document #0 to Dictionary(8104 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,526 : INFO : built Dictionary(8121 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4870 documents (total 27264 corpus positions)
# 2018-06-26 21:19:10,528 : INFO : adding document #0 to Dictionary(8121 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,530 : INFO : built Dictionary(8149 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4889 documents (total 27371 corpus positions)
# 2018-06-26 21:19:10,533 : INFO : adding document #0 to Dictionary(8149 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,541 : INFO : built Dictionary(8168 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4909 documents (total 27480 corpus positions)
# 2018-06-26 21:19:10,542 : INFO : adding document #0 to Dictionary(8168 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,544 : INFO : built Dictionary(8175 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4918 documents (total 27540 corpus positions)
# 2018-06-26 21:19:10,545 : INFO : adding document #0 to Dictionary(8175 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,549 : INFO : built Dictionary(8209 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4936 documents (total 27638 corpus positions)
# 2018-06-26 21:19:10,551 : INFO : adding document #0 to Dictionary(8209 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,553 : INFO : built Dictionary(8236 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4960 documents (total 27784 corpus positions)
# 2018-06-26 21:19:10,556 : INFO : adding document #0 to Dictionary(8236 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,561 : INFO : built Dictionary(8255 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4980 documents (total 27901 corpus positions)
# 2018-06-26 21:19:10,564 : INFO : adding document #0 to Dictionary(8255 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,569 : INFO : built Dictionary(8265 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 4994 documents (total 27979 corpus positions)
# 2018-06-26 21:19:10,570 : INFO : adding document #0 to Dictionary(8265 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,573 : INFO : built Dictionary(8271 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 5002 documents (total 28030 corpus positions)
# 2018-06-26 21:19:10,574 : INFO : adding document #0 to Dictionary(8271 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,575 : INFO : built Dictionary(8282 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 5012 documents (total 28079 corpus positions)
# 2018-06-26 21:19:10,576 : INFO : adding document #0 to Dictionary(8282 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,578 : INFO : built Dictionary(8301 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 5031 documents (total 28167 corpus positions)
# 2018-06-26 21:19:10,580 : INFO : adding document #0 to Dictionary(8301 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,582 : INFO : built Dictionary(8312 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 5042 documents (total 28218 corpus positions)
# 2018-06-26 21:19:10,585 : INFO : adding document #0 to Dictionary(8312 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,588 : INFO : built Dictionary(8335 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 5065 documents (total 28359 corpus positions)
# 2018-06-26 21:19:10,591 : INFO : adding document #0 to Dictionary(8335 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,599 : INFO : built Dictionary(8354 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 5084 documents (total 28461 corpus positions)
# 2018-06-26 21:19:10,603 : INFO : adding document #0 to Dictionary(8354 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,604 : INFO : built Dictionary(8371 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 5099 documents (total 28559 corpus positions)
# 2018-06-26 21:19:10,606 : INFO : adding document #0 to Dictionary(8371 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,608 : INFO : built Dictionary(8379 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 5109 documents (total 28620 corpus positions)
# 2018-06-26 21:19:10,608 : INFO : adding document #0 to Dictionary(8379 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,610 : INFO : built Dictionary(8395 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 5124 documents (total 28705 corpus positions)
# 2018-06-26 21:19:10,612 : INFO : adding document #0 to Dictionary(8395 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,618 : INFO : built Dictionary(8409 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 5135 documents (total 28777 corpus positions)
# 2018-06-26 21:19:10,623 : INFO : adding document #0 to Dictionary(8409 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,630 : INFO : built Dictionary(8435 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 5164 documents (total 28943 corpus positions)
# 2018-06-26 21:19:10,632 : INFO : adding document #0 to Dictionary(8435 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...)
# 2018-06-26 21:19:10,634 : INFO : built Dictionary(8446 unique tokens: ['dear', 'jane!', 'winsome', '(where', 'how']...) from 5174 documents (total 28990 corpus positions)

# %%
text_dictionary.save('../data/spa.dict')
# Out:
# 2018-06-26 21:20:08,758 : INFO : saving Dictionary object under ../data/spa.dict, separately None
# 2018-06-26 21:20:08,766 : INFO : saved ../data/spa.dict
